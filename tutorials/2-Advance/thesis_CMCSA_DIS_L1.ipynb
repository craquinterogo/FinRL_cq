# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['CMCSA','DIS']
print(DOW_30_TICKER)
# Out:
# ['CMCSA', 'DIS']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close    volume  \
# 6121  2022-05-26  104.220001  106.129997  103.959999  105.610001  11297800
# 6122  2022-05-27   44.130001   44.639999   43.980000   43.477409  18073500
# 6123  2022-05-27  106.889999  109.370003  106.529999  109.320000  13671300
# 6124  2022-05-31   43.910000   44.660000   43.480000   43.595554  25249600
# 6125  2022-05-31  110.000000  111.239998  107.910004  110.440002  20274600
#
#         tic  day
# 6121    DIS    3
# 6122  CMCSA    4
# 6123    DIS    4
# 6124  CMCSA    1
# 6125    DIS    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume    tic  \
# 0  2010-04-01   9.410000   9.520000   9.310000   7.365880  38877200  CMCSA
# 1  2010-04-01  35.070000  35.590000  35.009998  30.965103  14603000    DIS
# 2  2010-04-05   9.405000   9.490000   9.340000   7.387473  26500200  CMCSA
# 3  2010-04-05  35.279999  35.540001  35.070000  30.677660  10607900    DIS
# 4  2010-04-06   9.340000   9.460000   9.290000   7.363919  22708600  CMCSA
#
#    day
# 0    3
# 1    3
# 2    0
# 3    0
# 4    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 350000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.88440425123129
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_57
# -------------------------------------
# | time/                 |           |
# |    fps                | 37        |
# |    iterations         | 100       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0.0665    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.194     |
# |    reward             | 0.6202824 |
# |    std                | 1.01      |
# |    value_loss         | 0.167     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 200        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -0.216     |
# |    reward             | -0.1982752 |
# |    std                | 1.01       |
# |    value_loss         | 0.387      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | -1.36     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -1.99     |
# |    reward             | 1.2304673 |
# |    std                | 1.01      |
# |    value_loss         | 2.54      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 116        |
# |    iterations         | 400        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0.172      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 1.48       |
# |    reward             | -1.5945746 |
# |    std                | 1.01       |
# |    value_loss         | 0.506      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 500        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0.0226     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 6.86       |
# |    reward             | -7.8841085 |
# |    std                | 1.01       |
# |    value_loss         | 23.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 152         |
# |    iterations         | 600         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.197      |
# |    reward             | 0.009260671 |
# |    std                | 1.01        |
# |    value_loss         | 0.0244      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 166        |
# |    iterations         | 700        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -2.9       |
# |    reward             | 0.19087611 |
# |    std                | 1.01       |
# |    value_loss         | 1.13       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 179        |
# |    iterations         | 800        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.334      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -5.2       |
# |    reward             | 0.47614628 |
# |    std                | 1.01       |
# |    value_loss         | 5.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 191        |
# |    iterations         | 900        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0.114      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 2.58       |
# |    reward             | -0.1098292 |
# |    std                | 1.01       |
# |    value_loss         | 2.06       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 1000      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0.000377  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -2.7      |
# |    reward             | 0.6817189 |
# |    std                | 1.01      |
# |    value_loss         | 2.8       |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.16602293082098663
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_48
# ------------------------------------
# | time/              |             |
# |    fps             | 213         |
# |    iterations      | 1           |
# |    time_elapsed    | 9           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.17495583 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0029061497 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0141      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0848       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00112     |
# |    reward               | -0.17574924  |
# |    std                  | 1            |
# |    value_loss           | 0.212        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031672788 |
# |    clip_fraction        | 0.00737      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0471      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.23         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00116     |
# |    reward               | 0.028360149  |
# |    std                  | 1            |
# |    value_loss           | 2.05         |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.11590798205222401
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_48
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  19.88440425123129
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_46
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | -0.404   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.475   |
# |    reward             | 0.540384 |
# |    std                | 1.02     |
# |    value_loss         | 0.166    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 200       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | -0.0781   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -1.68     |
# |    reward             | 0.4306789 |
# |    std                | 1.02      |
# |    value_loss         | 0.819     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 96        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -0.0205   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -5.08     |
# |    reward             | 1.3191222 |
# |    std                | 1.02      |
# |    value_loss         | 3.39      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 400        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -0.123     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 2.81       |
# |    reward             | -1.6767604 |
# |    std                | 1.03       |
# |    value_loss         | 1.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 139        |
# |    iterations         | 500        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 0.0166     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -4.89      |
# |    reward             | -11.328189 |
# |    std                | 1.02       |
# |    value_loss         | 48.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 158        |
# |    iterations         | 600        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 2.34       |
# |    reward             | 0.40190032 |
# |    std                | 1.02       |
# |    value_loss         | 0.593      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 173         |
# |    iterations         | 700         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 0.137       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 3.62        |
# |    reward             | -0.73471886 |
# |    std                | 1.02        |
# |    value_loss         | 1.73        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 187          |
# |    iterations         | 800          |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -2.85        |
# |    explained_variance | -0.913       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 0.841        |
# |    reward             | -0.007222587 |
# |    std                | 1.01         |
# |    value_loss         | 0.464        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -1.29      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -5.17      |
# |    reward             | 0.43434152 |
# |    std                | 1.01       |
# |    value_loss         | 2.49       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -0.558     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 1.14       |
# |    reward             | 0.63736635 |
# |    std                | 1.01       |
# |    value_loss         | 0.651      |
# --------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.03870128325612266
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_46
# ------------------------------------
# | time/              |             |
# |    fps             | 160         |
# |    iterations      | 1           |
# |    time_elapsed    | 12          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.09876115 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 2            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0045976853 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.025       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.141        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00175     |
# |    reward               | -0.4339863   |
# |    std                  | 0.99         |
# |    value_loss           | 0.605        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 3            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.004135382  |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00245     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.6          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00435     |
# |    reward               | -0.032270845 |
# |    std                  | 0.995        |
# |    value_loss           | 2.92         |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.12952566768551105
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_46
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  19.88440425123129
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_46
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0.0433    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -0.00685  |
# |    reward             | 0.6505132 |
# |    std                | 1.01      |
# |    value_loss         | 0.219     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 97          |
# |    iterations         | 200         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.85       |
# |    explained_variance | 0.0756      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.632       |
# |    reward             | -0.80548245 |
# |    std                | 1.01        |
# |    value_loss         | 0.624       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 300       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | -0.022    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -5.61     |
# |    reward             | 1.0854307 |
# |    std                | 1         |
# |    value_loss         | 2.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 400        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -0.00585   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 3.03       |
# |    reward             | -1.4183334 |
# |    std                | 1.01       |
# |    value_loss         | 2.49       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 166       |
# |    iterations         | 500       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0.0124    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -11.2     |
# |    reward             | -11.02663 |
# |    std                | 1.01      |
# |    value_loss         | 51.8      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 186         |
# |    iterations         | 600         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.85       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 1.81        |
# |    reward             | -0.15979141 |
# |    std                | 1.01        |
# |    value_loss         | 0.658       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 202        |
# |    iterations         | 700        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.045      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -5.32      |
# |    reward             | 0.23777036 |
# |    std                | 1.01       |
# |    value_loss         | 3.66       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 215         |
# |    iterations         | 800         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.85       |
# |    explained_variance | -0.17       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -3.77       |
# |    reward             | -0.39267996 |
# |    std                | 1.01        |
# |    value_loss         | 2.39        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 900        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | -0.212     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 0.384      |
# |    reward             | 0.33457276 |
# |    std                | 0.993      |
# |    value_loss         | 1.19       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 240       |
# |    iterations         | 1000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 1.75      |
# |    reward             | 1.3371919 |
# |    std                | 1         |
# |    value_loss         | 5.6       |
# -------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  0.09190904711673817
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_46
# -----------------------------------
# | time/              |            |
# |    fps             | 212        |
# |    iterations      | 1          |
# |    time_elapsed    | 9          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.0294666 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036338991 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0154      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000448    |
# |    reward               | 0.52480006   |
# |    std                  | 1            |
# |    value_loss           | 0.0387       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0041955877 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00247      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.567        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00333     |
# |    reward               | -0.09765207  |
# |    std                  | 1            |
# |    value_loss           | 1.75         |
# ------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  0.0030064420526657396
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_45
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  19.88440425123129
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_43
# --------------------------------------
# | time/                 |            |
# |    fps                | 67         |
# |    iterations         | 100        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | -0.357     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.921      |
# |    reward             | 0.71813875 |
# |    std                | 1.02       |
# |    value_loss         | 0.473      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 200        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | -0.176     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 1.08       |
# |    reward             | -0.7982235 |
# |    std                | 1.02       |
# |    value_loss         | 1.07       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -0.499    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -4.4      |
# |    reward             | 1.2752936 |
# |    std                | 1.02      |
# |    value_loss         | 3.08      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 121        |
# |    iterations         | 400        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -0.0611    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 4.06       |
# |    reward             | -1.6194719 |
# |    std                | 1.02       |
# |    value_loss         | 3.64       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 500        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | 0.0496     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -18.2      |
# |    reward             | -12.626192 |
# |    std                | 1.03       |
# |    value_loss         | 64.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 160       |
# |    iterations         | 600       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -1.12     |
# |    reward             | 0.5593998 |
# |    std                | 1.03      |
# |    value_loss         | 0.181     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 175        |
# |    iterations         | 700        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0.00838    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -0.398     |
# |    reward             | -0.7547964 |
# |    std                | 1.03       |
# |    value_loss         | 0.126      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 188         |
# |    iterations         | 800         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | -0.239      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 0.979       |
# |    reward             | 0.118815884 |
# |    std                | 1.03        |
# |    value_loss         | 0.621       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 201        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | 0.259      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 0.596      |
# |    reward             | -0.9643985 |
# |    std                | 1.03       |
# |    value_loss         | 0.286      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 213        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -0.162     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 0.698      |
# |    reward             | -2.7649403 |
# |    std                | 1.03       |
# |    value_loss         | 1.09       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.22902999949472472
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_43
# ------------------------------------
# | time/              |             |
# |    fps             | 198         |
# |    iterations      | 1           |
# |    time_elapsed    | 10          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.08449751 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033916072 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0167       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.398        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00193     |
# |    reward               | -0.06196339  |
# |    std                  | 1            |
# |    value_loss           | 0.609        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031879216 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0654       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.35         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00218     |
# |    reward               | -0.06079056  |
# |    std                  | 1            |
# |    value_loss           | 1.72         |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  -0.22196638156541335
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_43
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  14.343137296040853  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C   0.166023   0.115908         0.0
# 1  189  2021-04-06  2021-07-06        A2C   0.038701  -0.129526   -0.074916
# 2  252  2021-07-06  2021-10-04        A2C   0.091909   0.003006    0.078526
# 3  315  2021-10-04  2022-01-03        PPO   -0.22903  -0.221966   -0.243624

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.1970586332567765

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0  350000.000000  2021-04-06           NaN  2021-04-06
# 1  349735.553271  2021-04-07     -0.000756  2021-04-07
# 2  349611.375482  2021-04-08     -0.000355  2021-04-08
# 3  349648.195442  2021-04-09      0.000105  2021-04-09
# 4  349029.881749  2021-04-12     -0.001768  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.210283
# Cumulative returns    -0.210283
# Annual volatility      0.183742
# Sharpe ratio          -1.197059
# Calmar ratio          -0.857473
# Stability              0.672843
# Max drawdown          -0.245235
# Omega ratio            0.794541
# Sortino ratio         -1.529251
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.906319
# Daily value at risk   -0.024022
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-21.028%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-21.028%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.374%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.20</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.86</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.67</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.524%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.53</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.402%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.25</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.52</td>
#       <td>2021-09-09</td>
#       <td>2022-03-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.07</td>
#       <td>2021-05-07</td>
#       <td>2021-05-19</td>
#       <td>2021-07-12</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.17</td>
#       <td>2021-07-12</td>
#       <td>2021-08-04</td>
#       <td>2021-09-07</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.82</td>
#       <td>2021-04-30</td>
#       <td>2021-05-05</td>
#       <td>2021-05-07</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.46</td>
#       <td>2021-04-16</td>
#       <td>2021-04-20</td>
#       <td>2021-04-29</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.09%</td>
#       <td>-6.77%</td>
#       <td>3.81%</td>
#     </tr>
#   </tbody>
# </table>
