# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['A','TT']
print(DOW_30_TICKER)
# Out:
# ['A', 'TT']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6630, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close    volume tic  day
# 0  2009-04-01  10.815451  11.537911  10.743920  10.393166   5530768   A    2
# 1  2009-04-01   8.476740   9.133563   8.458150   7.215966  27483491  TT    2
# 2  2009-04-02  11.723891  11.995708  11.573677  10.601031   5987774   A    3
# 3  2009-04-02   9.257492  10.261317   9.083992   7.951473  21417273  TT    3
# 4  2009-04-03  11.230329  11.874106  11.230329  10.691974   4024842   A    4

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume tic  \
# 6625  2022-05-26  135.600006  137.350006  135.529999  135.545670  1025500  TT
# 6626  2022-05-27  124.919998  130.770004  124.489998  130.094025  2698800   A
# 6627  2022-05-27  138.220001  140.570007  137.740005  139.201569   989400  TT
# 6628  2022-05-31  128.910004  130.070007  126.720001  127.114464  3403100   A
# 6629  2022-05-31  138.639999  139.059998  136.520004  136.784119  2507900  TT
#
#       day
# 6625    3
# 6626    4
# 6627    4
# 6628    1
# 6629    1

# %%
df.shape
# Out:
# (6630, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume tic  day
# 0  2009-04-01  10.815451  11.537911  10.743920  10.393166   5530768   A    2
# 1  2009-04-01   8.476740   9.133563   8.458150   7.215966  27483491  TT    2
# 2  2009-04-02  11.723891  11.995708  11.573677  10.601031   5987774   A    3
# 3  2009-04-02   9.257492  10.261317   9.083992   7.951473  21417273  TT    3
# 4  2009-04-03  11.230329  11.874106  11.230329  10.691974   4024842   A    4

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# A     3315
# TT    3315
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# A     3315
# TT    3315
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

# ensemble_agent = DRLEnsembleAgent(df=processed,
#                  train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
#                  val_test_period=(TEST_START_DATE,TEST_END_DATE),
#                  rebalance_window=rebalance_window, 
#                  validation_window=validation_window, 
#                  **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  21.04995814733224
# ======Model training from:  2009-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_42
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 100       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -0.112    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -3.43     |
# |    reward             | 0.4372082 |
# |    std                | 0.993     |
# |    value_loss         | 13.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 159       |
# |    iterations         | 200       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0.0906    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 0.444     |
# |    reward             | -1.131838 |
# |    std                | 1.01      |
# |    value_loss         | 0.503     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 124       |
# |    iterations         | 300       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | -0.00219  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -10.6     |
# |    reward             | 2.4560554 |
# |    std                | 1.01      |
# |    value_loss         | 19.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 149       |
# |    iterations         | 400       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -6.87     |
# |    reward             | 1.3524292 |
# |    std                | 1.02      |
# |    value_loss         | 6.19      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 500       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 19.6      |
# |    reward             | -2.493533 |
# |    std                | 1.03      |
# |    value_loss         | 50.3      |
# -------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 187            |
# |    iterations         | 600            |
# |    time_elapsed       | 16             |
# |    total_timesteps    | 3000           |
# | train/                |                |
# |    entropy_loss       | -2.89          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 599            |
# |    policy_loss        | -0.895         |
# |    reward             | -0.00042395692 |
# |    std                | 1.03           |
# |    value_loss         | 0.078          |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 202          |
# |    iterations         | 700          |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -0.19        |
# |    reward             | -0.030570593 |
# |    std                | 1.03         |
# |    value_loss         | 0.00515      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 215           |
# |    iterations         | 800           |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.92         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.0189        |
# |    reward             | -0.0021840497 |
# |    std                | 1.04          |
# |    value_loss         | 0.000179      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 227            |
# |    iterations         | 900            |
# |    time_elapsed       | 19             |
# |    total_timesteps    | 4500           |
# | train/                |                |
# |    entropy_loss       | -2.94          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 899            |
# |    policy_loss        | -0.0128        |
# |    reward             | -7.3560645e-05 |
# |    std                | 1.06           |
# |    value_loss         | 2.08e-05       |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 1000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.98     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.00365   |
# |    reward             | 0.0       |
# |    std                | 1.08      |
# |    value_loss         | 5.64e-05  |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.2754139585755682
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_35
# -----------------------------------
# | time/              |            |
# |    fps             | 529        |
# |    iterations      | 1          |
# |    time_elapsed    | 3          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.20467806 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0025253831 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0796       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000192    |
# |    reward               | 0.27304038   |
# |    std                  | 1.01         |
# |    value_loss           | 0.197        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 3             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0027526137  |
# |    clip_fraction        | 0.0204        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.446         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.0012       |
# |    reward               | -0.0037234873 |
# |    std                  | 1.02          |
# |    value_loss           | 1.69          |
# -------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.3515938854024806
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_34
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  21.04995814733224
# ======Model training from:  2009-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_27
# -------------------------------------
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -3.08     |
# |    reward             | 0.3181313 |
# |    std                | 1         |
# |    value_loss         | 4.42      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 331        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.0985     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 1.07       |
# |    reward             | -0.7868372 |
# |    std                | 1.01       |
# |    value_loss         | 0.808      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 336       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | -0.219    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -10.6     |
# |    reward             | 2.3903966 |
# |    std                | 1.01      |
# |    value_loss         | 9.89      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 400       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -6.78     |
# |    reward             | 0.8569035 |
# |    std                | 0.999     |
# |    value_loss         | 11.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 148        |
# |    iterations         | 500        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 12.5       |
# |    reward             | -1.6899322 |
# |    std                | 1.01       |
# |    value_loss         | 15         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 162        |
# |    iterations         | 600        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -0.0164    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 12.6       |
# |    reward             | -11.364945 |
# |    std                | 1.01       |
# |    value_loss         | 53.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 177        |
# |    iterations         | 700        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -0.0561    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -0.105     |
# |    reward             | -4.0847764 |
# |    std                | 1.01       |
# |    value_loss         | 4.43       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 800      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.675   |
# |    reward             | 2.291892 |
# |    std                | 1.02     |
# |    value_loss         | 1.76     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 200      |
# |    iterations         | 900      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 9.17     |
# |    reward             | 3.568343 |
# |    std                | 1.02     |
# |    value_loss         | 15.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 4.16      |
# |    reward             | 0.9235387 |
# |    std                | 1.01      |
# |    value_loss         | 4.8       |
# -------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.3713250484109953
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_27
# -----------------------------------
# | time/              |            |
# |    fps             | 484        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.26689813 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068198647 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0867       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00379     |
# |    reward               | 0.037273686  |
# |    std                  | 0.998        |
# |    value_loss           | 0.214        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0030814372 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.71         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00147     |
# |    reward               | 0.0036728054 |
# |    std                  | 1            |
# |    value_loss           | 5.41         |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.2941318061527265
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_27
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  21.04995814733224
# ======Model training from:  2009-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_25
# --------------------------------------
# | time/                 |            |
# |    fps                | 328        |
# |    iterations         | 100        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -3.83      |
# |    reward             | 0.27325055 |
# |    std                | 1.02       |
# |    value_loss         | 9.59       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 328        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | 0.069      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -1.01      |
# |    reward             | -1.1399637 |
# |    std                | 1.02       |
# |    value_loss         | 0.42       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.0305   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -8.71    |
# |    reward             | 2.182857 |
# |    std                | 1.03     |
# |    value_loss         | 14.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 400       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | -0.172    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -4.06     |
# |    reward             | 1.1184176 |
# |    std                | 1.02      |
# |    value_loss         | 4.49      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 153        |
# |    iterations         | 500        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 0.00221    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 13.9       |
# |    reward             | -2.3400857 |
# |    std                | 1.02       |
# |    value_loss         | 38.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 600        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 0.0131     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 9.01       |
# |    reward             | -10.386308 |
# |    std                | 1.02       |
# |    value_loss         | 40.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 183        |
# |    iterations         | 700        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 2.42       |
# |    reward             | 0.29517728 |
# |    std                | 1.01       |
# |    value_loss         | 1.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 800        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -0.0134    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -5.86      |
# |    reward             | -0.6845618 |
# |    std                | 1.01       |
# |    value_loss         | 6.1        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 205         |
# |    iterations         | 900         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | 0.0464      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 1.46        |
# |    reward             | -0.16983733 |
# |    std                | 1.01        |
# |    value_loss         | 4.07        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0.002     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -4.17     |
# |    reward             | 4.2111287 |
# |    std                | 1.01      |
# |    value_loss         | 11.8      |
# -------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  -0.118013138546663
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_25
# -----------------------------------
# | time/              |            |
# |    fps             | 375        |
# |    iterations      | 1          |
# |    time_elapsed    | 5          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.07566924 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 227          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0032926127 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00356     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00127     |
# |    reward               | 0.09771525   |
# |    std                  | 0.999        |
# |    value_loss           | 0.0688       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.001775725 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.34        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00111    |
# |    reward               | -0.25511038 |
# |    std                  | 0.994       |
# |    value_loss           | 2.61        |
# -----------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  0.029145700364360337
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_25
# day: 3085, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 8924060.35
# total_reward: 7924060.35
# total_cost: 1085.58
# total_trades: 6164
# Sharpe: 0.868
# =================================
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2009-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  21.04995814733224
# ======Model training from:  2009-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_24
# ------------------------------------
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0816  |
# |    reward             | 0.0      |
# |    std                | 1.08     |
# |    value_loss         | 0.00184  |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 300        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -3         |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.152      |
# |    reward             | -0.2782237 |
# |    std                | 1.09       |
# |    value_loss         | 0.0262     |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -5.53     |
# |    reward             | 0.9989066 |
# |    std                | 1.08      |
# |    value_loss         | 3.14      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 220       |
# |    iterations         | 400       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 0.0206    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -3.51     |
# |    reward             | 0.8667086 |
# |    std                | 1.09      |
# |    value_loss         | 2.45      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 500      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | -0.0565  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 17.4     |
# |    reward             | -2.21692 |
# |    std                | 1.08     |
# |    value_loss         | 38.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 171      |
# |    iterations         | 600      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.0112   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -7.37    |
# |    reward             | -12.7547 |
# |    std                | 1.08     |
# |    value_loss         | 80       |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 700        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -3.02      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -4.97      |
# |    reward             | -0.5337422 |
# |    std                | 1.1        |
# |    value_loss         | 2.34       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 200          |
# |    iterations         | 800          |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -3.02        |
# |    explained_variance | -0.134       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 14.1         |
# |    reward             | -0.024452943 |
# |    std                | 1.1          |
# |    value_loss         | 21.7         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 900       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -6.27     |
# |    reward             | 1.2004405 |
# |    std                | 1.1       |
# |    value_loss         | 4.54      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 1000       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -3.03      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 5.78       |
# |    reward             | -0.9063483 |
# |    std                | 1.1        |
# |    value_loss         | 9.44       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.20302383614909586
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_24
# -----------------------------------
# | time/              |            |
# |    fps             | 531        |
# |    iterations      | 1          |
# |    time_elapsed    | 3          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.36052018 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0026812567 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.128        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00108     |
# |    reward               | 0.06553142   |
# |    std                  | 1            |
# |    value_loss           | 0.355        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037511191 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.35         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0014      |
# |    reward               | 2.3179722    |
# |    std                  | 0.998        |
# |    value_loss           | 2.31         |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.20510442714710478
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_24
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 10637804.55
# total_reward: 9637804.55
# total_cost: 2605.74
# total_trades: 3798
# Sharpe: 0.864
# =================================
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  15.125634360313416  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO   0.275414   0.351594    0.244293
# 1  189  2021-04-06  2021-07-06        A2C   0.371325   0.294132    0.204347
# 2  252  2021-07-06  2021-10-04        PPO  -0.118013   0.029146   -0.150319
# 3  315  2021-10-04  2022-01-03       DDPG  -0.203024   0.205104    0.293642

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.8475740524726617

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.998185e+05  2021-04-07     -0.000181  2021-04-07
# 2   1.000073e+06  2021-04-08      0.000255  2021-04-08
# 3   1.000396e+06  2021-04-09      0.000323  2021-04-09
# 4   1.000348e+06  2021-04-12     -0.000048  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.169624
# Cumulative returns    -0.169624
# Annual volatility      0.197175
# Sharpe ratio          -0.847574
# Calmar ratio          -0.536552
# Stability              0.352224
# Max drawdown          -0.316137
# Omega ratio            0.853846
# Sortino ratio         -1.097654
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.689508
# Daily value at risk   -0.025505
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-16.962%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-16.962%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.718%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.54</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.614%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.10</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.55%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.23</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.84</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.61</td>
#       <td>2021-09-03</td>
#       <td>2022-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.98</td>
#       <td>2021-08-03</td>
#       <td>2021-08-10</td>
#       <td>2021-08-19</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.92</td>
#       <td>2021-08-30</td>
#       <td>2021-09-01</td>
#       <td>2021-09-02</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.84</td>
#       <td>2021-07-23</td>
#       <td>2021-07-28</td>
#       <td>2021-07-29</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.78</td>
#       <td>2021-06-11</td>
#       <td>2021-06-18</td>
#       <td>2021-06-28</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.07%</td>
#       <td>-4.47%</td>
#       <td>5.74%</td>
#     </tr>
#   </tbody>
# </table>
