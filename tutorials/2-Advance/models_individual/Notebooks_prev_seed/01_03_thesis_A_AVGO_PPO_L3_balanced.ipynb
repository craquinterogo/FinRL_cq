# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['A','AVGO']
print(DOW_30_TICKER)
# Out:
# ['A', 'AVGO']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26  531.539978  554.570007  527.719971  541.591003  3974300
# 6122  2022-05-27  124.919998  130.770004  124.489998  130.094025  2698800
# 6123  2022-05-27  562.090027  585.460022  560.010010  573.673828  3730100
# 6124  2022-05-31  128.910004  130.070007  126.720001  127.114464  3403100
# 6125  2022-05-31  584.500000  587.030029  576.000000  570.575684  3000900
#
#        tic  day
# 6121  AVGO    3
# 6122     A    4
# 6123  AVGO    4
# 6124     A    1
# 6125  AVGO    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  24.706724  24.942776  24.499285  22.442751  3105098     A    3
# 1  2010-04-01  20.690001  20.799999  20.090000  15.229786   324600  AVGO    3
# 2  2010-04-05  24.742489  24.921316  24.706724  22.618128  3731961     A    0
# 3  2010-04-05  20.690001  20.700001  19.790001  15.051489   612000  AVGO    0
# 4  2010-04-06  24.778255  24.814020  24.620888  22.449244  3499054     A    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 10_000,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 100_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  18.962614678896227
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 10000, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# ------------------------------------
# | time/              |             |
# |    fps             | 422         |
# |    iterations      | 1           |
# |    time_elapsed    | 23          |
# |    total_timesteps | 10000       |
# | train/             |             |
# |    reward          | 0.034518052 |
# ------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -39750.54
# total_reward: -49750.54
# total_cost: 357.56
# total_trades: 2772
# Sharpe: -0.073
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 416           |
# |    iterations           | 2             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 20000         |
# | train/                  |               |
# |    approx_kl            | 0.0037417933  |
# |    clip_fraction        | 0.0101        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0193       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000334     |
# |    reward               | -0.0023960252 |
# |    std                  | 1             |
# |    value_loss           | 0.00747       |
# -------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -14981.84
# total_reward: -24981.84
# total_cost: 357.02
# total_trades: 2666
# Sharpe: -0.452
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 3           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.003789512 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0263      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00145    |
# |    reward               | 0.010005018 |
# |    std                  | 1.01        |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 4            |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0022390864 |
# |    clip_fraction        | 0.00925      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0394      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000906    |
# |    reward               | -0.003764814 |
# |    std                  | 0.998        |
# |    value_loss           | 0.00722      |
# ------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -72113.46
# total_reward: -82113.46
# total_cost: 361.27
# total_trades: 2724
# Sharpe: -0.315
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 5            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0015701049 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0152      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -1.98e-05    |
# |    reward               | -0.025133962 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0232       |
# ------------------------------------------
# day: 2707, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: -77298.41
# total_reward: -87298.41
# total_cost: 383.51
# total_trades: 2752
# Sharpe: -0.307
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 6             |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 0.0027743736  |
# |    clip_fraction        | 0.0141        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.018        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000573     |
# |    reward               | -0.0049952166 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0421        |
# -------------------------------------------
# day: 2707, episode: 25
# begin_total_asset: 10000.00
# end_total_asset: -66326.38
# total_reward: -76326.38
# total_cost: 351.90
# total_trades: 2664
# Sharpe: -0.318
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 7            |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0026924466 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00211     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000869    |
# |    reward               | 0.09690065   |
# |    std                  | 1.02         |
# |    value_loss           | 0.051        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 8            |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 0.0027214366 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0177      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000496    |
# |    reward               | -0.045160893 |
# |    std                  | 1.05         |
# |    value_loss           | 0.0327       |
# ------------------------------------------
# day: 2707, episode: 30
# begin_total_asset: 10000.00
# end_total_asset: -66473.97
# total_reward: -76473.97
# total_cost: 364.48
# total_trades: 2684
# Sharpe: -0.334
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 9            |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 90000        |
# | train/                  |              |
# |    approx_kl            | 0.0032612062 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0137      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000567    |
# |    reward               | 0.004761484  |
# |    std                  | 1.04         |
# |    value_loss           | 0.0187       |
# ------------------------------------------
# day: 2707, episode: 35
# begin_total_asset: 10000.00
# end_total_asset: -26483.59
# total_reward: -36483.59
# total_cost: 356.34
# total_trades: 2708
# Sharpe: 0.218
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 10           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 100000       |
# | train/                  |              |
# |    approx_kl            | 0.004403742  |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0169      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00195     |
# |    reward               | -0.102191225 |
# |    std                  | 1.05         |
# |    value_loss           | 0.0294       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# PPO Sharpe Ratio:  -0.08585895702539814
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.00000000e+04 1.29873474e+02 4.62661011e+02 0.00000000e+00
#   0.00000000e+00 1.74376833e+00 4.68947411e+00 1.28886871e+02
#   4.73304657e+02 1.16377350e+02 4.16861572e+02 6.06303787e+01
#   5.49654160e+01 2.25215042e+02 1.10210159e+02 3.74220161e+01
#   6.06779385e+00 1.21544266e+02 4.43080963e+02 1.22726051e+02
#   4.42397888e+02]]
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# ============================================
# turbulence_threshold:  18.962614678896227
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 10000, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 488          |
# |    iterations      | 1            |
# |    time_elapsed    | 20           |
# |    total_timesteps | 10000        |
# | train/             |              |
# |    reward          | 0.0091629615 |
# -------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -22692.89
# total_reward: -32692.89
# total_cost: 412.70
# total_trades: 2720
# Sharpe: 0.640
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 2            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0028231626 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0146       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000912    |
# |    reward               | -0.005373086 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00806      |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -38603.40
# total_reward: -48603.40
# total_cost: 396.82
# total_trades: 2834
# Sharpe: 0.576
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 3            |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 30000        |
# | train/                  |              |
# |    approx_kl            | 0.0030844284 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.185       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.023       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000406    |
# |    reward               | 0.0070800274 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00519      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 4            |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0039696763 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -0.0148      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0519      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00105     |
# |    reward               | 0.014531952  |
# |    std                  | 1.04         |
# |    value_loss           | 0.00854      |
# ------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -15703.88
# total_reward: -25703.88
# total_cost: 385.78
# total_trades: 2788
# Sharpe: -0.263
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 5            |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.001318842  |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -0.000144    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0428      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | -0.022704305 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00988      |
# ------------------------------------------
# day: 2770, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: -19272.01
# total_reward: -29272.01
# total_cost: 388.90
# total_trades: 2818
# Sharpe: -0.338
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 6            |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 60000        |
# | train/                  |              |
# |    approx_kl            | 0.0019752667 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.0143       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0309      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000667    |
# |    reward               | 0.008105973  |
# |    std                  | 1.07         |
# |    value_loss           | 0.01         |
# ------------------------------------------
# day: 2770, episode: 25
# begin_total_asset: 10000.00
# end_total_asset: -62542.06
# total_reward: -72542.06
# total_cost: 396.17
# total_trades: 2852
# Sharpe: -0.570
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 7            |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0044574826 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.0138       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00888     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00126     |
# |    reward               | -0.008760338 |
# |    std                  | 1.07         |
# |    value_loss           | 0.00889      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 8             |
# |    time_elapsed         | 183           |
# |    total_timesteps      | 80000         |
# | train/                  |               |
# |    approx_kl            | 0.0031756016  |
# |    clip_fraction        | 0.00535       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.98         |
# |    explained_variance   | 2.57e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0294       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000466     |
# |    reward               | -0.0038831383 |
# |    std                  | 1.07          |
# |    value_loss           | 0.0157        |
# -------------------------------------------
# day: 2770, episode: 30
# begin_total_asset: 10000.00
# end_total_asset: -49661.49
# total_reward: -59661.49
# total_cost: 375.84
# total_trades: 2714
# Sharpe: 0.212
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 9            |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 90000        |
# | train/                  |              |
# |    approx_kl            | 0.0029203373 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0196      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00049     |
# |    reward               | -0.013446167 |
# |    std                  | 1.07         |
# |    value_loss           | 0.00743      |
# ------------------------------------------
# day: 2770, episode: 35
# begin_total_asset: 10000.00
# end_total_asset: -19918.14
# total_reward: -29918.14
# total_cost: 400.81
# total_trades: 2790
# Sharpe: -0.398
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 10           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 100000       |
# | train/                  |              |
# |    approx_kl            | 0.0014323592 |
# |    clip_fraction        | 0.0057       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.042       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000306    |
# |    reward               | -0.01147351  |
# |    std                  | 1.09         |
# |    value_loss           | 0.00859      |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# PPO Sharpe Ratio:  -0.3152267737644463
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.7117615e+04  1.4784785e+02  4.5607751e+02 -2.4000000e+01
#   -9.0000000e+00  3.1223810e+00  3.5969939e+00  1.5008386e+02
#    4.6046967e+02  1.3879758e+02  4.4025177e+02  6.6720131e+01
#    5.3663353e+01  9.5907684e+01  8.8637436e+01  3.7719433e+01
#    1.6090811e+01  1.4126389e+02  4.4891983e+02  1.3640550e+02
#    4.4209937e+02]]
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# ============================================
# turbulence_threshold:  18.962614678896227
# ======Model training from:  2010-04-01 to  2021-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 10000, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_1
# ------------------------------------
# | time/              |             |
# |    fps             | 481         |
# |    iterations      | 1           |
# |    time_elapsed    | 20          |
# |    total_timesteps | 10000       |
# | train/             |             |
# |    reward          | 0.009835004 |
# ------------------------------------
# day: 2833, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -50070.12
# total_reward: -60070.12
# total_cost: 417.89
# total_trades: 2818
# Sharpe: 0.228
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 452           |
# |    iterations           | 2             |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 20000         |
# | train/                  |               |
# |    approx_kl            | 0.0017210522  |
# |    clip_fraction        | 0.012         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -0.0942       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0391       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -6.1e-05      |
# |    reward               | -0.0033748546 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00473       |
# -------------------------------------------
# day: 2833, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -76394.39
# total_reward: -86394.39
# total_cost: 421.50
# total_trades: 2898
# Sharpe: 0.391
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 444          |
# |    iterations           | 3            |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 30000        |
# | train/                  |              |
# |    approx_kl            | 0.0019252616 |
# |    clip_fraction        | 0.00852      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.022        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0315      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000167    |
# |    reward               | -0.04213717  |
# |    std                  | 1.01         |
# |    value_loss           | 0.0189       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 4            |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0017895711 |
# |    clip_fraction        | 0.00568      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -4.46e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0101      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000119    |
# |    reward               | 0.0093636345 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0275       |
# ------------------------------------------
# day: 2833, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -33688.49
# total_reward: -43688.49
# total_cost: 416.09
# total_trades: 2852
# Sharpe: 0.565
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 5            |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0018818416 |
# |    clip_fraction        | 0.00451      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.000161     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0154      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000301    |
# |    reward               | 0.024980705  |
# |    std                  | 1.01         |
# |    value_loss           | 0.0199       |
# ------------------------------------------
# day: 2833, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: -24005.81
# total_reward: -34005.81
# total_cost: 402.31
# total_trades: 2764
# Sharpe: -0.100
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# ...
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0229       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000219     |
# |    reward               | -0.0024569822 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0124        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 7            |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.004628694  |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 6.76e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0639      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00169     |
# |    reward               | 0.0004348524 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00936      |
# ------------------------------------------
# day: 2896, episode: 25
# begin_total_asset: 10000.00
# end_total_asset: -25761.37
# total_reward: -35761.37
# total_cost: 446.75
# total_trades: 2798
# Sharpe: 0.396
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 327           |
# |    iterations           | 8             |
# |    time_elapsed         | 244           |
# |    total_timesteps      | 80000         |
# | train/                  |               |
# |    approx_kl            | 0.002417314   |
# |    clip_fraction        | 0.0102        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.000131      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0151       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.0007       |
# |    reward               | -0.0010119079 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0211        |
# -------------------------------------------
# day: 2896, episode: 30
# begin_total_asset: 10000.00
# end_total_asset: -26715.16
# total_reward: -36715.16
# total_cost: 438.64
# total_trades: 2764
# Sharpe: 0.120
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 9            |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 90000        |
# | train/                  |              |
# |    approx_kl            | 0.0020757327 |
# |    clip_fraction        | 0.00989      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 3.04e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0423      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000452    |
# |    reward               | 0.0010427266 |
# |    std                  | 1.04         |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 10           |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 100000       |
# | train/                  |              |
# |    approx_kl            | 0.0035037783 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 3.97e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0139      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000582    |
# |    reward               | 0.031234618  |
# |    std                  | 1.04         |
# |    value_loss           | 0.0158       |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# PPO Sharpe Ratio:  0.16084071611637793
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.9394193e+04  1.5568901e+02  6.4801355e+02 -2.8000000e+01
#   -1.1000000e+01  9.6467811e-01  2.7344007e+01  1.6118152e+02
#    6.8647925e+02  1.4802783e+02  5.5121216e+02  4.9942398e+01
#    6.7751984e+01  3.0670855e+01  9.1102592e+01  4.2563453e+00
#    5.3900658e+01  1.5406818e+02  5.9265698e+02  1.5493849e+02
#    5.5401251e+02]]
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# TYPE POLICY PREDICTING : 	 <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# Ensemble Strategy took:  18.640738888581595  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0  -0.085859           0
# 1  189  2021-04-06  2021-07-06        PPO          0  -0.315227           0
# 2  252  2021-07-06  2021-10-04        PPO          0   -0.11408           0
# 3  315  2021-10-04  2022-01-03        PPO          0   0.160841           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.40113614854327934

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10008.164926  2021-04-07      0.000816  2021-04-07
# 2   10001.686685  2021-04-08     -0.000647  2021-04-08
# 3    9992.849588  2021-04-09     -0.000884  2021-04-09
# 4    9995.931879  2021-04-12      0.000308  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.111239
# Cumulative returns    -0.111239
# Annual volatility      0.229710
# Sharpe ratio          -0.401136
# Calmar ratio          -0.450276
# Stability              0.315057
# Max drawdown          -0.247045
# Omega ratio            0.932043
# Sortino ratio         -0.583570
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.199999
# Daily value at risk   -0.029306
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-11.124%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-11.124%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.971%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.40</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.45</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.705%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.58</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.931%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-1.20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.70</td>
#       <td>2021-05-18</td>
#       <td>2021-12-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>2021-04-20</td>
#       <td>2021-04-26</td>
#       <td>2021-05-04</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.94</td>
#       <td>2021-05-04</td>
#       <td>2021-05-07</td>
#       <td>2021-05-10</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.89</td>
#       <td>2021-05-12</td>
#       <td>2021-05-14</td>
#       <td>2021-05-18</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.26</td>
#       <td>2021-04-07</td>
#       <td>2021-04-13</td>
#       <td>2021-04-19</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.04%</td>
#       <td>-4.92%</td>
#       <td>4.78%</td>
#     </tr>
#   </tbody>
# </table>
