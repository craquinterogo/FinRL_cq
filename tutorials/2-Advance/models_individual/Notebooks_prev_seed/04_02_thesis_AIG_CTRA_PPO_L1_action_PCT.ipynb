# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AIG','CTRA']
print(DOW_30_TICKER)
# Out:
# ['AIG', 'CTRA']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high        low      close    volume   tic  \
# 6121  2022-05-26  34.340000  35.779999  34.220001  33.063053  11206100  CTRA
# 6122  2022-05-27  57.849998  59.000000  57.630001  57.997391   3891100   AIG
# 6123  2022-05-27  34.250000  35.529999  34.200001  33.893208   8413700  CTRA
# 6124  2022-05-31  58.650002  59.759998  58.169998  57.682827   5639200   AIG
# 6125  2022-05-31  36.060001  36.450001  34.130001  32.757710  22122700  CTRA
#
#       day
# 6121    3
# 6122    4
# 6123    4
# 6124    1
# 6125    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume   tic  day
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921478   6250200   AIG    3
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570669   4922000  CTRA    3
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559858  16281300   AIG    0
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793337   4937200  CTRA    0
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131054  19971000   AIG    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
processed.head()
# Out:
#          date       open       high        low      close    volume   tic  \
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921478   6250200   AIG
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570669   4922000  CTRA
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559858  16281300   AIG
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793337   4937200  CTRA
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131054  19971000   AIG
#
#    day      macd    boll_ub    boll_lb  rsi_30      cci_30  dx_30  \
# 0    3  0.000000  24.143474  22.337863   100.0   66.666667  100.0
# 1    3  0.000000  24.143474  22.337863   100.0   66.666667  100.0
# 2    0  0.014323  24.143474  22.337863   100.0   66.666667  100.0
# 3    0  0.004996   7.996904   7.367103   100.0   66.666667  100.0
# 4    1  0.035963  24.747661  22.327266   100.0  100.000000  100.0
#
#    close_30_sma  close_60_sma  turbulence
# 0     22.921478     22.921478         0.0
# 1      7.570669      7.570669         0.0
# 2     23.240668     23.240668         0.0
# 3      7.682003      7.682003         0.0
# 4     23.537464     23.537464         0.0

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 50_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.344666027864296
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_2
# -------------------------------------
# | time/              |              |
# |    fps             | 309          |
# |    iterations      | 1            |
# |    time_elapsed    | 6            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.008905835 |
# -------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 325           |
# |    iterations           | 2             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00068988366 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -0.0601       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0266       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | 9.11e-05      |
# |    reward               | -0.0043760934 |
# |    std                  | 1             |
# |    value_loss           | 0.0179        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0022171056 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.345       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0211      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000575    |
# |    reward               | -0.16738279  |
# |    std                  | 0.999        |
# |    value_loss           | 0.00941      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 252           |
# |    iterations           | 4             |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00508729    |
# |    clip_fraction        | 0.0603        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -0.0281       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0228       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00427      |
# |    reward               | -0.0029803247 |
# |    std                  | 0.994         |
# |    value_loss           | 0.00494       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 5            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.004196804  |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.142       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0365      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00306     |
# |    reward               | -0.003931911 |
# |    std                  | 0.991        |
# |    value_loss           | 0.00414      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 270           |
# |    iterations           | 6             |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.0048028217  |
# |    clip_fraction        | 0.0291        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.0576        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0342       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00204      |
# |    reward               | -0.0139146345 |
# |    std                  | 0.985         |
# |    value_loss           | 0.00132       |
# -------------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -10859.85
# total_reward: -20859.85
# total_cost: 120.05
# total_trades: 5414
# Sharpe: 0.343
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 7            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0045035863 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0079      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000366    |
# |    reward               | 0.052749638  |
# |    std                  | 0.99         |
# |    value_loss           | 0.0225       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 8           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005708984 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | -0.187      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.027      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.003      |
# |    reward               | 0.015560463 |
# |    std                  | 0.984       |
# |    value_loss           | 0.00811     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 9            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0050239214 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | -0.0987      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0259      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00158     |
# |    reward               | 0.004884553  |
# |    std                  | 0.981        |
# |    value_loss           | 0.00271      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 10           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0037139542 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0287      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00243     |
# |    reward               | 0.017478608  |
# |    std                  | 0.976        |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 11           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031580655 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.296        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0334      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00242     |
# |    reward               | -0.00227065  |
# |    std                  | 0.972        |
# |    value_loss           | 0.00163      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 12           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0072041377 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0173      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00266     |
# |    reward               | -0.005158617 |
# |    std                  | 0.974        |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 329           |
# |    iterations           | 13            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.0060961843  |
# |    clip_fraction        | 0.0316        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.247         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0345       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00157      |
# |    reward               | -0.0036781745 |
# |    std                  | 0.978         |
# |    value_loss           | 0.00166       |
# -------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 110.03
# total_reward: -9889.97
# total_cost: 136.94
# total_trades: 5414
# Sharpe: 0.320
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 335           |
# |    iterations           | 14            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.0035583829  |
# |    clip_fraction        | 0.0171        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.487         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0383       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00215      |
# |    reward               | -0.0062443307 |
# |    std                  | 0.973         |
# |    value_loss           | 0.00131       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 15           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0019457666 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0279      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00202     |
# |    reward               | -0.02883921  |
# |    std                  | 0.967        |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 341           |
# |    iterations           | 16            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.005821045   |
# |    clip_fraction        | 0.0588        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0.303         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0177       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00201      |
# |    reward               | 0.00018625526 |
# |    std                  | 0.967         |
# |    value_loss           | 0.00305       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 17           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0074170763 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.011       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00112      |
# |    reward               | 0.0027006858 |
# |    std                  | 0.969        |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 18          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006970044 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0223     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0025     |
# |    reward               | 0.005611436 |
# |    std                  | 0.97        |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 19           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.005447862  |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0313      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00173     |
# |    reward               | 0.0076121916 |
# |    std                  | 0.973        |
# |    value_loss           | 0.00191      |
# ------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 390.30
# total_reward: -9609.70
# total_cost: 147.00
# total_trades: 5414
# Sharpe: -0.340
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 20           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0046900837 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0145      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00223      |
# |    reward               | 0.033150855  |
# |    std                  | 0.975        |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 21          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004700889 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0249     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00144    |
# |    reward               | 0.021011941 |
# |    std                  | 0.981       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 22           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.007290144  |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.466        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0337      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00159     |
# |    reward               | 0.0012296255 |
# |    std                  | 0.981        |
# |    value_loss           | 0.011        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 23           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0052263406 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0304      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00121     |
# |    reward               | 0.0013941383 |
# |    std                  | 0.983        |
# |    value_loss           | 0.00203      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 24           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0049155466 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0153      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00073      |
# |    reward               | -0.06885725  |
# |    std                  | 0.981        |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 365          |
# |    iterations           | 25           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0066424115 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0461      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00213     |
# |    reward               | 0.0016653892 |
# |    std                  | 0.985        |
# |    value_loss           | 0.0017       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.2434974618701292
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[ 1.0000000e+04  4.4805408e+01  1.6062769e+01  0.0000000e+00
#    0.0000000e+00  5.4846513e-01  5.2864827e-02  4.6732227e+01
#    1.6984121e+01  4.3252018e+01  1.5429833e+01  5.7691299e+01
#    5.0486069e+01  1.1617151e+01 -3.8270771e+01  7.4090924e+00
#    8.9696541e+00  4.4508801e+01  1.6239410e+01  4.1729580e+01
#    1.6083076e+01]]
# ============================================
# turbulence_threshold:  19.344666027864296
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_2
# -------------------------------------
# | time/              |              |
# |    fps             | 476          |
# |    iterations      | 1            |
# |    time_elapsed    | 4            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.015843457 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0018826212 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.0276      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0151      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000499    |
# |    reward               | 0.08006342   |
# |    std                  | 0.996        |
# |    value_loss           | 0.0373       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0041240747 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00586     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0238      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00293     |
# |    reward               | 0.02163729   |
# |    std                  | 0.991        |
# |    value_loss           | 0.0174       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 4            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.005526054  |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.0404      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0331      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00245     |
# |    reward               | -0.004626209 |
# |    std                  | 0.995        |
# |    value_loss           | 0.00618      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 5          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00148854 |
# |    clip_fraction        | 0.000342   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.83      |
# |    explained_variance   | -0.0273    |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0242    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.000504   |
# |    reward               | 0.0106379  |
# |    std                  | 1          |
# |    value_loss           | 0.0025     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0024596304 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00428      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0241      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0024      |
# |    reward               | -0.007828146 |
# |    std                  | 1            |
# |    value_loss           | 0.0127       |
# ------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -3110.86
# total_reward: -13110.86
# total_cost: 122.85
# total_trades: 5540
# Sharpe: -0.391
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 7            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047508143 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -1.57        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0244      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00513     |
# |    reward               | -0.004415315 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0139       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 8            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.004669447  |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.0501      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0318      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00353     |
# |    reward               | 0.0020754558 |
# |    std                  | 1            |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0027001775 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0287      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00045     |
# |    reward               | 0.0039055848 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00156      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 10           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0013908448 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0249      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000221    |
# |    reward               | 0.028178347  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00204      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 11          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005076147 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0372     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00164    |
# |    reward               | 0.04466437  |
# |    std                  | 1.03        |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 12           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0035621123 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -0.00208     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0284      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00204     |
# |    reward               | 0.005347078  |
# |    std                  | 1.04         |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 13           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051116226 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0229      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00349     |
# |    reward               | -0.017837739 |
# |    std                  | 1.04         |
# |    value_loss           | 0.0149       |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -1277.13
# total_reward: -11277.13
# total_cost: 156.11
# total_trades: 5540
# Sharpe: -0.248
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 14          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004295637 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0334     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00326    |
# |    reward               | -0.1357296  |
# |    std                  | 1.03        |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 15           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0037473408 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0152      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000977    |
# |    reward               | -0.028025402 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00882      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 16           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0011330565 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0239      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000321    |
# |    reward               | -0.00683329  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 17            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.0039325613  |
# |    clip_fraction        | 0.0274        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0193       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00202      |
# |    reward               | -0.0034900622 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00209       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 18            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.007207738   |
# |    clip_fraction        | 0.0695        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0365       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00594      |
# |    reward               | -0.0027944406 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00212       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 19           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0018054062 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0259      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000684    |
# |    reward               | -0.03727269  |
# |    std                  | 1            |
# |    value_loss           | 0.00175      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 20           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036657667 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0349      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00293     |
# |    reward               | -0.003705297 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -3627.56
# total_reward: -13627.56
# total_cost: 137.59
# total_trades: 5540
# Sharpe: -0.504
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 21           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.005151036  |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.00502     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0179      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00171     |
# |    reward               | -0.031650625 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00302      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 22            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.005407555   |
# |    clip_fraction        | 0.0325        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0233       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00301      |
# |    reward               | -0.0015711306 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00237       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 23           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043849004 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0288      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00234     |
# |    reward               | 0.014183958  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00249      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 24           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0037419433 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.00474     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0444      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00171     |
# |    reward               | -0.004371775 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 25           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0043700067 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0462      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | 0.0013598673 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.07231067073123668
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.68467832e+04  4.50344315e+01  1.48622675e+01 -7.29695129e+01
#   -2.33998245e+02 -8.47349644e-01  7.72209316e-02  5.13974648e+01
#    1.58006067e+01  4.36545029e+01  1.34798088e+01  4.45638351e+01
#    4.97791519e+01 -1.11025337e+02  9.52523727e+01  3.32284203e+01
#    5.63854551e+00  4.85274696e+01  1.46157284e+01  4.77497673e+01
#    1.47524805e+01]]
# ============================================
# turbulence_threshold:  19.344666027864296
# ======Model training from:  2010-04-01 to  2021-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_2
# -------------------------------------
# | time/              |              |
# |    fps             | 524          |
# |    iterations      | 1            |
# |    time_elapsed    | 3            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.007932859 |
# -------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 442            |
# |    iterations           | 2              |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.004103824    |
# |    clip_fraction        | 0.0206         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | 0.0152         |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0181        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00212       |
# |    reward               | -0.00012333757 |
# |    std                  | 1              |
# |    value_loss           | 0.0116         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 440          |
# |    iterations           | 3            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0075724754 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0405      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00554     |
# |    reward               | 0.0131682735 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00728      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003192354 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -0.139      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0236     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.000168    |
# |    reward               | 0.014305216 |
# ...
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0156      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00154     |
# |    reward               | 0.000694647  |
# |    std                  | 0.993        |
# |    value_loss           | 0.0122       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 9            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0031182421 |
# |    clip_fraction        | 0.00981      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0245      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.00019      |
# |    reward               | 0.0029120843 |
# |    std                  | 0.998        |
# |    value_loss           | 0.00199      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 10           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026908852 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00448     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0325      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000653    |
# |    reward               | -0.002467183 |
# |    std                  | 0.989        |
# |    value_loss           | 0.00274      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 11           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0028916264 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -0.0314      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0412      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000862    |
# |    reward               | -0.008268242 |
# |    std                  | 0.989        |
# |    value_loss           | 0.00152      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 12          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004675844 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0682      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0308     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00147    |
# |    reward               | 0.015114842 |
# |    std                  | 0.99        |
# |    value_loss           | 0.00307     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 13           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0048955968 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0239      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00114     |
# |    reward               | 0.0256288    |
# |    std                  | 0.994        |
# |    value_loss           | 0.0111       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 14          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006170928 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0282     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00538    |
# |    reward               | -0.03216372 |
# |    std                  | 0.989       |
# |    value_loss           | 0.00696     |
# -----------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -9948.05
# total_reward: -19948.05
# total_cost: 213.27
# total_trades: 5792
# Sharpe: -0.300
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 15           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0033065798 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0342      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0038      |
# |    reward               | -0.009525061 |
# |    std                  | 0.988        |
# |    value_loss           | 0.0131       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 16          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002539959 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.028      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000931   |
# |    reward               | 0.011296679 |
# |    std                  | 0.982       |
# |    value_loss           | 0.00472     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 17           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0024555847 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0224      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000606    |
# |    reward               | 0.002338204  |
# |    std                  | 0.981        |
# |    value_loss           | 0.00394      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 18          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.003278927 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.0644      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0233     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00236    |
# |    reward               | 0.003789082 |
# |    std                  | 0.986       |
# |    value_loss           | 0.00384     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 19           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0058091427 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0989       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0355      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00413     |
# |    reward               | 0.006025448  |
# |    std                  | 0.989        |
# |    value_loss           | 0.00133      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 20          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004166904 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0196     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00221    |
# |    reward               | -0.04535322 |
# |    std                  | 0.995       |
# |    value_loss           | 0.00307     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 21           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.005296422  |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0247      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00218     |
# |    reward               | 0.0036947725 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00156      |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -4242.50
# total_reward: -14242.50
# total_cost: 201.15
# total_trades: 5792
# Sharpe: 0.182
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 22           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0060731187 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0353      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00337     |
# |    reward               | 0.0054831696 |
# |    std                  | 1            |
# |    value_loss           | 0.00157      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 23          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005007183 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0282     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000707   |
# |    reward               | 0.002144606 |
# |    std                  | 0.997       |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 24           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0047643366 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0241      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00374     |
# |    reward               | -0.010589985 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 25           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.002319133  |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.422        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0225      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000843    |
# |    reward               | 0.0014540824 |
# |    std                  | 1            |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.17332000684440832
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.6700559e+04  5.6106419e+01  1.7893314e+01 -6.7563850e+01
#   -2.6932001e+02  3.6457905e-01 -2.4918348e-01  5.6597851e+01
#    1.9178034e+01  5.1466885e+01  1.7312626e+01  5.4033581e+01
#    4.8056076e+01  1.1924813e+02 -1.1977670e+02  1.8484997e+01
#    2.1615852e+01  5.3881409e+01  1.8416004e+01  5.5446522e+01
#    1.8800699e+01]]
# Ensemble Strategy took:  8.674047060807546  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0  -0.243497           0
# 1  189  2021-04-06  2021-07-06        PPO          0  -0.072311           0
# 2  252  2021-07-06  2021-10-04        PPO          0  -0.359038           0
# 3  315  2021-10-04  2022-01-03        PPO          0    0.17332           0

# %%
len(ensemble_agent.crk_model)
# Out:
# 4

# %%
ensemble_agent.crk_model[0].policy.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict([('log_std',
#                Parameter containing:
#                tensor([ 0.0306, -0.0710], requires_grad=True))]),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('features_extractor',
#                FlattenExtractor(
#                  (flatten): Flatten(start_dim=1, end_dim=-1)
#                )),
#               ('mlp_extractor',
#                MlpExtractor(
#                  (shared_net): Sequential()
#                  (policy_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                  (value_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                )),
#               ('action_net',
#                Linear(in_features=64, out_features=2, bias=True)),
#               ('value_net',
#                Linear(in_features=64, out_features=1, bias=True))]),
#  'observation_space': Box([-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#   inf inf inf], (21,), float32),
#  'action_space': Box([-1. -1.], [1. 1.], (2,), float32),
#  'normalize_images': True,
#  'optimizer_class': torch.optim.adam.Adam,
#  'optimizer_kwargs': {'eps': 1e-05},
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      eps: 1e-05
#      foreach: None
#      lr: 0.00025
#      maximize: False
#      weight_decay: 0
#  ),
#  'features_extractor_class': stable_baselines3.common.torch_layers.FlattenExtractor,
#  'features_extractor_kwargs': {},
#  '_squash_output': False,
#  'net_arch': [{'pi': [64, 64], 'vf': [64, 64]}],
#  'activation_fn': torch.nn.modules.activation.Tanh,
#  'ortho_init': True,
#  'features_dim': 21,
#  'log_std_init': 0.0,
#  'use_sde': False,
#  'dist_kwargs': None,
#  'action_dist': <stable_baselines3.common.distributions.DiagGaussianDistribution at 0x17c664b9fa0>}

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.5335289535188121

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1    9987.702707  2021-04-07     -0.001230  2021-04-07
# 2   10094.683663  2021-04-08      0.010711  2021-04-08
# 3   10133.290442  2021-04-09      0.003824  2021-04-09
# 4   10152.459403  2021-04-12      0.001892  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.425128
# Cumulative returns    -0.425128
# Annual volatility      0.327060
# Sharpe ratio          -1.533529
# Calmar ratio          -0.858038
# Stability              0.840589
# Max drawdown          -0.495465
# Omega ratio            0.764982
# Sortino ratio         -1.971643
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.844413
# Daily value at risk   -0.043196
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-42.513%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-42.513%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>32.706%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.53</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.86</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-49.546%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.76</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.97</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.32%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.34</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.75</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>49.55</td>
#       <td>2021-07-19</td>
#       <td>2022-03-25</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.91</td>
#       <td>2021-04-20</td>
#       <td>2021-05-17</td>
#       <td>2021-06-18</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.95</td>
#       <td>2021-06-18</td>
#       <td>2021-07-01</td>
#       <td>2021-07-19</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.01</td>
#       <td>2021-04-13</td>
#       <td>2021-04-14</td>
#       <td>2021-04-16</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.12</td>
#       <td>2021-04-06</td>
#       <td>2021-04-07</td>
#       <td>2021-04-08</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.20%</td>
#       <td>-9.01%</td>
#       <td>8.82%</td>
#     </tr>
#   </tbody>
# </table>
