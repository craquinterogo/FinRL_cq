# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['ACN','NDAQ']
print(DOW_30_TICKER)
# Out:
# ['ACN', 'NDAQ']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# ACN     3063
# NDAQ    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26   49.403332   50.516666   49.169998   49.806362  2370600
# 6122  2022-05-27  293.440002  304.170013  293.440002  301.730194  2759000
# 6123  2022-05-27   50.840000   51.896667   50.393333   51.360649  2790000
# 6124  2022-05-31  302.399994  303.320007  296.700012  296.085480  4143700
# 6125  2022-05-31   51.430000   52.123333   51.326668   51.235245  4908600
#
#        tic  day
# 6121  NDAQ    3
# 6122   ACN    4
# 6123  NDAQ    4
# 6124   ACN    1
# 6125  NDAQ    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  42.169998  42.650002  41.650002  32.790665  3622700   ACN    3
# 1  2010-04-01   7.096667   7.116667   7.000000   5.911549  6013500  NDAQ    3
# 2  2010-04-05  41.820000  42.169998  41.610001  32.884712  2561300   ACN    0
# 3  2010-04-05   7.090000   7.223333   7.070000   6.040120  7216500  NDAQ    0
# 4  2010-04-06  42.020000  42.310001  41.450001  32.539867  5802000   ACN    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# ACN     3063
# NDAQ    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# ACN     3063
# NDAQ    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 15_000, 
                 'ppo' : 0, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 None,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  23.580968401549146
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_2
# ----------------------------------------
# | time/                 |              |
# |    fps                | 132          |
# |    iterations         | 100          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.96        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.000191    |
# |    reward             | -0.011017805 |
# |    std                | 1.06         |
# |    value_loss         | 3.8e-05      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 193         |
# |    iterations         | 200         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -3.02       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.0286     |
# |    reward             | 0.019051507 |
# |    std                | 1.1         |
# |    value_loss         | 0.000498    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 231          |
# |    iterations         | 300          |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -3.07        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | -0.053       |
# |    reward             | -0.037865944 |
# |    std                | 1.13         |
# |    value_loss         | 0.000582     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 256          |
# |    iterations         | 400          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -3.1         |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.383        |
# |    reward             | -0.032841377 |
# |    std                | 1.14         |
# |    value_loss         | 0.0145       |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.11    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.516    |
# |    reward             | 0.427231 |
# |    std                | 1.15     |
# |    value_loss         | 0.071    |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 285           |
# |    iterations         | 600           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -3.13         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.0129       |
# |    reward             | -0.0012251411 |
# |    std                | 1.16          |
# |    value_loss         | 1.39e-05      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 295         |
# |    iterations         | 700         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -3.16       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.027      |
# |    reward             | 0.002257035 |
# |    std                | 1.18        |
# |    value_loss         | 6.33e-05    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 302          |
# |    iterations         | 800          |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -3.21        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | -0.0322      |
# |    reward             | 0.0048799324 |
# |    std                | 1.2          |
# |    value_loss         | 0.000186     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 307           |
# |    iterations         | 900           |
# |    time_elapsed       | 14            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -3.27         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 0.0423        |
# |    reward             | -0.0070654005 |
# |    std                | 1.24          |
# |    value_loss         | 0.000221      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 312          |
# |    iterations         | 1000         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.31        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.0167       |
# |    reward             | -0.019785848 |
# |    std                | 1.27         |
# |    value_loss         | 0.000211     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 315           |
# |    iterations         | 1100          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -3.35         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.0223       |
# |    reward             | -0.0061133825 |
# |    std                | 1.29          |
# |    value_loss         | 8.16e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 319           |
# |    iterations         | 1200          |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -3.4          |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | -0.028        |
# |    reward             | -0.0041563343 |
# |    std                | 1.33          |
# |    value_loss         | 7.7e-05       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 323           |
# |    iterations         | 1300          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -3.45         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -0.0177       |
# |    reward             | 0.00032662277 |
# |    std                | 1.36          |
# |    value_loss         | 1.91e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 326           |
# |    iterations         | 1400          |
# |    time_elapsed       | 21            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -3.52         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | -0.046        |
# |    reward             | 0.00052491954 |
# |    std                | 1.41          |
# |    value_loss         | 0.00028       |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 329         |
# |    iterations         | 1500        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -3.58       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | 0.0286      |
# |    reward             | -0.02964176 |
# |    std                | 1.45        |
# |    value_loss         | 0.000188    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 331          |
# |    iterations         | 1600         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -3.64        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.169       |
# |    reward             | -0.026116554 |
# |    std                | 1.49         |
# |    value_loss         | 0.00224      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 332          |
# |    iterations         | 1700         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -3.66        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | -0.0355      |
# |    reward             | -0.010944631 |
# |    std                | 1.51         |
# |    value_loss         | 0.000277     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 333          |
# |    iterations         | 1800         |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -3.7         |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | -0.0374      |
# |    reward             | 0.0053179665 |
# |    std                | 1.54         |
# |    value_loss         | 8.97e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 334          |
# |    iterations         | 1900         |
# |    time_elapsed       | 28           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -3.76        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | -0.0258      |
# |    reward             | 0.0059428834 |
# |    std                | 1.59         |
# |    value_loss         | 9.08e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 335         |
# |    iterations         | 2000        |
# |    time_elapsed       | 29          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.83       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.0181      |
# |    reward             | 0.005639996 |
# |    std                | 1.64        |
# |    value_loss         | 4.21e-05    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 336        |
# |    iterations         | 2100       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -3.9       |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 0.0189     |
# |    reward             | 0.04822709 |
# |    std                | 1.7        |
# |    value_loss         | 5.84e-05   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 338         |
# |    iterations         | 2200        |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -3.96       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | 0.025       |
# |    reward             | 0.011350193 |
# |    std                | 1.75        |
# |    value_loss         | 4.72e-05    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 338         |
# |    iterations         | 2300        |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -4.01       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | -0.0322     |
# |    reward             | 0.007550625 |
# |    std                | 1.8         |
# |    value_loss         | 0.000155    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 337         |
# |    iterations         | 2400        |
# |    time_elapsed       | 35          |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -4.05       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2399        |
# |    policy_loss        | -0.00518    |
# |    reward             | 0.002558765 |
# |    std                | 1.83        |
# |    value_loss         | 8.22e-06    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 338        |
# |    iterations         | 2500       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -4.09      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -0.0901    |
# |    reward             | 0.02317442 |
# |    std                | 1.88       |
# |    value_loss         | 0.000562   |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 339          |
# |    iterations         | 2600         |
# |    time_elapsed       | 38           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -4.16        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | -0.167       |
# |    reward             | -0.009455577 |
# |    std                | 1.94         |
# |    value_loss         | 0.00223      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 341         |
# |    iterations         | 2700        |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -4.18       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | 0.523       |
# |    reward             | -0.09141996 |
# |    std                | 1.96        |
# |    value_loss         | 0.022       |
# ---------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -15461.08
# total_reward: -25461.08
# total_cost: 303.44
# total_trades: 2554
# Sharpe: 0.329
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 342          |
# |    iterations         | 2800         |
# |    time_elapsed       | 40           |
# |    total_timesteps    | 14000        |
# | train/                |              |
# |    entropy_loss       | -4.21        |
# |    explained_variance | 2.38e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2799         |
# |    policy_loss        | -0.0551      |
# |    reward             | 0.0018631612 |
# |    std                | 1.99         |
# |    value_loss         | 0.00019      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 343         |
# |    iterations         | 2900        |
# |    time_elapsed       | 42          |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -4.26       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | -0.0194     |
# |    reward             | 0.024544833 |
# |    std                | 2.03        |
# |    value_loss         | 9.88e-05    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 345         |
# |    iterations         | 3000        |
# |    time_elapsed       | 43          |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -4.29       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | -0.0375     |
# |    reward             | 0.030929733 |
# |    std                | 2.07        |
# |    value_loss         | 0.000366    |
# ---------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  -0.15472668956527083
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.0000000e+04 2.7538513e+02 4.9783970e+01 0.0000000e+00 0.0000000e+00
#   6.0808344e+00 7.8874612e-01 2.7960818e+02 4.9821030e+01 2.4755247e+02
#   4.6236755e+01 6.2531033e+01 6.1703228e+01 1.4572672e+02 1.5516148e+02
#   4.8110012e+01 3.1571991e+01 2.5843158e+02 4.7271191e+01 2.5370239e+02
#   4.6681297e+01]]
# ============================================
# turbulence_threshold:  23.580968401549146
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_2
# ----------------------------------------
# | time/                 |              |
# |    fps                | 373          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.00485     |
# |    reward             | -0.016039932 |
# |    std                | 1.05         |
# |    value_loss         | 9.88e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 373         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.98       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.00817    |
# |    reward             | 0.008947112 |
# |    std                | 1.07        |
# |    value_loss         | 0.000272    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 375          |
# |    iterations         | 300          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -3.03        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 0.0057       |
# |    reward             | 0.0042232964 |
# |    std                | 1.1          |
# |    value_loss         | 2.83e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 375         |
# |    iterations         | 400         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -3.08       |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -0.154      |
# |    reward             | 0.007872461 |
# |    std                | 1.13        |
# |    value_loss         | 0.0015      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -3.12      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -0.0309    |
# |    reward             | 0.10703792 |
# |    std                | 1.15       |
# |    value_loss         | 0.00969    |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 373        |
# |    iterations         | 600        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -3.13      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -0.0181    |
# |    reward             | 0.00613137 |
# |    std                | 1.16       |
# |    value_loss         | 5.2e-05    |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 371        |
# |    iterations         | 700        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -3.18      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -0.014     |
# |    reward             | 0.01127541 |
# |    std                | 1.19       |
# |    value_loss         | 3.81e-05   |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 800          |
# |    time_elapsed       | 10           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -3.22        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | -0.0079      |
# |    reward             | -0.014156974 |
# |    std                | 1.21         |
# |    value_loss         | 6.55e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 900          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.24        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.0372      |
# |    reward             | -0.017234629 |
# |    std                | 1.22         |
# |    value_loss         | 0.000245     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 369          |
# |    iterations         | 1000         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.25        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.125       |
# |    reward             | -0.007457265 |
# |    std                | 1.23         |
# |    value_loss         | 0.00119      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 370         |
# |    iterations         | 1100        |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -3.25       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 0.684       |
# |    reward             | 0.007172864 |
# |    std                | 1.23        |
# |    value_loss         | 0.0736      |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 370           |
# |    iterations         | 1200          |
# |    time_elapsed       | 16            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -3.27         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | -0.0627       |
# |    reward             | -0.0068055955 |
# |    std                | 1.24          |
# |    value_loss         | 0.000411      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 1300         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -3.3         |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | 0.0167       |
# |    reward             | -0.007005723 |
# |    std                | 1.26         |
# |    value_loss         | 0.000202     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 368         |
# |    iterations         | 1400        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -3.33       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 0.251       |
# |    reward             | 0.056540016 |
# |    std                | 1.28        |
# |    value_loss         | 0.00935     |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 367        |
# |    iterations         | 1500       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -3.36      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -0.0288    |
# |    reward             | 0.01853023 |
# |    std                | 1.3        |
# |    value_loss         | 0.000133   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 367         |
# |    iterations         | 1600        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -3.39       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | 0.104       |
# |    reward             | 0.062280998 |
# |    std                | 1.32        |
# |    value_loss         | 0.000659    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 368          |
# |    iterations         | 1700         |
# |    time_elapsed       | 23           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -3.42        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | -0.0333      |
# |    reward             | 0.0019833834 |
# |    std                | 1.34         |
# |    value_loss         | 0.000183     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 369         |
# |    iterations         | 1800        |
# |    time_elapsed       | 24          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -3.46       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -0.00782    |
# |    reward             | 0.009327204 |
# |    std                | 1.36        |
# |    value_loss         | 9.62e-06    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 1900         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -3.52        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 0.0397       |
# |    reward             | -0.016138202 |
# |    std                | 1.41         |
# |    value_loss         | 0.000186     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 2000         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -3.57        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1999         |
# |    policy_loss        | -0.0033      |
# |    reward             | -0.002237329 |
# |    std                | 1.44         |
# |    value_loss         | 6.27e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 370         |
# |    iterations         | 2100        |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -3.64       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | -0.0925     |
# |    reward             | 0.031438913 |
# |    std                | 1.49        |
# |    value_loss         | 0.001       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 371         |
# |    iterations         | 2200        |
# |    time_elapsed       | 29          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -3.67       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | -0.184      |
# |    reward             | 0.014447848 |
# |    std                | 1.52        |
# |    value_loss         | 0.00217     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 371         |
# |    iterations         | 2300        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -3.71       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | -0.0122     |
# |    reward             | 0.005195123 |
# |    std                | 1.54        |
# |    value_loss         | 0.000471    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 371          |
# |    iterations         | 2400         |
# |    time_elapsed       | 32           |
# |    total_timesteps    | 12000        |
# | train/                |              |
# |    entropy_loss       | -3.74        |
# |    explained_variance | 1.79e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | -0.109       |
# |    reward             | 0.0009653799 |
# |    std                | 1.57         |
# |    value_loss         | 0.0013       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 371         |
# |    iterations         | 2500        |
# |    time_elapsed       | 33          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -3.75       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 0.12        |
# |    reward             | 0.029598296 |
# |    std                | 1.58        |
# |    value_loss         | 0.00167     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 369          |
# |    iterations         | 2600         |
# |    time_elapsed       | 35           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -3.78        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | -0.0122      |
# |    reward             | -0.034541328 |
# |    std                | 1.6          |
# |    value_loss         | 0.000293     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 368         |
# |    iterations         | 2700        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -3.79       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | -0.0361     |
# |    reward             | 0.017313395 |
# |    std                | 1.61        |
# |    value_loss         | 0.000669    |
# ---------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -46215.20
# total_reward: -56215.20
# total_cost: 221.17
# total_trades: 2434
# Sharpe: 0.378
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 367          |
# |    iterations         | 2800         |
# |    time_elapsed       | 38           |
# |    total_timesteps    | 14000        |
# | train/                |              |
# |    entropy_loss       | -3.81        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2799         |
# |    policy_loss        | 0.000414     |
# |    reward             | 0.0014384821 |
# |    std                | 1.62         |
# |    value_loss         | 8.08e-07     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 365          |
# |    iterations         | 2900         |
# |    time_elapsed       | 39           |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -3.84        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | 0.0221       |
# |    reward             | 0.0076007233 |
# |    std                | 1.65         |
# |    value_loss         | 5.15e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 365           |
# |    iterations         | 3000          |
# |    time_elapsed       | 41            |
# |    total_timesteps    | 15000         |
# | train/                |               |
# |    entropy_loss       | -3.87         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2999          |
# |    policy_loss        | 0.0713        |
# |    reward             | -0.0063503357 |
# |    std                | 1.68          |
# |    value_loss         | 0.000447      |
# -----------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.24115584297092876
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.0541000e+04  2.9955228e+02  5.7697010e+01  3.0000000e+00
#   -2.8000000e+01  4.6435189e+00  8.9956301e-01  2.9891794e+02
#    5.9745670e+01  2.6933096e+02  5.5217831e+01  6.5731194e+01
#    6.1977993e+01  2.1724931e+02  5.6719246e+01  5.3212513e+01
#    3.1374651e+01  2.8176910e+02  5.6437672e+01  2.8202286e+02
#    5.4492279e+01]]
# ============================================
# turbulence_threshold:  23.580968401549146
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_2
# ----------------------------------------
# | time/                 |              |
# |    fps                | 335          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.97        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | 0.000811     |
# |    reward             | -0.008390902 |
# |    std                | 1.07         |
# |    value_loss         | 2.06e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 357         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -3.03       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.0102     |
# |    reward             | 0.012330185 |
# |    std                | 1.1         |
# |    value_loss         | 0.000266    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 364          |
# |    iterations         | 300          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -3.08        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | -0.0313      |
# |    reward             | -0.014966529 |
# |    std                | 1.13         |
# |    value_loss         | 0.000144     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 365          |
# |    iterations         | 400          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.126        |
# |    reward             | -0.017675608 |
# |    std                | 1.15         |
# |    value_loss         | 0.00444      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 365        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -3.15      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 0.179      |
# |    reward             | 0.32767686 |
# |    std                | 1.17       |
# |    value_loss         | 0.0406     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 360          |
# |    iterations         | 600          |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -3.17        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.00156     |
# |    reward             | 0.0032470115 |
# |    std                | 1.18         |
# |    value_loss         | 1.07e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 354          |
# |    iterations         | 700          |
# |    time_elapsed       | 9            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -3.2         |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.0487       |
# |    reward             | -0.008164037 |
# |    std                | 1.2          |
# |    value_loss         | 0.000172     |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 354            |
# |    iterations         | 800            |
# |    time_elapsed       | 11             |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -3.24          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | -0.0456        |
# |    reward             | -6.6215516e-06 |
# |    std                | 1.22           |
# |    value_loss         | 0.000235       |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 354          |
# |    iterations         | 900          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.29        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.00713     |
# |    reward             | -0.016337264 |
# |    std                | 1.26         |
# |    value_loss         | 3.45e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 354          |
# |    iterations         | 1000         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.36        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.00947      |
# |    reward             | -0.009870721 |
# |    std                | 1.3          |
# |    value_loss         | 0.000652     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 350          |
# |    iterations         | 1100         |
# |    time_elapsed       | 15           |
# ...
# |    n_updates          | 699         |
# |    policy_loss        | 0.0414      |
# |    reward             | 0.003206666 |
# |    std                | 1.24        |
# |    value_loss         | 0.00101     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 365         |
# |    iterations         | 800         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -3.28       |
# |    explained_variance | -60.8       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -0.105      |
# |    reward             | 0.012308525 |
# |    std                | 1.25        |
# |    value_loss         | 0.0114      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 365          |
# |    iterations         | 900          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.3         |
# |    explained_variance | -75.3        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.111       |
# |    reward             | -0.011072338 |
# |    std                | 1.26         |
# |    value_loss         | 0.00403      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 366          |
# |    iterations         | 1000         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.3         |
# |    explained_variance | -0.162       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.452       |
# |    reward             | 0.0021161267 |
# |    std                | 1.26         |
# |    value_loss         | 0.0258       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 367         |
# |    iterations         | 1100        |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -3.3        |
# |    explained_variance | -10.3       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | -0.0814     |
# |    reward             | 0.005675656 |
# |    std                | 1.26        |
# |    value_loss         | 0.00683     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 366          |
# |    iterations         | 1200         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -3.31        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | 0.00883      |
# |    reward             | 0.0028468412 |
# |    std                | 1.27         |
# |    value_loss         | 1.63e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 366          |
# |    iterations         | 1300         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -3.34        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | 0.199        |
# |    reward             | 0.0024725401 |
# |    std                | 1.29         |
# |    value_loss         | 0.00379      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 365         |
# |    iterations         | 1400        |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -3.35       |
# |    explained_variance | -4.31       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 0.153       |
# |    reward             | -0.01688843 |
# |    std                | 1.29        |
# |    value_loss         | 0.00632     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 365         |
# |    iterations         | 1500        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -3.36       |
# |    explained_variance | -1.53       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -0.328      |
# |    reward             | 0.011135396 |
# |    std                | 1.3         |
# |    value_loss         | 0.0121      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 364         |
# |    iterations         | 1600        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -3.36       |
# |    explained_variance | -3.42       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | 0.179       |
# |    reward             | 0.055013552 |
# |    std                | 1.3         |
# |    value_loss         | 0.0193      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 364          |
# |    iterations         | 1700         |
# |    time_elapsed       | 23           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -3.39        |
# |    explained_variance | 0.056        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 0.127        |
# |    reward             | -0.033304613 |
# |    std                | 1.32         |
# |    value_loss         | 0.0549       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 363           |
# |    iterations         | 1800          |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -3.4          |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 0.0203        |
# |    reward             | -0.0009062003 |
# |    std                | 1.33          |
# |    value_loss         | 5.02e-05      |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 363        |
# |    iterations         | 1900       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -3.44      |
# |    explained_variance | 0.00057    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 0.0322     |
# |    reward             | 0.00849901 |
# |    std                | 1.35       |
# |    value_loss         | 0.000208   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 363         |
# |    iterations         | 2000        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.48       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.133       |
# |    reward             | 0.009622759 |
# |    std                | 1.38        |
# |    value_loss         | 0.00142     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 363          |
# |    iterations         | 2100         |
# |    time_elapsed       | 28           |
# |    total_timesteps    | 10500        |
# | train/                |              |
# |    entropy_loss       | -3.52        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2099         |
# |    policy_loss        | 0.033        |
# |    reward             | -0.023849795 |
# |    std                | 1.4          |
# |    value_loss         | 0.000186     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 363         |
# |    iterations         | 2200        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -3.53       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | 0.0638      |
# |    reward             | -0.14451127 |
# |    std                | 1.41        |
# |    value_loss         | 0.00104     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 364          |
# |    iterations         | 2300         |
# |    time_elapsed       | 31           |
# |    total_timesteps    | 11500        |
# | train/                |              |
# |    entropy_loss       | -3.54        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2299         |
# |    policy_loss        | -0.0308      |
# |    reward             | -0.064863354 |
# |    std                | 1.42         |
# |    value_loss         | 0.00434      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 365          |
# |    iterations         | 2400         |
# |    time_elapsed       | 32           |
# |    total_timesteps    | 12000        |
# | train/                |              |
# |    entropy_loss       | -3.55        |
# |    explained_variance | -9.13        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | -0.0681      |
# |    reward             | -0.011318366 |
# |    std                | 1.43         |
# |    value_loss         | 0.000882     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 364         |
# |    iterations         | 2500        |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -3.57       |
# |    explained_variance | 0.406       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 0.136       |
# |    reward             | 0.021345489 |
# |    std                | 1.44        |
# |    value_loss         | 0.00106     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 363          |
# |    iterations         | 2600         |
# |    time_elapsed       | 35           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -3.59        |
# |    explained_variance | -0.568       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | 0.0126       |
# |    reward             | -0.018535627 |
# |    std                | 1.46         |
# |    value_loss         | 0.000421     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 363          |
# |    iterations         | 2700         |
# |    time_elapsed       | 37           |
# |    total_timesteps    | 13500        |
# | train/                |              |
# |    entropy_loss       | -3.62        |
# |    explained_variance | -0.00254     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2699         |
# |    policy_loss        | 0.284        |
# |    reward             | -0.004589711 |
# |    std                | 1.48         |
# |    value_loss         | 0.00752      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 362          |
# |    iterations         | 2800         |
# |    time_elapsed       | 38           |
# |    total_timesteps    | 14000        |
# | train/                |              |
# |    entropy_loss       | -3.61        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2799         |
# |    policy_loss        | -0.541       |
# |    reward             | -0.006419043 |
# |    std                | 1.47         |
# |    value_loss         | 0.022        |
# ----------------------------------------
# day: 2896, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 10860.91
# total_reward: 860.91
# total_cost: 388.00
# total_trades: 2670
# Sharpe: 0.168
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 361           |
# |    iterations         | 2900          |
# |    time_elapsed       | 40            |
# |    total_timesteps    | 14500         |
# | train/                |               |
# |    entropy_loss       | -3.62         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2899          |
# |    policy_loss        | 0.0565        |
# |    reward             | 0.00032816848 |
# |    std                | 1.48          |
# |    value_loss         | 0.000199      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 361          |
# |    iterations         | 3000         |
# |    time_elapsed       | 41           |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -3.64        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | 0.104        |
# |    reward             | -0.026802951 |
# |    std                | 1.49         |
# |    value_loss         | 0.000983     |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.4711336220513693
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 2.1954219e+04  4.0172943e+02  6.6597176e+01 -3.1000000e+01
#   -2.9000000e+01  1.2611729e+01  2.7250320e-01  4.2328799e+02
#    6.9807274e+01  3.5073837e+02  6.4841652e+01  6.2777000e+01
#    4.9552269e+01  9.7660858e+01 -1.5815196e+00  2.7458639e+01
#    1.4760778e+01  3.7704617e+02  6.7293343e+01  3.6351938e+02
#    6.7372795e+01]]
# Ensemble Strategy took:  2.8314393520355225  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C  -0.154727          0           0
# 1  189  2021-04-06  2021-07-06        A2C  -0.241156          0           0
# 2  252  2021-07-06  2021-10-04        A2C  -0.095776          0           0
# 3  315  2021-10-04  2022-01-03        A2C   0.471134          0           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.04976274268519288

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10001.157296  2021-04-07  1.157296e-04  2021-04-07
# 2   10002.613537  2021-04-08  1.456072e-04  2021-04-08
# 3   10001.165880  2021-04-09 -1.447279e-04  2021-04-09
# 4   10001.169146  2021-04-12  3.265000e-07  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.012309
# Cumulative returns    -0.012309
# Annual volatility      0.215659
# Sharpe ratio           0.049763
# Calmar ratio          -0.044515
# Stability              0.118872
# Max drawdown          -0.276522
# Omega ratio            1.010934
# Sortino ratio          0.072798
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.318198
# Daily value at risk   -0.027128
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-1.231%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-1.231%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>21.566%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-27.652%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.32</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.713%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.75</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27.65</td>
#       <td>2021-04-29</td>
#       <td>2021-12-29</td>
#       <td>2022-02-23</td>
#       <td>215</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.92</td>
#       <td>2022-03-08</td>
#       <td>2022-03-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.51</td>
#       <td>2022-02-23</td>
#       <td>2022-02-25</td>
#       <td>2022-03-07</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.11</td>
#       <td>2021-04-21</td>
#       <td>2021-04-26</td>
#       <td>2021-04-29</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.06</td>
#       <td>2021-04-08</td>
#       <td>2021-04-15</td>
#       <td>2021-04-20</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.00%</td>
#       <td>-7.68%</td>
#       <td>6.85%</td>
#     </tr>
#   </tbody>
# </table>
