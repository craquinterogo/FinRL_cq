# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AIG','CTRA']
print(DOW_30_TICKER)
# Out:
# ['AIG', 'CTRA']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high        low      close    volume   tic  \
# 6121  2022-05-26  34.340000  35.779999  34.220001  33.063053  11206100  CTRA
# 6122  2022-05-27  57.849998  59.000000  57.630001  57.997391   3891100   AIG
# 6123  2022-05-27  34.250000  35.529999  34.200001  33.893208   8413700  CTRA
# 6124  2022-05-31  58.650002  59.759998  58.169998  57.682827   5639200   AIG
# 6125  2022-05-31  36.060001  36.450001  34.130001  32.757710  22122700  CTRA
#
#       day
# 6121    3
# 6122    4
# 6123    4
# 6124    1
# 6125    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume   tic  day
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921474   6250200   AIG    3
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570667   4922000  CTRA    3
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559866  16281300   AIG    0
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793332   4937200  CTRA    0
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131056  19971000   AIG    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
processed.head()
# Out:
#          date       open       high        low      close    volume   tic  \
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921474   6250200   AIG
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570667   4922000  CTRA
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559866  16281300   AIG
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793332   4937200  CTRA
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131056  19971000   AIG
#
#    day      macd    boll_ub    boll_lb  rsi_30      cci_30  dx_30  \
# 0    3  0.000000  24.143492  22.337848   100.0   66.666667  100.0
# 1    3  0.000000  24.143492  22.337848   100.0   66.666667  100.0
# 2    0  0.014323  24.143492  22.337848   100.0   66.666667  100.0
# 3    0  0.004996   7.996894   7.367104   100.0   66.666667  100.0
# 4    1  0.035963  24.747669  22.327262   100.0  100.000000  100.0
#
#    close_30_sma  close_60_sma  turbulence
# 0     22.921474     22.921474         0.0
# 1      7.570667      7.570667         0.0
# 2     23.240670     23.240670         0.0
# 3      7.681999      7.681999         0.0
# 4     23.537465     23.537465         0.0

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 50_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.34467188858183
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# --------------------------------------
# | time/              |               |
# |    fps             | 315           |
# |    iterations      | 1             |
# |    time_elapsed    | 6             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0030618873 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0061452948 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0447       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0342      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00281     |
# |    reward               | 0.002951018  |
# |    std                  | 1            |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0032259354 |
# |    clip_fraction        | 0.00669      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0714       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0264      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 0.000392     |
# |    reward               | -0.038477916 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00531      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 4             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.000994418   |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | -0.0591       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0279       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | 0.000436      |
# |    reward               | -0.0057036066 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00442       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0024496312 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.0072      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0381      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00126     |
# |    reward               | -0.009675399 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00493      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0031470205 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.044        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0316      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 0.01812483   |
# |    std                  | 1.03         |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 7125.81
# total_reward: -2874.19
# total_cost: 123.01
# total_trades: 2648
# Sharpe: 0.050
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 7            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0036337194 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.0144       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0248      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00187     |
# |    reward               | 0.029171761  |
# |    std                  | 1.03         |
# |    value_loss           | 0.0017       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 8           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006284522 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0268      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0406     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00321    |
# |    reward               | 0.008101365 |
# |    std                  | 1.03        |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 402           |
# |    iterations           | 9             |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0036991844  |
# |    clip_fraction        | 0.0309        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | -0.00451      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0211       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000876     |
# |    reward               | -0.0021018768 |
# |    std                  | 1.03          |
# |    value_loss           | 0.00691       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 10           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0018768392 |
# |    clip_fraction        | 0.00371      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.000736     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0261      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000745    |
# |    reward               | 0.008601424  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 11           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0027466947 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.00748      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0246      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 0.012993603  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00704      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 12           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0045148414 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.00459      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0305      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00491     |
# |    reward               | 0.0032669425 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 13           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.004566772  |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.000888     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0247      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000504    |
# |    reward               | -0.011055381 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0196       |
# ------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 8242.35
# total_reward: -1757.65
# total_cost: 125.53
# total_trades: 2790
# Sharpe: 0.329
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 14           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.008647624  |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | -0.000936    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0273      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000942    |
# |    reward               | -0.002977517 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00385      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 414           |
# |    iterations           | 15            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.003602279   |
# |    clip_fraction        | 0.0313        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0.0033        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0227       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00143      |
# |    reward               | -0.0072793732 |
# |    std                  | 1.03          |
# |    value_loss           | 0.0148        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 16          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004020771 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -0.000192   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00684    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00118    |
# |    reward               | 0.012653258 |
# |    std                  | 1.03        |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 17           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0014062847 |
# |    clip_fraction        | 0.00913      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.000907     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0256      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000252    |
# |    reward               | -0.049144674 |
# |    std                  | 1.04         |
# |    value_loss           | 0.0136       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 410           |
# |    iterations           | 18            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.005031392   |
# |    clip_fraction        | 0.0495        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0136       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00397      |
# |    reward               | -0.0020411036 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00548       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 19          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004396702 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.00138     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0335     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00246    |
# |    reward               | 0.003305102 |
# |    std                  | 1.04        |
# |    value_loss           | 0.014       |
# -----------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 8914.89
# total_reward: -1085.11
# total_cost: 126.56
# total_trades: 2756
# Sharpe: 0.452
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 20          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006046095 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0016      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0396     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00404    |
# |    reward               | 0.02370401  |
# |    std                  | 1.03        |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 417           |
# |    iterations           | 21            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00029756883 |
# |    clip_fraction        | 0.00522       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.00199       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0147       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.000445      |
# |    reward               | 0.024241952   |
# |    std                  | 1.03          |
# |    value_loss           | 0.0172        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 22           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0045309467 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0242      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00149     |
# |    reward               | -0.020992339 |
# |    std                  | 1.02         |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 418            |
# |    iterations           | 23             |
# |    time_elapsed         | 112            |
# |    total_timesteps      | 47104          |
# | train/                  |                |
# |    approx_kl            | 0.0039035156   |
# |    clip_fraction        | 0.0244         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.88          |
# |    explained_variance   | 0.00166        |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0218        |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -0.00154       |
# |    reward               | -0.00026325235 |
# |    std                  | 1.02           |
# |    value_loss           | 0.0243         |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 417           |
# |    iterations           | 24            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.005679378   |
# |    clip_fraction        | 0.0586        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0256       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00263      |
# |    reward               | -0.0012882332 |
# |    std                  | 1.03          |
# |    value_loss           | 0.0269        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 25           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0060412586 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0139      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00244     |
# |    reward               | 0.029398222  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0206       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.32464229711060477
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[ 1.0000000e+04  4.4805416e+01  1.6062765e+01  0.0000000e+00
#    0.0000000e+00  5.4846609e-01  5.2864667e-02  4.6732227e+01
#    1.6984121e+01  4.3252022e+01  1.5429832e+01  5.7691311e+01
#    5.0486050e+01  1.1617319e+01 -3.8271023e+01  7.4090924e+00
#    8.9696541e+00  4.4508804e+01  1.6239408e+01  4.1729580e+01
#    1.6083076e+01]]
# ============================================
# turbulence_threshold:  19.34467188858183
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 479          |
# |    iterations      | 1            |
# |    time_elapsed    | 4            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.004469592 |
# -------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 439        |
# |    iterations           | 2          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00252469 |
# |    clip_fraction        | 0.0115     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.83      |
# |    explained_variance   | -1.36      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0331    |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00105   |
# |    reward               | 0.02810635 |
# |    std                  | 0.994      |
# |    value_loss           | 0.00845    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.005927156  |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.234       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0269      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00724     |
# |    reward               | 0.0027821031 |
# |    std                  | 0.991        |
# |    value_loss           | 0.00676      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 4            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027747508 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.0322      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0301      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | 0.0113786515 |
# |    std                  | 0.989        |
# |    value_loss           | 0.00604      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0011934035 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00411     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0363      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00102     |
# |    reward               | 0.0049174875 |
# |    std                  | 0.992        |
# |    value_loss           | 0.00407      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0026007108 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00209     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0351      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00126     |
# |    reward               | 0.011442334  |
# |    std                  | 0.995        |
# |    value_loss           | 0.00331      |
# ------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 5934.55
# total_reward: -4065.45
# total_cost: 114.29
# total_trades: 2720
# Sharpe: 0.066
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 7            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.005817378  |
# |    clip_fraction        | 0.0681       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.000652    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0249      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00215     |
# |    reward               | -0.008593944 |
# |    std                  | 0.991        |
# |    value_loss           | 0.00856      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 8            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0041314336 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.000845     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0411      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0015      |
# |    reward               | 0.037456494  |
# |    std                  | 0.992        |
# |    value_loss           | 0.00416      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 9           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004235694 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | -6.85e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.018      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00139    |
# |    reward               | 0.012811272 |
# |    std                  | 0.995       |
# |    value_loss           | 0.00914     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 10           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0037242596 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.000864    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0308      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00254     |
# |    reward               | 0.006782939  |
# |    std                  | 0.994        |
# |    value_loss           | 0.00355      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 11           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0036679409 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 3.74e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0205      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00314     |
# |    reward               | 0.0150133995 |
# |    std                  | 0.995        |
# |    value_loss           | 0.0118       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 12           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0028829027 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0011       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.019       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000225    |
# |    reward               | 0.008293234  |
# |    std                  | 0.995        |
# |    value_loss           | 0.00938      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 13           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051432103 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.00156     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0224      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00249     |
# |    reward               | -0.029287979 |
# |    std                  | 0.992        |
# |    value_loss           | 0.00305      |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 774.14
# total_reward: -9225.86
# total_cost: 124.93
# total_trades: 2780
# Sharpe: -0.222
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 14           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0051817857 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 2.56e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0247      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00323     |
# |    reward               | -0.015147319 |
# |    std                  | 0.996        |
# |    value_loss           | 0.00982      |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 412            |
# |    iterations           | 15             |
# |    time_elapsed         | 74             |
# |    total_timesteps      | 30720          |
# | train/                  |                |
# |    approx_kl            | 0.0010966382   |
# |    clip_fraction        | 0.0106         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.83          |
# |    explained_variance   | 0.000648       |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0141        |
# |    n_updates            | 140            |
# |    policy_gradient_loss | 0.000453       |
# |    reward               | -0.00051490776 |
# |    std                  | 0.999          |
# |    value_loss           | 0.0198         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 16           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0031104384 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.000868     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00549     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000391    |
# |    reward               | -0.006288607 |
# |    std                  | 0.994        |
# |    value_loss           | 0.014        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 17           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0032932532 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00334      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0392      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00214     |
# |    reward               | 0.014560585  |
# |    std                  | 0.991        |
# |    value_loss           | 0.00435      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 407           |
# |    iterations           | 18            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.0057272064  |
# |    clip_fraction        | 0.0277        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.000726      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0106       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000672     |
# |    reward               | -0.0049154945 |
# |    std                  | 0.984         |
# |    value_loss           | 0.0136        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 19           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0029516548 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -1.23e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0248      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000977    |
# |    reward               | -0.009657293 |
# |    std                  | 0.989        |
# |    value_loss           | 0.0166       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 20          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002034499 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.000148    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0148     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00136    |
# |    reward               | -0.04379805 |
# |    std                  | 0.981       |
# |    value_loss           | 0.0157      |
# -----------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 3648.03
# total_reward: -6351.97
# total_cost: 130.79
# total_trades: 2860
# Sharpe: 0.498
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 21           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.004910657  |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0265      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00322     |
# |    reward               | -0.010000003 |
# |    std                  | 0.99         |
# |    value_loss           | 0.00465      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 22           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0048346315 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 3.58e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0302      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00157     |
# |    reward               | -0.02111133  |
# |    std                  | 0.988        |
# |    value_loss           | 0.0196       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 23           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0044580586 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0109      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00126     |
# |    reward               | 0.10592889   |
# |    std                  | 0.977        |
# |    value_loss           | 0.0504       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 24           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.003921667  |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.000129     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0182      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | -0.028645216 |
# |    std                  | 0.981        |
# |    value_loss           | 0.0394       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 25           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0033435929 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.000672     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0278      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000336    |
# |    reward               | 0.013960065  |
# |    std                  | 0.989        |
# |    value_loss           | 0.00708      |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.018990213766964987
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.41609482e+04  4.50344276e+01  1.48622684e+01 -9.70000000e+01
#    1.30000000e+01 -8.47349286e-01  7.72210583e-02  5.13974609e+01
#    1.58006067e+01  4.36545029e+01  1.34798079e+01  4.45638275e+01
#    4.97791595e+01 -1.11025391e+02  9.52524414e+01  3.32284203e+01
#    5.63854551e+00  4.85274696e+01  1.46157284e+01  4.77497673e+01
#    1.47524805e+01]]
# ============================================
# turbulence_threshold:  19.34467188858183
# ======Model training from:  2010-04-01 to  2021-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_1
# --------------------------------------
# | time/              |               |
# |    fps             | 484           |
# |    iterations      | 1             |
# |    time_elapsed    | 4             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0024611675 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 437           |
# |    iterations           | 2             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.003915535   |
# |    clip_fraction        | 0.0324        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -1.64         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0377       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00276      |
# |    reward               | -0.0056452407 |
# |    std                  | 0.995         |
# |    value_loss           | 0.00341       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 443           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0040638866  |
# |    clip_fraction        | 0.0107        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -0.419        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0218       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000717     |
# |    reward               | -0.0021031268 |
# |    std                  | 0.999         |
# |    value_loss           | 0.00259       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0044229105 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.0169      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0274      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00217     |
# ...
# |    loss                 | -0.0308      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00342     |
# |    reward               | -0.031024896 |
# |    std                  | 0.979        |
# |    value_loss           | 0.00529      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 404           |
# |    iterations           | 9             |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0037772933  |
# |    clip_fraction        | 0.0173        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.019        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00141      |
# |    reward               | -0.0057574003 |
# |    std                  | 0.972         |
# |    value_loss           | 0.00225       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 10           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0035358015 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0244      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00183     |
# |    reward               | 0.020899246  |
# |    std                  | 0.971        |
# |    value_loss           | 0.00729      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 11           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0045308634 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0024      |
# |    reward               | -0.017876562 |
# |    std                  | 0.978        |
# |    value_loss           | 0.00295      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 12           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.003407422  |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0429      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00306     |
# |    reward               | -0.009921512 |
# |    std                  | 0.984        |
# |    value_loss           | 0.00279      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 13           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.00502975   |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0128      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0025      |
# |    reward               | -0.004457562 |
# |    std                  | 0.976        |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 14          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004414837 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0238     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00283    |
# |    reward               | -0.05069599 |
# |    std                  | 0.973       |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 2270.56
# total_reward: -7729.44
# total_cost: 125.19
# total_trades: 2902
# Sharpe: 0.085
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 411           |
# |    iterations           | 15            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.0043151644  |
# |    clip_fraction        | 0.018         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0203       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00184      |
# |    reward               | -0.0050044805 |
# |    std                  | 0.973         |
# |    value_loss           | 0.00432       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 412           |
# |    iterations           | 16            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.0038977028  |
# |    clip_fraction        | 0.00859       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0211       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000792     |
# |    reward               | -0.0134517895 |
# |    std                  | 0.967         |
# |    value_loss           | 0.00158       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 414           |
# |    iterations           | 17            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.003736869   |
# |    clip_fraction        | 0.0182        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0457       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00173      |
# |    reward               | 0.00011980796 |
# |    std                  | 0.965         |
# |    value_loss           | 0.00186       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 18           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0030227525 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0297      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000758    |
# |    reward               | 0.014675274  |
# |    std                  | 0.955        |
# |    value_loss           | 0.00167      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 19           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0030525103 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0227      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0017      |
# |    reward               | 0.002045348  |
# |    std                  | 0.953        |
# |    value_loss           | 0.000727     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 20           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036417732 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.036       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00135     |
# |    reward               | -0.015393549 |
# |    std                  | 0.955        |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 21           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.002946506  |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00171     |
# |    reward               | 0.0023816263 |
# |    std                  | 0.959        |
# |    value_loss           | 0.00569      |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 3690.36
# total_reward: -6309.64
# total_cost: 135.26
# total_trades: 2902
# Sharpe: -0.123
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 22           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0031788577 |
# |    clip_fraction        | 0.00425      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.035       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000609    |
# |    reward               | 0.005066783  |
# |    std                  | 0.953        |
# |    value_loss           | 0.000788     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 412           |
# |    iterations           | 23            |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.004759867   |
# |    clip_fraction        | 0.0263        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0174       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00256      |
# |    reward               | -0.0127725545 |
# |    std                  | 0.948         |
# |    value_loss           | 0.00132       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 413           |
# |    iterations           | 24            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.006459429   |
# |    clip_fraction        | 0.0645        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0338       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.0053       |
# |    reward               | -0.0010293961 |
# |    std                  | 0.949         |
# |    value_loss           | 0.00215       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 25           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.002777786  |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0278      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000702    |
# |    reward               | 0.0051583895 |
# |    std                  | 0.952        |
# |    value_loss           | 0.00251      |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.04655989179837324
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.48679629e+04  5.61064186e+01  1.78933163e+01 -1.17000000e+02
#    3.30000000e+01  3.64579082e-01 -2.49183282e-01  5.65978508e+01
#    1.91780338e+01  5.14668846e+01  1.73126259e+01  5.40335846e+01
#    4.80560875e+01  1.19248146e+02 -1.19776619e+02  1.84849968e+01
#    2.16158524e+01  5.38814087e+01  1.84160042e+01  5.54465218e+01
#    1.88006992e+01]]
# Ensemble Strategy took:  8.30382198492686  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0  -0.324642           0
# 1  189  2021-04-06  2021-07-06        PPO          0   -0.01899           0
# 2  252  2021-07-06  2021-10-04        PPO          0  -0.335659           0
# 3  315  2021-10-04  2022-01-03        PPO          0    0.04656           0

# %%
len(ensemble_agent.crk_model)
# Out:
# 4

# %%
ensemble_agent.crk_model[0].policy.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict([('log_std',
#                Parameter containing:
#                tensor([0.0208, 0.0139], requires_grad=True))]),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('features_extractor',
#                FlattenExtractor(
#                  (flatten): Flatten(start_dim=1, end_dim=-1)
#                )),
#               ('mlp_extractor',
#                MlpExtractor(
#                  (shared_net): Sequential()
#                  (policy_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                  (value_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                )),
#               ('action_net',
#                Linear(in_features=64, out_features=2, bias=True)),
#               ('value_net',
#                Linear(in_features=64, out_features=1, bias=True))]),
#  'observation_space': Box([-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#   inf inf inf], (21,), float32),
#  'action_space': Box([-1. -1.], [1. 1.], (2,), float32),
#  'normalize_images': True,
#  'optimizer_class': torch.optim.adam.Adam,
#  'optimizer_kwargs': {'eps': 1e-05},
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      eps: 1e-05
#      foreach: None
#      lr: 0.00025
#      maximize: False
#      weight_decay: 0
#  ),
#  'features_extractor_class': stable_baselines3.common.torch_layers.FlattenExtractor,
#  'features_extractor_kwargs': {},
#  '_squash_output': False,
#  'net_arch': [{'pi': [64, 64], 'vf': [64, 64]}],
#  'activation_fn': torch.nn.modules.activation.Tanh,
#  'ortho_init': True,
#  'features_dim': 21,
#  'log_std_init': 0.0,
#  'use_sde': False,
#  'dist_kwargs': None,
#  'action_dist': <stable_baselines3.common.distributions.DiagGaussianDistribution at 0x2424cb715e0>}

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.862488564032708

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1    9989.131104  2021-04-07     -0.001087  2021-04-07
# 2   10010.131877  2021-04-08      0.002102  2021-04-08
# 3    9998.315876  2021-04-09     -0.001180  2021-04-09
# 4    9971.941463  2021-04-12     -0.002638  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.166716
# Cumulative returns    -0.166716
# Annual volatility      0.191161
# Sharpe ratio          -0.862489
# Calmar ratio          -0.919460
# Stability              0.718939
# Max drawdown          -0.181319
# Omega ratio            0.864586
# Sortino ratio         -1.205249
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.934601
# Daily value at risk   -0.024738
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-16.672%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-16.672%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.116%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.86</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.92</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.72</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-18.132%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.21</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.474%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.67</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.13</td>
#       <td>2021-07-08</td>
#       <td>2022-03-25</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.44</td>
#       <td>2021-04-20</td>
#       <td>2021-06-01</td>
#       <td>2021-07-08</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.52</td>
#       <td>2021-04-08</td>
#       <td>2021-04-14</td>
#       <td>2021-04-20</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.11</td>
#       <td>2021-04-06</td>
#       <td>2021-04-07</td>
#       <td>2021-04-08</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.07%</td>
#       <td>-3.75%</td>
#       <td>4.89%</td>
#     </tr>
#   </tbody>
# </table>
