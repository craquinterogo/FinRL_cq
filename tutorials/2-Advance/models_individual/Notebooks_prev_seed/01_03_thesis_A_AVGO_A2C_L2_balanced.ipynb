# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['A','AVGO']
print(DOW_30_TICKER)
# Out:
# ['A', 'AVGO']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26  531.539978  554.570007  527.719971  541.591003  3974300
# 6122  2022-05-27  124.919998  130.770004  124.489998  130.094025  2698800
# 6123  2022-05-27  562.090027  585.460022  560.010010  573.673828  3730100
# 6124  2022-05-31  128.910004  130.070007  126.720001  127.114464  3403100
# 6125  2022-05-31  584.500000  587.030029  576.000000  570.575684  3000900
#
#        tic  day
# 6121  AVGO    3
# 6122     A    4
# 6123  AVGO    4
# 6124     A    1
# 6125  AVGO    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  24.706724  24.942776  24.499285  22.442745  3105098     A    3
# 1  2010-04-01  20.690001  20.799999  20.090000  15.229790   324600  AVGO    3
# 2  2010-04-05  24.742489  24.921316  24.706724  22.618132  3731961     A    0
# 3  2010-04-05  20.690001  20.700001  19.790001  15.051489   612000  AVGO    0
# 4  2010-04-06  24.778255  24.814020  24.620888  22.449238  3499054     A    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# A       3063
# AVGO    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 15_000, 
                 'ppo' : 0, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 None,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  18.96247884362481
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 117          |
# |    iterations         | 100          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0265      |
# |    reward             | -0.017727789 |
# |    std                | 1.05         |
# |    value_loss         | 0.000302     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 173         |
# |    iterations         | 200         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.98       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.0122      |
# |    reward             | 0.019193605 |
# |    std                | 1.07        |
# |    value_loss         | 0.000236    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 207         |
# |    iterations         | 300         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -3.01       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.0397     |
# |    reward             | -0.04155916 |
# |    std                | 1.09        |
# |    value_loss         | 0.00201     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 400         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -3.05       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -0.107      |
# |    reward             | 0.025190998 |
# |    std                | 1.11        |
# |    value_loss         | 0.00448     |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 243        |
# |    iterations         | 500        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -3.06      |
# |    explained_variance | -14.7      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -1.96      |
# |    reward             | 0.33985865 |
# |    std                | 1.12       |
# |    value_loss         | 0.373      |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 254           |
# |    iterations         | 600           |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -3.08         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.0645        |
# |    reward             | -0.0017612398 |
# |    std                | 1.13          |
# |    value_loss         | 0.000612      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 264          |
# |    iterations         | 700          |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -3.12        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -0.0711      |
# |    reward             | 0.0019324785 |
# |    std                | 1.15         |
# |    value_loss         | 0.000886     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 271          |
# |    iterations         | 800          |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -3.15        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 0.0198       |
# |    reward             | -0.006326801 |
# |    std                | 1.17         |
# |    value_loss         | 0.000313     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 275          |
# |    iterations         | 900          |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.16        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 0.0273       |
# |    reward             | -0.030039608 |
# |    std                | 1.18         |
# |    value_loss         | 0.000215     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 279          |
# |    iterations         | 1000         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.18        |
# |    explained_variance | -2.38e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.166       |
# |    reward             | -0.004333649 |
# |    std                | 1.19         |
# |    value_loss         | 0.00424      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 281          |
# |    iterations         | 1100         |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -3.19        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | -0.0363      |
# |    reward             | -0.013198689 |
# |    std                | 1.19         |
# |    value_loss         | 0.000154     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 285          |
# |    iterations         | 1200         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -3.21        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | -0.0668      |
# |    reward             | -0.011032715 |
# |    std                | 1.21         |
# |    value_loss         | 0.000499     |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 288        |
# |    iterations         | 1300       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -3.22      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 0.0166     |
# |    reward             | 0.03873745 |
# |    std                | 1.21       |
# |    value_loss         | 0.000263   |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 290          |
# |    iterations         | 1400         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -3.27        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | -0.172       |
# |    reward             | -0.008912803 |
# |    std                | 1.24         |
# |    value_loss         | 0.0026       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 293         |
# |    iterations         | 1500        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -3.3        |
# |    explained_variance | -3.45       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -0.174      |
# |    reward             | -0.22923502 |
# |    std                | 1.26        |
# |    value_loss         | 0.00967     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 295         |
# |    iterations         | 1600        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -3.32       |
# |    explained_variance | -1.13       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -0.461      |
# |    reward             | 0.022693116 |
# |    std                | 1.28        |
# |    value_loss         | 0.0278      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 296         |
# |    iterations         | 1700        |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -3.35       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | 0.0295      |
# |    reward             | -0.01803507 |
# |    std                | 1.29        |
# |    value_loss         | 0.000321    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 297          |
# |    iterations         | 1800         |
# |    time_elapsed       | 30           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -3.36        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | -0.114       |
# |    reward             | -0.008356312 |
# |    std                | 1.3          |
# |    value_loss         | 0.000746     |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 302        |
# |    iterations         | 1900       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -3.38      |
# |    explained_variance | 2.38e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -0.102     |
# |    reward             | 0.07025914 |
# |    std                | 1.31       |
# |    value_loss         | 0.00217    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 307         |
# |    iterations         | 2000        |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.41       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -0.108      |
# |    reward             | 0.085362144 |
# |    std                | 1.33        |
# |    value_loss         | 0.00416     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 311         |
# |    iterations         | 2100        |
# |    time_elapsed       | 33          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -3.41       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | -0.0361     |
# |    reward             | -0.08006209 |
# |    std                | 1.34        |
# |    value_loss         | 0.00604     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 316          |
# |    iterations         | 2200         |
# |    time_elapsed       | 34           |
# |    total_timesteps    | 11000        |
# | train/                |              |
# |    entropy_loss       | -3.43        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2199         |
# |    policy_loss        | 0.0337       |
# |    reward             | 0.0028825663 |
# |    std                | 1.34         |
# |    value_loss         | 0.000163     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 320          |
# |    iterations         | 2300         |
# |    time_elapsed       | 35           |
# |    total_timesteps    | 11500        |
# | train/                |              |
# |    entropy_loss       | -3.46        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2299         |
# |    policy_loss        | -0.00028     |
# |    reward             | -0.007126474 |
# |    std                | 1.36         |
# |    value_loss         | 1.99e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 324           |
# |    iterations         | 2400          |
# |    time_elapsed       | 36            |
# |    total_timesteps    | 12000         |
# | train/                |               |
# |    entropy_loss       | -3.49         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2399          |
# |    policy_loss        | -0.114        |
# |    reward             | -0.0036153533 |
# |    std                | 1.38          |
# |    value_loss         | 0.000723      |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 328        |
# |    iterations         | 2500       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -3.5       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -0.521     |
# |    reward             | 0.07894679 |
# |    std                | 1.39       |
# |    value_loss         | 0.0169     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 330         |
# |    iterations         | 2600        |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -3.51       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | -0.507      |
# |    reward             | 0.026228348 |
# |    std                | 1.4         |
# |    value_loss         | 0.0308      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 329        |
# |    iterations         | 2700       |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -3.52      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 0.102      |
# |    reward             | 0.06270279 |
# |    std                | 1.41       |
# |    value_loss         | 0.014      |
# --------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -22735.61
# total_reward: -32735.61
# total_cost: 607.10
# total_trades: 3838
# Sharpe: 0.521
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 328           |
# |    iterations         | 2800          |
# |    time_elapsed       | 42            |
# |    total_timesteps    | 14000         |
# | train/                |               |
# |    entropy_loss       | -3.54         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2799          |
# |    policy_loss        | 0.0446        |
# |    reward             | -0.0033944496 |
# |    std                | 1.42          |
# |    value_loss         | 0.000334      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 327         |
# |    iterations         | 2900        |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -3.56       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | -0.0353     |
# |    reward             | 0.009429974 |
# |    std                | 1.43        |
# |    value_loss         | 0.00128     |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 329       |
# |    iterations         | 3000      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -3.57     |
# |    explained_variance | 0.805     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.265     |
# |    reward             | 0.2574456 |
# |    std                | 1.44      |
# |    value_loss         | 0.0118    |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.10551608200933212
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.00000000e+04 1.29873489e+02 4.62661011e+02 0.00000000e+00
#   0.00000000e+00 1.74376857e+00 4.68947315e+00 1.28886887e+02
#   4.73304657e+02 1.16377342e+02 4.16861572e+02 6.06303787e+01
#   5.49654121e+01 2.25215179e+02 1.10210144e+02 3.74220161e+01
#   6.06779385e+00 1.21544266e+02 4.43080963e+02 1.22726051e+02
#   4.42397888e+02]]
# ============================================
# turbulence_threshold:  18.96247884362481
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 436          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.92        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0253      |
# |    reward             | -0.020581877 |
# |    std                | 1.04         |
# |    value_loss         | 0.000441     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 431         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.96       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.045       |
# |    reward             | 0.023746602 |
# |    std                | 1.06        |
# |    value_loss         | 0.00112     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 434          |
# |    iterations         | 300          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -3.01        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 0.164        |
# |    reward             | -0.013707871 |
# |    std                | 1.09         |
# |    value_loss         | 0.00401      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 425          |
# |    iterations         | 400          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -3.02        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.144        |
# |    reward             | -0.030210838 |
# |    std                | 1.1          |
# |    value_loss         | 0.00608      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 410        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -3.02      |
# |    explained_variance | -4.36e-05  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -0.744     |
# |    reward             | 0.16620667 |
# |    std                | 1.1        |
# |    value_loss         | 0.0721     |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 392           |
# |    iterations         | 600           |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -3.04         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.00376       |
# |    reward             | 0.00077218685 |
# |    std                | 1.11          |
# |    value_loss         | 0.000356      |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 700       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.244     |
# |    reward             | 0.0563188 |
# |    std                | 1.12      |
# |    value_loss         | 0.00682   |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 366         |
# |    iterations         | 800         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -3.09       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -0.0899     |
# |    reward             | 0.014901019 |
# |    std                | 1.13        |
# |    value_loss         | 0.00182     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 373          |
# |    iterations         | 900          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.0811      |
# |    reward             | -0.008958038 |
# |    std                | 1.14         |
# |    value_loss         | 0.0041       |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 378          |
# |    iterations         | 1000         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.505       |
# |    reward             | -0.063990034 |
# |    std                | 1.15         |
# |    value_loss         | 0.0364       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 381        |
# |    iterations         | 1100       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -3.13      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 2.92       |
# |    reward             | 0.27709058 |
# |    std                | 1.16       |
# |    value_loss         | 1.25       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 385          |
# |    iterations         | 1200         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -3.15        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | -0.17        |
# |    reward             | -0.017260535 |
# |    std                | 1.17         |
# |    value_loss         | 0.00274      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 389          |
# |    iterations         | 1300         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -3.17        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | -0.176       |
# |    reward             | -0.021678865 |
# |    std                | 1.18         |
# |    value_loss         | 0.00216      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 387        |
# |    iterations         | 1400       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -3.17      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 0.699      |
# |    reward             | 0.15061787 |
# |    std                | 1.18       |
# |    value_loss         | 0.109      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 387        |
# |    iterations         | 1500       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -3.18      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -1.06      |
# |    reward             | 0.21858847 |
# |    std                | 1.19       |
# |    value_loss         | 0.12       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 389         |
# |    iterations         | 1600        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -3.18       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | 0.804       |
# |    reward             | 0.049794886 |
# |    std                | 1.19        |
# |    value_loss         | 0.0789      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 391         |
# |    iterations         | 1700        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -3.19       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -0.0402     |
# |    reward             | 0.007811669 |
# |    std                | 1.19        |
# |    value_loss         | 0.000198    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 392         |
# |    iterations         | 1800        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -3.21       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 0.112       |
# |    reward             | 0.010324667 |
# |    std                | 1.2         |
# |    value_loss         | 0.00116     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 390          |
# |    iterations         | 1900         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -3.23        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 0.187        |
# |    reward             | -0.046482492 |
# |    std                | 1.21         |
# |    value_loss         | 0.00527      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 385         |
# |    iterations         | 2000        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.25       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.243       |
# |    reward             | 0.017525284 |
# |    std                | 1.23        |
# |    value_loss         | 0.0121      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 383          |
# |    iterations         | 2100         |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 10500        |
# | train/                |              |
# |    entropy_loss       | -3.25        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2099         |
# |    policy_loss        | -0.177       |
# |    reward             | -0.032768138 |
# |    std                | 1.23         |
# |    value_loss         | 0.0102       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 382         |
# |    iterations         | 2200        |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -3.26       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | -1.22       |
# |    reward             | 0.035679705 |
# |    std                | 1.24        |
# |    value_loss         | 0.124       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 384         |
# |    iterations         | 2300        |
# |    time_elapsed       | 29          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -3.27       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | -0.00111    |
# |    reward             | 0.002663766 |
# |    std                | 1.25        |
# |    value_loss         | 0.000285    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 385        |
# |    iterations         | 2400       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -3.3       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -0.0295    |
# |    reward             | 0.01755762 |
# |    std                | 1.26       |
# |    value_loss         | 0.000232   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 386        |
# |    iterations         | 2500       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -3.32      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -0.489     |
# |    reward             | 0.05727574 |
# |    std                | 1.27       |
# |    value_loss         | 0.0198     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 386          |
# |    iterations         | 2600         |
# |    time_elapsed       | 33           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -3.33        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | -0.462       |
# |    reward             | -0.031789515 |
# |    std                | 1.28         |
# |    value_loss         | 0.0766       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 386         |
# |    iterations         | 2700        |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -3.35       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | -0.213      |
# |    reward             | -0.25366372 |
# |    std                | 1.29        |
# |    value_loss         | 0.0184      |
# ---------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -129765.13
# total_reward: -139765.13
# total_cost: 398.08
# total_trades: 2608
# Sharpe: -0.253
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 380         |
# |    iterations         | 2800        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -3.36       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2799        |
# |    policy_loss        | 0.0508      |
# |    reward             | 0.003785681 |
# |    std                | 1.3         |
# |    value_loss         | 0.000278    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 2900       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -3.38      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | 0.17       |
# |    reward             | 0.04984202 |
# |    std                | 1.32       |
# |    value_loss         | 0.00426    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 381         |
# |    iterations         | 3000        |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -3.41       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | 1.25        |
# |    reward             | -0.04634346 |
# |    std                | 1.33        |
# |    value_loss         | 0.0702      |
# ---------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.16088429722917935
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[453.00296   147.84785   456.07748   -65.         41.          3.1223817
#     3.5969906 150.08386   460.46967   138.79756   440.25177    66.72007
#    53.663345   95.9077     88.63725    37.719433   16.09081   141.26389
#   448.91983   136.4055    442.09937  ]]
# ============================================
# turbulence_threshold:  18.96247884362481
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 365          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0319      |
# |    reward             | -0.016985666 |
# |    std                | 1.03         |
# |    value_loss         | 0.000304     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 375         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.0301     |
# |    reward             | 0.048863042 |
# |    std                | 1.04        |
# |    value_loss         | 0.000886    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 373         |
# |    iterations         | 300         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.683      |
# |    reward             | -0.24638687 |
# |    std                | 1.04        |
# |    value_loss         | 0.122       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 360        |
# |    iterations         | 400        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -0.849     |
# |    reward             | 0.19764787 |
# |    std                | 1.04       |
# |    value_loss         | 0.271      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 335       |
# |    iterations         | 500       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.94     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -1.76     |
# |    reward             | 3.6100132 |
# |    std                | 1.05      |
# |    value_loss         | 1.77      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 339           |
# |    iterations         | 600           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.93         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.0606        |
# |    reward             | -0.0024479888 |
# |    std                | 1.05          |
# |    value_loss         | 0.0012        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 346         |
# |    iterations         | 700         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.95       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 0.0415      |
# |    reward             | 0.003942516 |
# |    std                | 1.06        |
# |    value_loss         | 0.000397    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 352        |
# |    iterations         | 800        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.96      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 0.0422     |
# |    reward             | 0.02264601 |
# |    std                | 1.06       |
# |    value_loss         | 0.00191    |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 355       |
# |    iterations         | 900       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.97     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.383    |
# |    reward             | 0.3016748 |
# |    std                | 1.07      |
# |    value_loss         | 0.0191    |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 359        |
# |    iterations         | 1000       |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.98      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -0.383     |
# |    reward             | -0.5711109 |
# |    std                | 1.07       |
# |    value_loss         | 0.225      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 359         |
# |    iterations         | 1100        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -2.98       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 2.82        |
# |    reward             | -0.44780654 |
# |    std                | 1.08        |
# |    value_loss         | 1.33        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 356          |
# ...
# |    entropy_loss       | -3.08        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.129        |
# |    reward             | -0.030376023 |
# |    std                | 1.13         |
# |    value_loss         | 0.00139      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 405          |
# |    iterations         | 800          |
# |    time_elapsed       | 9            |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 0.13         |
# |    reward             | -0.006325003 |
# |    std                | 1.14         |
# |    value_loss         | 0.00187      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 404          |
# |    iterations         | 900          |
# |    time_elapsed       | 11           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.12        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.056       |
# |    reward             | -0.003460814 |
# |    std                | 1.15         |
# |    value_loss         | 0.00266      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 402        |
# |    iterations         | 1000       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -3.14      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 0.32       |
# |    reward             | 0.02810632 |
# |    std                | 1.16       |
# |    value_loss         | 0.0183     |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 401       |
# |    iterations         | 1100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.406     |
# |    reward             | 0.1045617 |
# |    std                | 1.16      |
# |    value_loss         | 0.0303    |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 402          |
# |    iterations         | 1200         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -3.16        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | -0.0123      |
# |    reward             | 0.0009041828 |
# |    std                | 1.17         |
# |    value_loss         | 3.03e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 403          |
# |    iterations         | 1300         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -3.18        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | -0.0916      |
# |    reward             | -0.004822111 |
# |    std                | 1.19         |
# |    value_loss         | 0.000765     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 404         |
# |    iterations         | 1400        |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -3.21       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -0.237      |
# |    reward             | 0.044805218 |
# |    std                | 1.21        |
# |    value_loss         | 0.00747     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 400          |
# |    iterations         | 1500         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -3.22        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 0.122        |
# |    reward             | -0.072734386 |
# |    std                | 1.21         |
# |    value_loss         | 0.0046       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 395         |
# |    iterations         | 1600        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -3.23       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -1.02       |
# |    reward             | -0.20979895 |
# |    std                | 1.22        |
# |    value_loss         | 0.219       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 396        |
# |    iterations         | 1700       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -3.23      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -1.66      |
# |    reward             | -0.4215917 |
# |    std                | 1.22       |
# |    value_loss         | 0.564      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 396          |
# |    iterations         | 1800         |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -3.25        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | 0.0339       |
# |    reward             | -0.020155737 |
# |    std                | 1.23         |
# |    value_loss         | 0.000228     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 392         |
# |    iterations         | 1900        |
# |    time_elapsed       | 24          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -3.27       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 0.0863      |
# |    reward             | 0.023581665 |
# |    std                | 1.24        |
# |    value_loss         | 0.00117     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 388         |
# |    iterations         | 2000        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.29       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 1.1         |
# |    reward             | -0.14192705 |
# |    std                | 1.25        |
# |    value_loss         | 0.126       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 385         |
# |    iterations         | 2100        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -3.28       |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | 1.51        |
# |    reward             | -0.04621662 |
# |    std                | 1.25        |
# |    value_loss         | 0.197       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 375          |
# |    iterations         | 2200         |
# |    time_elapsed       | 29           |
# |    total_timesteps    | 11000        |
# | train/                |              |
# |    entropy_loss       | -3.28        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2199         |
# |    policy_loss        | 2.97         |
# |    reward             | -0.003433938 |
# |    std                | 1.25         |
# |    value_loss         | 1.38         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 367        |
# |    iterations         | 2300       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -3.28      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -3.21      |
# |    reward             | -0.5660526 |
# |    std                | 1.25       |
# |    value_loss         | 1.66       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 366          |
# |    iterations         | 2400         |
# |    time_elapsed       | 32           |
# |    total_timesteps    | 12000        |
# | train/                |              |
# |    entropy_loss       | -3.29        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | 0.0795       |
# |    reward             | 0.0086752325 |
# |    std                | 1.26         |
# |    value_loss         | 0.000744     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 358           |
# |    iterations         | 2500          |
# |    time_elapsed       | 34            |
# |    total_timesteps    | 12500         |
# | train/                |               |
# |    entropy_loss       | -3.32         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2499          |
# |    policy_loss        | -0.0126       |
# |    reward             | -0.0057677617 |
# |    std                | 1.27          |
# |    value_loss         | 4.2e-05       |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 355        |
# |    iterations         | 2600       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -3.32      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | -0.0886    |
# |    reward             | 0.11576827 |
# |    std                | 1.28       |
# |    value_loss         | 0.00828    |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 351          |
# |    iterations         | 2700         |
# |    time_elapsed       | 38           |
# |    total_timesteps    | 13500        |
# | train/                |              |
# |    entropy_loss       | -3.36        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2699         |
# |    policy_loss        | 0.215        |
# |    reward             | -0.021617152 |
# |    std                | 1.3          |
# |    value_loss         | 0.0116       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 349         |
# |    iterations         | 2800        |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -3.36       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2799        |
# |    policy_loss        | 2.38        |
# |    reward             | -0.15732838 |
# |    std                | 1.3         |
# |    value_loss         | 0.439       |
# ---------------------------------------
# day: 2896, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -392377.09
# total_reward: -402377.09
# total_cost: 622.98
# total_trades: 2988
# Sharpe: 0.320
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 343           |
# |    iterations         | 2900          |
# |    time_elapsed       | 42            |
# |    total_timesteps    | 14500         |
# | train/                |               |
# |    entropy_loss       | -3.36         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2899          |
# |    policy_loss        | 0.21          |
# |    reward             | -0.0016980296 |
# |    std                | 1.3           |
# |    value_loss         | 0.00503       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 339          |
# |    iterations         | 3000         |
# |    time_elapsed       | 44           |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -3.37        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | 0.121        |
# |    reward             | -0.015384593 |
# |    std                | 1.3          |
# |    value_loss         | 0.00164      |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.35063976886580384
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 4.8100305e+04  1.5568901e+02  6.4801355e+02  5.0000000e+00
#   -7.5000000e+01  9.6467745e-01  2.7344009e+01  1.6118152e+02
#    6.8647925e+02  1.4802783e+02  5.5121216e+02  4.9942398e+01
#    6.7751953e+01  3.0670862e+01  9.1102585e+01  4.2563453e+00
#    5.3900658e+01  1.5406818e+02  5.9265698e+02  1.5493849e+02
#    5.5401251e+02]]
# Ensemble Strategy took:  2.8980212012926736  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C   0.105516          0           0
# 1  189  2021-04-06  2021-07-06        A2C  -0.160884          0           0
# 2  252  2021-07-06  2021-10-04        A2C  -0.136856          0           0
# 3  315  2021-10-04  2022-01-03        A2C   -0.35064          0           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.3686281448982773

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10008.165002  2021-04-07      0.000817  2021-04-07
# 2    9992.952415  2021-04-08     -0.001520  2021-04-08
# 3    9964.164191  2021-04-09     -0.002881  2021-04-09
# 4    9974.199775  2021-04-12      0.001007  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.316284
# Cumulative returns    -0.316284
# Annual volatility      9.946716
# Sharpe ratio          -1.368628
# Calmar ratio          -0.302171
# Stability                   NaN
# Max drawdown          -1.046706
# Omega ratio            0.457743
# Sortino ratio         -1.428172
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.128631
# Daily value at risk   -1.307190
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-31.628%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-31.628%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>994.672%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.37</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.30</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-104.671%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.43</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-130.719%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-1.66</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>104.67</td>
#       <td>2021-10-12</td>
#       <td>2021-12-27</td>
#       <td>2022-01-20</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>63.44</td>
#       <td>2022-01-27</td>
#       <td>2022-03-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.66</td>
#       <td>2021-06-02</td>
#       <td>2021-08-19</td>
#       <td>2021-10-11</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.22</td>
#       <td>2022-01-25</td>
#       <td>2022-01-26</td>
#       <td>2022-01-27</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.16</td>
#       <td>2021-04-07</td>
#       <td>2021-05-12</td>
#       <td>2021-05-28</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-5.40%</td>
#       <td>-811.25%</td>
#       <td>215.35%</td>
#     </tr>
#   </tbody>
# </table>
