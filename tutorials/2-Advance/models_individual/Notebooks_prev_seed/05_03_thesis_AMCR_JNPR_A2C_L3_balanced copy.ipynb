# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AMCR','JNPR']
print(DOW_30_TICKER)
# Out:
# ['AMCR', 'JNPR']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (5591, 8)

# %%
df['tic'].value_counts()
# Out:
# JNPR    3063
# AMCR    2528
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high    low      close    volume   tic  day
# 5586  2022-05-26  30.190001  30.940001  30.18  29.994238   3476800  JNPR    3
# 5587  2022-05-27  13.190000  13.310000  13.12  13.040057   8531400  AMCR    4
# 5588  2022-05-27  30.980000  31.230000  30.77  30.581974   2867000  JNPR    4
# 5589  2022-05-31  13.170000  13.260000  13.01  12.834316  35769100  AMCR    1
# 5590  2022-05-31  30.860001  30.950001  30.41  30.256529   5073000  JNPR    1

# %%
df.shape
# Out:
# (5591, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  30.809999  31.080000  30.209999  24.890249  3832100  JNPR    3
# 1  2010-04-05  30.780001  30.930000  30.430000  25.225388  7685900  JNPR    0
# 2  2010-04-06  30.610001  31.770000  30.430000  25.862968  8171100  JNPR    1
# 3  2010-04-07  31.520000  31.870001  31.320000  25.740353  6328300  JNPR    2
# 4  2010-04-08  31.420000  31.490000  30.670000  25.560534  6908900  JNPR    3

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# JNPR    3063
# AMCR    2528
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# JNPR    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 15_000, 
                 'ppo' : 0, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 None,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  12.043048887802687
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 149          |
# |    iterations         | 100          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -1.49        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0262      |
# |    reward             | -0.006488786 |
# |    std                | 1.07         |
# |    value_loss         | 0.000216     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 230         |
# |    iterations         | 200         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -1.51       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.00799     |
# |    reward             | 0.003069021 |
# |    std                | 1.1         |
# |    value_loss         | 0.000143    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 279          |
# |    iterations         | 300          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -1.54        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | -0.00268     |
# |    reward             | -0.015092067 |
# |    std                | 1.13         |
# |    value_loss         | 1.44e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 321           |
# |    iterations         | 400           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -1.56         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -0.00807      |
# |    reward             | -0.0016871509 |
# |    std                | 1.16          |
# |    value_loss         | 8.98e-05      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 346         |
# |    iterations         | 500         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -1.59       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 0.00313     |
# |    reward             | 0.038342934 |
# |    std                | 1.18        |
# |    value_loss         | 0.000273    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 368           |
# |    iterations         | 600           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -1.61         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.00641       |
# |    reward             | -0.0008556076 |
# |    std                | 1.21          |
# |    value_loss         | 3.98e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 386           |
# |    iterations         | 700           |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -1.62         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.0159       |
# |    reward             | -0.0019239559 |
# |    std                | 1.23          |
# |    value_loss         | 0.000188      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 401           |
# |    iterations         | 800           |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -1.65         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.00253      |
# |    reward             | -0.0025670042 |
# |    std                | 1.26          |
# |    value_loss         | 1.3e-05       |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 412            |
# |    iterations         | 900            |
# |    time_elapsed       | 10             |
# |    total_timesteps    | 4500           |
# | train/                |                |
# |    entropy_loss       | -1.67          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 899            |
# |    policy_loss        | 0.0167         |
# |    reward             | -0.00083271525 |
# |    std                | 1.28           |
# |    value_loss         | 0.000228       |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 421         |
# |    iterations         | 1000        |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -1.66       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 0.00311     |
# |    reward             | 0.001025194 |
# |    std                | 1.27        |
# |    value_loss         | 0.000182    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 427           |
# |    iterations         | 1100          |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -1.67         |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.0418       |
# |    reward             | -0.0048151934 |
# |    std                | 1.29          |
# |    value_loss         | 0.000773      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 434         |
# |    iterations         | 1200        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -1.69       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -0.035      |
# |    reward             | -0.03872697 |
# |    std                | 1.31        |
# |    value_loss         | 0.000439    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 441        |
# |    iterations         | 1300       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -1.71      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 0.0192     |
# |    reward             | 0.06603023 |
# |    std                | 1.34       |
# |    value_loss         | 0.000146   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 447         |
# |    iterations         | 1400        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -1.73       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -0.0349     |
# |    reward             | -0.00208177 |
# |    std                | 1.36        |
# |    value_loss         | 0.000623    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 451          |
# |    iterations         | 1500         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -1.75        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | -0.0243      |
# |    reward             | -0.010043958 |
# |    std                | 1.39         |
# |    value_loss         | 0.000202     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 454          |
# |    iterations         | 1600         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -1.76        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.0213      |
# |    reward             | 0.0056126826 |
# |    std                | 1.41         |
# |    value_loss         | 0.000178     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 459          |
# |    iterations         | 1700         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -1.79        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 0.00754      |
# |    reward             | -0.015334588 |
# |    std                | 1.45         |
# |    value_loss         | 9.74e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 463         |
# |    iterations         | 1800        |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -1.82       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -0.0111     |
# |    reward             | 0.008966832 |
# |    std                | 1.49        |
# |    value_loss         | 6.41e-05    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 467         |
# |    iterations         | 1900        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -1.85       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 0.00976     |
# |    reward             | 0.012162183 |
# |    std                | 1.53        |
# |    value_loss         | 0.000109    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 469          |
# |    iterations         | 2000         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -1.87        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1999         |
# |    policy_loss        | 0.009        |
# |    reward             | -0.004132593 |
# |    std                | 1.58         |
# |    value_loss         | 0.000181     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 471         |
# |    iterations         | 2100        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -1.88       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | 0.0205      |
# |    reward             | -0.03019585 |
# |    std                | 1.59        |
# |    value_loss         | 0.000174    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 473           |
# |    iterations         | 2200          |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 11000         |
# | train/                |               |
# |    entropy_loss       | -1.9          |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2199          |
# |    policy_loss        | -0.0112       |
# |    reward             | -0.0012388547 |
# |    std                | 1.62          |
# |    value_loss         | 0.000112      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 475           |
# |    iterations         | 2300          |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 11500         |
# | train/                |               |
# |    entropy_loss       | -1.91         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2299          |
# |    policy_loss        | 0.0412        |
# |    reward             | -0.0025998063 |
# |    std                | 1.64          |
# |    value_loss         | 0.000576      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 477          |
# |    iterations         | 2400         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 12000        |
# | train/                |              |
# |    entropy_loss       | -1.93        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | 0.0185       |
# |    reward             | 0.0026662012 |
# |    std                | 1.67         |
# |    value_loss         | 0.000273     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 479          |
# |    iterations         | 2500         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 12500        |
# | train/                |              |
# |    entropy_loss       | -1.95        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2499         |
# |    policy_loss        | 0.00231      |
# |    reward             | -0.014878214 |
# |    std                | 1.7          |
# |    value_loss         | 0.000297     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 481          |
# |    iterations         | 2600         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -1.98        |
# |    explained_variance | 1.79e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | -0.0703      |
# |    reward             | -0.006947362 |
# |    std                | 1.76         |
# |    value_loss         | 0.00121      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 484          |
# |    iterations         | 2700         |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 13500        |
# | train/                |              |
# |    entropy_loss       | -1.99        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2699         |
# |    policy_loss        | 0.0889       |
# |    reward             | 0.0019152529 |
# |    std                | 1.78         |
# |    value_loss         | 0.00224      |
# ----------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 9000.00
# total_reward: -1000.00
# total_cost: 101.33
# total_trades: 2707
# Sharpe: 0.057
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 484         |
# |    iterations         | 2800        |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -2.02       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2799        |
# |    policy_loss        | -0.0312     |
# |    reward             | 0.012504647 |
# |    std                | 1.83        |
# |    value_loss         | 0.000856    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 487          |
# |    iterations         | 2900         |
# |    time_elapsed       | 29           |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -2.05        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | -0.04        |
# |    reward             | -0.038860343 |
# |    std                | 1.88         |
# |    value_loss         | 0.00131      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 488         |
# |    iterations         | 3000        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -2.08       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | 0.0114      |
# |    reward             | 0.003887956 |
# |    std                | 1.93        |
# |    value_loss         | 0.000292    |
# ---------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  -0.20421556614683642
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.0000000e+04 2.4394411e+01 0.0000000e+00 3.0838424e-01 2.4958952e+01
#   2.3238611e+01 5.6291092e+01 7.8713943e+01 1.9371996e+01 2.3590782e+01
#   2.3505814e+01]]
# ============================================
# turbulence_threshold:  12.043048887802687
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 529          |
# |    iterations         | 100          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -1.48        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0204      |
# |    reward             | -0.006490512 |
# |    std                | 1.06         |
# |    value_loss         | 0.000221     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 529         |
# |    iterations         | 200         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -1.52       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.00881     |
# |    reward             | 0.001900074 |
# |    std                | 1.11        |
# |    value_loss         | 5.6e-05     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 529          |
# |    iterations         | 300          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -1.56        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | -0.000131    |
# |    reward             | -0.011015145 |
# |    std                | 1.15         |
# |    value_loss         | 4.81e-06     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 534           |
# |    iterations         | 400           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -1.59         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -0.00792      |
# |    reward             | -0.0010690212 |
# |    std                | 1.18          |
# |    value_loss         | 4.26e-05      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 530         |
# |    iterations         | 500         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -1.62       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 0.0042      |
# |    reward             | 0.024410678 |
# |    std                | 1.22        |
# |    value_loss         | 9.8e-05     |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 534           |
# |    iterations         | 600           |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -1.64         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.0229        |
# |    reward             | -0.0026475452 |
# |    std                | 1.25          |
# |    value_loss         | 0.000247      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 535         |
# |    iterations         | 700         |
# |    time_elapsed       | 6           |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -1.67       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 0.00202     |
# |    reward             | 0.014080698 |
# |    std                | 1.29        |
# |    value_loss         | 1.11e-05    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 535           |
# |    iterations         | 800           |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -1.7          |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.00202      |
# |    reward             | -0.0041253413 |
# |    std                | 1.33          |
# |    value_loss         | 1.53e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 533          |
# |    iterations         | 900          |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -1.73        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.0109      |
# |    reward             | -0.004271785 |
# |    std                | 1.37         |
# |    value_loss         | 6.05e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 535           |
# |    iterations         | 1000          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -1.77         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | 0.0345        |
# |    reward             | -0.0014478035 |
# |    std                | 1.43          |
# |    value_loss         | 0.000538      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 536           |
# |    iterations         | 1100          |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -1.83         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.0644       |
# |    reward             | -0.0017365093 |
# |    std                | 1.5           |
# |    value_loss         | 0.000543      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 535         |
# |    iterations         | 1200        |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -1.86       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -0.0345     |
# |    reward             | 0.008142713 |
# |    std                | 1.56        |
# |    value_loss         | 0.00039     |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 537           |
# |    iterations         | 1300          |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -1.9          |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -0.0576       |
# |    reward             | -0.0026628496 |
# |    std                | 1.62          |
# |    value_loss         | 0.00132       |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 537         |
# |    iterations         | 1400        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -1.94       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 0.0479      |
# |    reward             | 0.005693246 |
# |    std                | 1.69        |
# |    value_loss         | 0.000416    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 537          |
# |    iterations         | 1500         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -1.99        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 0.000606     |
# |    reward             | 0.0023594713 |
# |    std                | 1.77         |
# |    value_loss         | 3.29e-06     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 537          |
# |    iterations         | 1600         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -2.04        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.00368     |
# |    reward             | 0.0015224767 |
# |    std                | 1.87         |
# |    value_loss         | 4.22e-06     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 536          |
# |    iterations         | 1700         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -2.07        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | -0.0089      |
# |    reward             | 0.0007752192 |
# |    std                | 1.92         |
# |    value_loss         | 1.82e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 536         |
# |    iterations         | 1800        |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -2.12       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -0.00727    |
# |    reward             | 0.003323712 |
# |    std                | 2.01        |
# |    value_loss         | 2.39e-05    |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 536            |
# |    iterations         | 1900           |
# |    time_elapsed       | 17             |
# |    total_timesteps    | 9500           |
# | train/                |                |
# |    entropy_loss       | -2.15          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1899           |
# |    policy_loss        | 0.0288         |
# |    reward             | -0.00077694387 |
# |    std                | 2.07           |
# |    value_loss         | 0.000145       |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 535         |
# |    iterations         | 2000        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -2.19       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.00144     |
# |    reward             | 0.006351965 |
# |    std                | 2.16        |
# |    value_loss         | 2.63e-05    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 535         |
# |    iterations         | 2100        |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -2.24       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | -0.0179     |
# |    reward             | 0.009364153 |
# |    std                | 2.26        |
# |    value_loss         | 0.000134    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 536         |
# |    iterations         | 2200        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -2.27       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | -0.00809    |
# |    reward             | 0.003543882 |
# |    std                | 2.35        |
# |    value_loss         | 2.75e-05    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 535          |
# |    iterations         | 2300         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 11500        |
# | train/                |              |
# |    entropy_loss       | -2.32        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2299         |
# |    policy_loss        | -0.00625     |
# |    reward             | 0.0073109497 |
# |    std                | 2.46         |
# |    value_loss         | 0.000132     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 536          |
# |    iterations         | 2400         |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 12000        |
# | train/                |              |
# |    entropy_loss       | -2.36        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | -0.0345      |
# |    reward             | 0.0034927377 |
# |    std                | 2.57         |
# |    value_loss         | 0.000266     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 536         |
# |    iterations         | 2500        |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -2.4        |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 0.00846     |
# |    reward             | 0.011131433 |
# |    std                | 2.68        |
# |    value_loss         | 2.98e-05    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 535           |
# |    iterations         | 2600          |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 13000         |
# | train/                |               |
# |    entropy_loss       | -2.44         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2599          |
# |    policy_loss        | -0.00432      |
# |    reward             | -0.0034190065 |
# |    std                | 2.78          |
# |    value_loss         | 1.44e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 535           |
# |    iterations         | 2700          |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 13500         |
# | train/                |               |
# |    entropy_loss       | -2.47         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2699          |
# |    policy_loss        | 0.0136        |
# |    reward             | -0.0064560217 |
# |    std                | 2.86          |
# |    value_loss         | 4.29e-05      |
# -----------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 8504.16
# total_reward: -1495.84
# total_cost: 122.10
# total_trades: 2770
# Sharpe: -0.052
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 534        |
# |    iterations         | 2800       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -2.51      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | -0.0116    |
# |    reward             | 0.00334922 |
# |    std                | 2.99       |
# |    value_loss         | 8.23e-05   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 534         |
# |    iterations         | 2900        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -2.54       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | 0.0134      |
# |    reward             | 0.010319226 |
# |    std                | 3.07        |
# |    value_loss         | 4.19e-05    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 534           |
# |    iterations         | 3000          |
# |    time_elapsed       | 28            |
# |    total_timesteps    | 15000         |
# | train/                |               |
# |    entropy_loss       | -2.56         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2999          |
# |    policy_loss        | 0.144         |
# |    reward             | -0.0061929836 |
# |    std                | 3.14          |
# |    value_loss         | 0.00232       |
# -----------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.1693734093887267
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 2.0084340e+04  2.6078335e+01 -4.1600000e+02  7.6819412e-02
#    2.7859289e+01  2.5562860e+01  5.2549217e+01 -4.1669506e+01
#    1.4199882e+01  2.6381594e+01  2.5597965e+01]]
# ============================================
# turbulence_threshold:  12.043048887802687
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_1
# -----------------------------------------
# | time/                 |               |
# |    fps                | 539           |
# |    iterations         | 100           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -1.47         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | -0.0228       |
# |    reward             | -0.0074280947 |
# |    std                | 1.05          |
# |    value_loss         | 0.000278      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 531          |
# |    iterations         | 200          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -1.51        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.0134       |
# |    reward             | 0.0050434824 |
# |    std                | 1.09         |
# |    value_loss         | 0.000389     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 538         |
# |    iterations         | 300         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -1.52       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.022      |
# |    reward             | -0.03426106 |
# |    std                | 1.11        |
# |    value_loss         | 0.000183    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 539           |
# |    iterations         | 400           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -1.54         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -0.0259       |
# |    reward             | -0.0054727765 |
# |    std                | 1.13          |
# |    value_loss         | 0.000757      |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 540       |
# |    iterations         | 500       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.55     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.0362    |
# |    reward             | 0.1338784 |
# |    std                | 1.14      |
# |    value_loss         | 0.00421   |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 540         |
# |    iterations         | 600         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -1.56       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 0.00322     |
# |    reward             | 0.004995207 |
# |    std                | 1.16        |
# |    value_loss         | 0.000182    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 540           |
# |    iterations         | 700           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -1.58         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.00694       |
# |    reward             | -0.0014396473 |
# |    std                | 1.17          |
# |    value_loss         | 1.94e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 532          |
# |    iterations         | 800          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -1.6         |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | -0.0055      |
# |    reward             | -0.006758184 |
# |    std                | 1.2          |
# |    value_loss         | 5.95e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 526         |
# |    iterations         | 900         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -1.63       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 0.0247      |
# |    reward             | 0.001287289 |
# |    std                | 1.23        |
# |    value_loss         | 0.000391    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 525           |
# |    iterations         | 1000          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -1.66         |
# |    explained_variance | 2.38e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | -0.0229       |
# |    reward             | -0.0047693667 |
# |    std                | 1.27          |
# |    value_loss         | 0.000102      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 525          |
# |    iterations         | 1100         |
# ...
# |    policy_loss        | 0.0216       |
# |    reward             | 0.0027492193 |
# |    std                | 1.14         |
# |    value_loss         | 0.000395     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 525          |
# |    iterations         | 800          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -1.58        |
# |    explained_variance | -2.38e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | -0.00359     |
# |    reward             | -0.009029442 |
# |    std                | 1.17         |
# |    value_loss         | 1.01e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 524           |
# |    iterations         | 900           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -1.61         |
# |    explained_variance | 1.79e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | -0.00934      |
# |    reward             | 0.00045133047 |
# |    std                | 1.21          |
# |    value_loss         | 5.22e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 524           |
# |    iterations         | 1000          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -1.66         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | 0.0266        |
# |    reward             | -0.0014806235 |
# |    std                | 1.27          |
# |    value_loss         | 0.000543      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 524          |
# |    iterations         | 1100         |
# |    time_elapsed       | 10           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -1.69        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.0157       |
# |    reward             | -0.004502406 |
# |    std                | 1.32         |
# |    value_loss         | 0.000101     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 524           |
# |    iterations         | 1200          |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -1.73         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | 0.00765       |
# |    reward             | 0.00077688234 |
# |    std                | 1.36          |
# |    value_loss         | 4.07e-05      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 524            |
# |    iterations         | 1300           |
# |    time_elapsed       | 12             |
# |    total_timesteps    | 6500           |
# | train/                |                |
# |    entropy_loss       | -1.76          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1299           |
# |    policy_loss        | -0.0357        |
# |    reward             | -0.00026580578 |
# |    std                | 1.4            |
# |    value_loss         | 0.000245       |
# ------------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 524      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0284  |
# |    reward             | 0.017232 |
# |    std                | 1.43     |
# |    value_loss         | 0.000261 |
# ------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 524            |
# |    iterations         | 1500           |
# |    time_elapsed       | 14             |
# |    total_timesteps    | 7500           |
# | train/                |                |
# |    entropy_loss       | -1.81          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1499           |
# |    policy_loss        | 5.3e-05        |
# |    reward             | -0.00013841814 |
# |    std                | 1.49           |
# |    value_loss         | 7.5e-06        |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 525          |
# |    iterations         | 1600         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -1.84        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.00672     |
# |    reward             | -0.006588752 |
# |    std                | 1.53         |
# |    value_loss         | 6.12e-05     |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 524            |
# |    iterations         | 1700           |
# |    time_elapsed       | 16             |
# |    total_timesteps    | 8500           |
# | train/                |                |
# |    entropy_loss       | -1.89          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1699           |
# |    policy_loss        | 0.0025         |
# |    reward             | -0.00016377408 |
# |    std                | 1.6            |
# |    value_loss         | 9.38e-06       |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 525         |
# |    iterations         | 1800        |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -1.92       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 0.0151      |
# |    reward             | 0.007646088 |
# |    std                | 1.66        |
# |    value_loss         | 0.000125    |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 526            |
# |    iterations         | 1900           |
# |    time_elapsed       | 18             |
# |    total_timesteps    | 9500           |
# | train/                |                |
# |    entropy_loss       | -1.96          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1899           |
# |    policy_loss        | 0.0274         |
# |    reward             | -1.5637125e-06 |
# |    std                | 1.71           |
# |    value_loss         | 0.000151       |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 528          |
# |    iterations         | 2000         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -1.99        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1999         |
# |    policy_loss        | 0.00659      |
# |    reward             | 0.0038526452 |
# |    std                | 1.76         |
# |    value_loss         | 1.46e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 527          |
# |    iterations         | 2100         |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 10500        |
# | train/                |              |
# |    entropy_loss       | -2.01        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2099         |
# |    policy_loss        | -0.0194      |
# |    reward             | -0.004038509 |
# |    std                | 1.81         |
# |    value_loss         | 9.76e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 527           |
# |    iterations         | 2200          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 11000         |
# | train/                |               |
# |    entropy_loss       | -2.06         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2199          |
# |    policy_loss        | 0.00834       |
# |    reward             | -0.0076590176 |
# |    std                | 1.89          |
# |    value_loss         | 5.36e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 526           |
# |    iterations         | 2300          |
# |    time_elapsed       | 21            |
# |    total_timesteps    | 11500         |
# | train/                |               |
# |    entropy_loss       | -2.1          |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2299          |
# |    policy_loss        | -0.0037       |
# |    reward             | 0.00062203984 |
# |    std                | 1.97          |
# |    value_loss         | 1.51e-05      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 526         |
# |    iterations         | 2400        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -2.14       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2399        |
# |    policy_loss        | 0.0342      |
# |    reward             | 0.011266868 |
# |    std                | 2.05        |
# |    value_loss         | 0.000244    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 527          |
# |    iterations         | 2500         |
# |    time_elapsed       | 23           |
# |    total_timesteps    | 12500        |
# | train/                |              |
# |    entropy_loss       | -2.18        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2499         |
# |    policy_loss        | -0.00644     |
# |    reward             | 0.0051677157 |
# |    std                | 2.13         |
# |    value_loss         | 1e-05        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 528       |
# |    iterations         | 2600      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -2.21     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.00191  |
# |    reward             | 0.0344118 |
# |    std                | 2.21      |
# |    value_loss         | 1.61e-05  |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 528          |
# |    iterations         | 2700         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 13500        |
# | train/                |              |
# |    entropy_loss       | -2.25        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2699         |
# |    policy_loss        | 0.0136       |
# |    reward             | 0.0064443043 |
# |    std                | 2.29         |
# |    value_loss         | 0.000127     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 528           |
# |    iterations         | 2800          |
# |    time_elapsed       | 26            |
# |    total_timesteps    | 14000         |
# | train/                |               |
# |    entropy_loss       | -2.29         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2799          |
# |    policy_loss        | -0.0326       |
# |    reward             | -0.0049083047 |
# |    std                | 2.38          |
# |    value_loss         | 0.000279      |
# -----------------------------------------
# day: 2896, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 7631.02
# total_reward: -2368.98
# total_cost: 125.16
# total_trades: 2896
# Sharpe: -0.120
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 528          |
# |    iterations         | 2900         |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -2.33        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | 0.0246       |
# |    reward             | -0.011646319 |
# |    std                | 2.48         |
# |    value_loss         | 0.000212     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 528          |
# |    iterations         | 3000         |
# |    time_elapsed       | 28           |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -2.35        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | 0.0689       |
# |    reward             | -0.018300494 |
# |    std                | 2.55         |
# |    value_loss         | 0.00054      |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.49492056418314084
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.95351777e+04  3.44254227e+01 -3.98000000e+02  1.00107288e+00
#    3.53951797e+01  3.07549877e+01  6.53524704e+01  1.21200935e+02
#    4.64443741e+01  3.22997971e+01  3.06517143e+01]]
# Ensemble Strategy took:  1.9473743160565695  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C  -0.204216          0           0
# 1  189  2021-04-06  2021-07-06        A2C  -0.169373          0           0
# 2  252  2021-07-06  2021-10-04        A2C  -0.069953          0           0
# 3  315  2021-10-04  2022-01-03        A2C  -0.494921          0           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.439578443921305

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1    9999.823023  2021-04-07     -0.000018  2021-04-07
# 2    9919.480031  2021-04-08     -0.008034  2021-04-08
# 3    9993.563309  2021-04-09      0.007468  2021-04-09
# 4    9954.415761  2021-04-12     -0.003917  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.482591
# Cumulative returns    -0.482591
# Annual volatility      0.402068
# Sharpe ratio          -1.439578
# Calmar ratio          -0.924551
# Stability              0.859719
# Max drawdown          -0.521973
# Omega ratio            0.777728
# Sortino ratio         -1.788107
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.792513
# Daily value at risk   -0.052953
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-48.259%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-48.259%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>40.207%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.44</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.92</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-52.197%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.79</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-5.295%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.31</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-1.77</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>52.20</td>
#       <td>2021-04-22</td>
#       <td>2022-03-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.41</td>
#       <td>2021-04-06</td>
#       <td>2021-04-16</td>
#       <td>2021-04-20</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.90</td>
#       <td>2021-04-20</td>
#       <td>2021-04-21</td>
#       <td>2021-04-22</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.23%</td>
#       <td>-11.54%</td>
#       <td>6.91%</td>
#     </tr>
#   </tbody>
# </table>
