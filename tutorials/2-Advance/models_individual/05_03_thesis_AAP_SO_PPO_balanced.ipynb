# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AAP','SO']
print(DOW_30_TICKER)
# Out:
# ['AAP', 'SO']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AAP    3063
# SO     3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26   76.250000   76.300003   75.239998   73.851044  3561800
# 6122  2022-05-27  190.740005  194.830002  190.660004  187.697830   685700
# 6123  2022-05-27   75.110001   76.110001   75.059998   74.616142  3773800
# 6124  2022-05-31  191.229996  191.800003  188.250000  184.596283   987500
# 6125  2022-05-31   75.330002   75.989998   74.970001   74.213982  8118800
#
#       tic  day
# 6121   SO    3
# 6122  AAP    4
# 6123   SO    4
# 6124  AAP    1
# 6125   SO    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume  tic  day
# 0  2010-04-01  42.119999  42.459999  41.970001  39.038826   627600  AAP    3
# 1  2010-04-01  33.290001  33.450001  33.200001  18.761770  2661500   SO    3
# 2  2010-04-05  42.459999  42.970001  42.419998  39.324512   954500  AAP    0
# 3  2010-04-05  33.509998  33.520000  33.310001  18.801075  2126800   SO    0
# 4  2010-04-06  42.529999  42.810001  42.419998  39.223129   729200  AAP    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AAP    3063
# SO     3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AAP    3063
# SO     3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 seed=106,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 60_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  26.696271266447546
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# -------------------------------------
# | time/              |              |
# |    fps             | 275          |
# |    iterations      | 1            |
# |    time_elapsed    | 7            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.006655698 |
# -------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 319            |
# |    iterations           | 2              |
# |    time_elapsed         | 12             |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.005153917    |
# |    clip_fraction        | 0.0401         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | -1.4           |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0331        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00273       |
# |    reward               | -0.00029316932 |
# |    std                  | 1              |
# |    value_loss           | 0.00214        |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 330            |
# |    iterations           | 3              |
# |    time_elapsed         | 18             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | 0.0063175093   |
# |    clip_fraction        | 0.0455         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | 0.0528         |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0296        |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.00325       |
# |    reward               | -0.00076854555 |
# |    std                  | 1              |
# |    value_loss           | 0.00918        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0032860362 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00522      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0166      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00173     |
# |    reward               | -0.009723958 |
# |    std                  | 1            |
# |    value_loss           | 0.0391       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 5            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0018766304 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0285      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00115     |
# |    reward               | 0.03276958   |
# |    std                  | 1.01         |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 6            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0055218763 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00256     |
# |    reward               | 0.16088556   |
# |    std                  | 1.01         |
# |    value_loss           | 0.00786      |
# ------------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -17132.46
# total_reward: -27132.46
# total_cost: 287.13
# total_trades: 2716
# Sharpe: -0.379
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 7            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.006011038  |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0978       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0193      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00598     |
# |    reward               | 0.0046537356 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0165       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 8            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0044111083 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0978       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0108      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00231     |
# |    reward               | 0.001708333  |
# |    std                  | 1.01         |
# |    value_loss           | 0.0276       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 298           |
# |    iterations           | 9             |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0031578136  |
# |    clip_fraction        | 0.015         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.267         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0343       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00148      |
# |    reward               | -0.0031516638 |
# |    std                  | 1             |
# |    value_loss           | 0.00283       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 10          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.001961233 |
# |    clip_fraction        | 0.00571     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0256     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000299   |
# |    reward               | 0.02089676  |
# |    std                  | 1.01        |
# |    value_loss           | 0.000712    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 11           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0049702255 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0265      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00343     |
# |    reward               | 0.0021141556 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0059       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 12            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.0039928285  |
# |    clip_fraction        | 0.0227        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -0.354        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0266       |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00658      |
# |    reward               | -0.0021974794 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0128        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 13           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0031695464 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0259      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0016      |
# |    reward               | 0.004713356  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -2440.87
# total_reward: -12440.87
# total_cost: 332.45
# total_trades: 2698
# Sharpe: 0.677
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 14           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0029553995 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0215      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00191     |
# |    reward               | -0.008783031 |
# |    std                  | 1.02         |
# |    value_loss           | 0.000534     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 15            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.0043924777  |
# |    clip_fraction        | 0.0232        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.132         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0107       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.0011       |
# |    reward               | -0.0055635055 |
# |    std                  | 1.03          |
# |    value_loss           | 0.00127       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 16           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0058689397 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.0929       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0317      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00348     |
# |    reward               | 0.004180088  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 17           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.002937139  |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.0374       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0356      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00094     |
# |    reward               | 0.0049979403 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 18           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0032281983 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.029       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00169     |
# |    reward               | 0.0059106788 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00276      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 19           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0020668209 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0331      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 0.008099099  |
# |    std                  | 1.04         |
# |    value_loss           | 0.00213      |
# ------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -2314.44
# total_reward: -12314.44
# total_cost: 309.12
# total_trades: 2796
# Sharpe: -0.217
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 320           |
# |    iterations           | 20            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.0018209601  |
# |    clip_fraction        | 0.0136        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0.188         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0358       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -1.27e-05     |
# |    reward               | -0.0020119213 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00139       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 21           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0024969545 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.0841       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.035       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000102     |
# |    reward               | 0.010938226  |
# |    std                  | 1.05         |
# |    value_loss           | 0.00211      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 22           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010688729 |
# |    clip_fraction        | 0.00215      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0253      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 3.37e-05     |
# |    reward               | 0.0047203833 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 23           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0035222515 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0358      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00259     |
# |    reward               | -0.006171762 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 24           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033276128 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0301      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00039     |
# |    reward               | -0.023857187 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 25            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.0053290054  |
# |    clip_fraction        | 0.0326        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0.068         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0227       |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00234      |
# |    reward               | 0.00050019304 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00215       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 327           |
# |    iterations           | 26            |
# |    time_elapsed         | 162           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.0045428304  |
# |    clip_fraction        | 0.0321        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.166         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0417       |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00184      |
# |    reward               | -0.0086468235 |
# |    std                  | 1.04          |
# |    value_loss           | 0.000754      |
# -------------------------------------------
# day: 2707, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: -558.49
# total_reward: -10558.49
# total_cost: 329.25
# total_trades: 2732
# Sharpe: 0.011
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 27           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0017530713 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0273      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000262    |
# |    reward               | 0.002410244  |
# |    std                  | 1.05         |
# |    value_loss           | 0.000737     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 28           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0033293327 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.0384       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0452      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | 0.0013533066 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 29          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004223635 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.0372      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0261     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00193    |
# |    reward               | 0.046597145 |
# |    std                  | 1.05        |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 30           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0042558815 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.0397       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0284      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000549    |
# |    reward               | -0.016192857 |
# |    std                  | 1.06         |
# |    value_loss           | 0.00148      |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.08118170496168314
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.0000000e+04 1.7477837e+02 5.8874802e+01 0.0000000e+00 0.0000000e+00
#   4.1594982e+00 8.2961220e-01 1.8100262e+02 5.9040657e+01 1.6522977e+02
#   5.4726429e+01 5.8235188e+01 5.9995220e+01 5.7902229e+01 1.3995833e+02
#   1.8285650e+01 3.2865856e+01 1.6800638e+02 5.5969154e+01 1.6059996e+02
#   5.5722916e+01]]
# ============================================
# turbulence_threshold:  26.696271266447546
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 318          |
# |    iterations      | 1            |
# |    time_elapsed    | 6            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.006655698 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005153917 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -1.4        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0331     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00273    |
# |    reward               | 0.10070686  |
# |    std                  | 1           |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 373           |
# |    iterations           | 3             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00075682753 |
# |    clip_fraction        | 0.00659       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.0725        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0262       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000282     |
# |    reward               | 0.013376648   |
# |    std                  | 1             |
# |    value_loss           | 0.00845       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0035554995 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0148      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0013      |
# |    reward               | 0.025842525  |
# |    std                  | 1.01         |
# |    value_loss           | 0.0457       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.005106208  |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0323       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0182      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0029      |
# |    reward               | 0.0033757125 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00878      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0037689318 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0205      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000658    |
# |    reward               | 0.087753884  |
# |    std                  | 1.02         |
# |    value_loss           | 0.00257      |
# ------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -12083.41
# total_reward: -22083.41
# total_cost: 306.47
# total_trades: 2764
# Sharpe: -0.513
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 7            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0053816508 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.0842       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0168      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00112     |
# |    reward               | -0.044851787 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00618      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.002807144 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0124      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0017      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000764   |
# |    reward               | 0.13485274  |
# |    std                  | 1.02        |
# |    value_loss           | 0.0408      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0052421596 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.000129    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0468       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00256     |
# |    reward               | 0.053908013  |
# |    std                  | 1.02         |
# |    value_loss           | 0.131        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 10          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005066693 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.00373    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0243     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000255   |
# |    reward               | 0.068638586 |
# |    std                  | 1.01        |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 11          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004654954 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.000844   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0196     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00169    |
# |    reward               | 0.011808202 |
# |    std                  | 1.02        |
# |    value_loss           | 0.0363      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 12           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.005916163  |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 1.67e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.007        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000767    |
# |    reward               | -0.054033082 |
# |    std                  | 1.02         |
# |    value_loss           | 0.0333       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 13           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0031521535 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.000285    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0188      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00141     |
# |    reward               | 0.010883052  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0277       |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -12786.65
# total_reward: -22786.65
# total_cost: 288.35
# total_trades: 2610
# Sharpe: 0.372
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 14           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0036126277 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.000779    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0326      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00138     |
# |    reward               | -0.01237912  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0303       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 15           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0035458016 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.000193    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0211      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00137     |
# |    reward               | 0.0019771135 |
# |    std                  | 1.02         |
# |    value_loss           | 0.0363       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 16           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0034207376 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 8.15e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0212      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00141     |
# |    reward               | 0.050137065  |
# |    std                  | 1.02         |
# |    value_loss           | 0.024        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 17           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035312455 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.000349    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0346      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00163     |
# |    reward               | -0.010952443 |
# |    std                  | 1.02         |
# |    value_loss           | 0.0067       |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 391            |
# |    iterations           | 18             |
# |    time_elapsed         | 94             |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | 0.0052971686   |
# |    clip_fraction        | 0.0325         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.88          |
# |    explained_variance   | -0.000113      |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0233        |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -0.00175       |
# |    reward               | -0.00037545367 |
# |    std                  | 1.02           |
# |    value_loss           | 0.00893        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 19           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0056075742 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -9.47e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0162      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00374     |
# |    reward               | -0.009695488 |
# |    std                  | 1.03         |
# |    value_loss           | 0.034        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 20           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0025376747 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 2.49e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0104      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00135     |
# |    reward               | -0.11209406  |
# |    std                  | 1.03         |
# |    value_loss           | 0.0676       |
# ------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -22940.63
# total_reward: -32940.63
# total_cost: 332.44
# total_trades: 2872
# Sharpe: 0.347
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 21           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028453688 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0225      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00196     |
# |    reward               | -0.029529441 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0436       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 22          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004324047 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 3.13e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00172     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000672   |
# |    reward               | 0.021750104 |
# |    std                  | 1.03        |
# |    value_loss           | 0.0691      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 23           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0026577844 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -1.99e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0341       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00116     |
# |    reward               | 0.24989726   |
# |    std                  | 1.04         |
# |    value_loss           | 0.118        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 24           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033343846 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 2e-05        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0781       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000176     |
# |    reward               | 0.039446507  |
# |    std                  | 1.05         |
# |    value_loss           | 0.255        |
# ...
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00148     |
# |    reward               | 0.0011767538 |
# |    std                  | 0.994        |
# |    value_loss           | 0.0381       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 14           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0013208078 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0275       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00219     |
# |    reward               | -0.11165106  |
# |    std                  | 1.02         |
# |    value_loss           | 0.153        |
# ------------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -52584.08
# total_reward: -62584.08
# total_cost: 335.64
# total_trades: 2898
# Sharpe: 0.302
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 15          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004842138 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | -1.19e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0343      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00209    |
# |    reward               | 0.036579672 |
# |    std                  | 1.02        |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 16          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.000789865 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -1.88e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.018      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 5.14e-05    |
# |    reward               | 0.023643726 |
# |    std                  | 1.02        |
# |    value_loss           | 0.0366      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 17           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.003594228  |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -1.62e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00731     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00129     |
# |    reward               | 0.0035614888 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0606       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 18          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.00457016  |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.057       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00122    |
# |    reward               | -0.05767899 |
# |    std                  | 1.02        |
# |    value_loss           | 0.171       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 19           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035949207 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -3.4e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00749      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00055     |
# |    reward               | 0.080938846  |
# |    std                  | 1.02         |
# |    value_loss           | 0.0643       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 414           |
# |    iterations           | 20            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.005183721   |
# |    clip_fraction        | 0.0336        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -1.59e-05     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0156        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00231      |
# |    reward               | 0.00021436463 |
# |    std                  | 1.03          |
# |    value_loss           | 0.0895        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 21           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0042960094 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0236       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00187     |
# |    reward               | -0.03870753  |
# |    std                  | 1.03         |
# |    value_loss           | 0.121        |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -39968.85
# total_reward: -49968.85
# total_cost: 357.00
# total_trades: 3060
# Sharpe: 0.203
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 22           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0025250097 |
# |    clip_fraction        | 0.00728      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | -2e-05       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00718      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000332    |
# |    reward               | -0.004000187 |
# |    std                  | 1.03         |
# |    value_loss           | 0.071        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 23           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.00489073   |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | -2.66e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00315     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00247     |
# |    reward               | -0.010659666 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0711       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 24           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0046046977 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -2.01e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.000716    |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00222     |
# |    reward               | -0.09935343  |
# |    std                  | 1.03         |
# |    value_loss           | 0.0689       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 25           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0022159384 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00376      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 1.69e-05     |
# |    reward               | -0.005080934 |
# |    std                  | 1.04         |
# |    value_loss           | 0.0517       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 26           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0058758156 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -2.25e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00809     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00343     |
# |    reward               | -0.08328304  |
# |    std                  | 1.04         |
# |    value_loss           | 0.043        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 27           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.003983926  |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -2.61e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.012        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00193     |
# |    reward               | -0.005987928 |
# |    std                  | 1.04         |
# |    value_loss           | 0.101        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 28           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0045454046 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.118        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00345     |
# |    reward               | 0.427809     |
# |    std                  | 1.04         |
# |    value_loss           | 0.304        |
# ------------------------------------------
# day: 2896, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: -46124.03
# total_reward: -56124.03
# total_cost: 376.37
# total_trades: 3090
# Sharpe: -0.249
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 29           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0042007403 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0111       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0018      |
# |    reward               | -0.06970712  |
# |    std                  | 1.04         |
# |    value_loss           | 0.0911       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 30           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.003760423  |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0791       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00118     |
# |    reward               | -0.009324552 |
# |    std                  | 1.03         |
# |    value_loss           | 0.115        |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  -0.1776013306900034
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.5808099e+04  2.2855141e+02  6.5578415e+01 -2.8000000e+01
#   -1.7000000e+01  2.2212360e+00  1.2388204e+00  2.3396100e+02
#    6.6576752e+01  2.1962239e+02  6.1500790e+01  5.4848202e+01
#    6.2292408e+01  8.7469833e+01  9.7697365e+01  1.0172410e+01
#    3.4706688e+01  2.2423181e+02  6.2696644e+01  2.2135344e+02
#    6.1249172e+01]]
# Ensemble Strategy took:  11.567589163780212  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0  -0.081182           0
# 1  189  2021-04-06  2021-07-06        PPO          0  -0.349265           0
# 2  252  2021-07-06  2021-10-04        PPO          0     0.0673           0
# 3  315  2021-10-04  2022-01-03        PPO          0  -0.177601           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.360722967901006

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10000.000000  2021-04-07      0.000000  2021-04-07
# 2    9997.635491  2021-04-08     -0.000236  2021-04-08
# 3   10004.193725  2021-04-09      0.000656  2021-04-09
# 4   10015.131036  2021-04-12      0.001093  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.087576
# Cumulative returns    -0.087576
# Annual volatility      0.199955
# Sharpe ratio          -0.360723
# Calmar ratio          -0.437849
# Stability              0.528508
# Max drawdown          -0.200013
# Omega ratio            0.942762
# Sortino ratio         -0.517995
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.069105
# Daily value at risk   -0.025478
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20.00</td>
#       <td>2021-05-25</td>
#       <td>2022-01-06</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.23</td>
#       <td>2021-04-16</td>
#       <td>2021-05-10</td>
#       <td>2021-05-24</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.04</td>
#       <td>2021-04-12</td>
#       <td>2021-04-13</td>
#       <td>2021-04-16</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.02</td>
#       <td>2021-04-07</td>
#       <td>2021-04-08</td>
#       <td>2021-04-09</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.03%</td>
#       <td>-3.72%</td>
#       <td>4.38%</td>
#     </tr>
#   </tbody>
# </table>
