# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AJG','BRO']
print(DOW_30_TICKER)
# Out:
# ['AJG', 'BRO']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AJG    3063
# BRO    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26   56.799999   58.369999   56.320000   57.894855  2128300
# 6122  2022-05-27  161.729996  165.649994  161.729996  164.228195   717100
# 6123  2022-05-27   58.400002   59.959999   58.290001   59.738327  2452300
# 6124  2022-05-31  164.929993  164.929993  161.580002  160.559738  1471100
# 6125  2022-05-31   59.470001   59.910000   58.430000   59.160374  8115600
#
#       tic  day
# 6121  BRO    3
# 6122  AJG    4
# 6123  BRO    4
# 6124  AJG    1
# 6125  BRO    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open    high        low      close  volume  tic  day
# 0  2010-04-01  24.590000  24.730  24.330000  17.112612  463400  AJG    3
# 1  2010-04-01   8.965000   8.995   8.825000   7.639946  806200  BRO    3
# 2  2010-04-05  24.500000  24.650  24.459999  17.182455  510200  AJG    0
# 3  2010-04-05   8.870000   8.915   8.830000   7.665800  938200  BRO    0
# 4  2010-04-06  24.459999  24.820  24.459999  17.273264  467900  AJG    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AJG    3063
# BRO    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AJG    3063
# BRO    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
processed.head()
# Out:
#          date       open    high        low      close  volume  tic  day  \
# 0  2010-04-01  24.590000  24.730  24.330000  17.112612  463400  AJG    3
# 1  2010-04-01   8.965000   8.995   8.825000   7.639946  806200  BRO    3
# 2  2010-04-05  24.500000  24.650  24.459999  17.182455  510200  AJG    0
# 3  2010-04-05   8.870000   8.915   8.830000   7.665800  938200  BRO    0
# 4  2010-04-06  24.459999  24.820  24.459999  17.273264  467900  AJG    1
#
#        macd    boll_ub    boll_lb  rsi_30      cci_30  dx_30  close_30_sma  \
# 0  0.000000  17.246307  17.048760   100.0   66.666667  100.0     17.112612
# 1  0.000000  17.246307  17.048760   100.0   66.666667  100.0      7.639946
# 2  0.001567  17.246307  17.048760   100.0   66.666667  100.0     17.147533
# 3  0.000580   7.689437   7.616309   100.0  -66.666667  100.0      7.652873
# 4  0.004813  17.350551  17.028336   100.0  100.000000  100.0     17.189444
#
#    close_60_sma  turbulence
# 0     17.112612         0.0
# 1      7.639946         0.0
# 2     17.147533         0.0
# 3      7.652873         0.0
# 4     17.189444         0.0

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 seed=106,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 50_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  23.751505847600722
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# -------------------------------------
# | time/              |              |
# |    fps             | 384          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.011068212 |
# -------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 454            |
# |    iterations           | 2              |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.001861788    |
# |    clip_fraction        | 0.0145         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.85          |
# |    explained_variance   | -2.71          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0314        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00102       |
# |    reward               | -0.00092699943 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00155        |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 478           |
# |    iterations           | 3             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0026074378  |
# |    clip_fraction        | 0.0136        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -0.0619       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0351       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000939     |
# |    reward               | -0.0039130426 |
# |    std                  | 1.02          |
# |    value_loss           | 0.00317       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0029375735 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.014       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0255      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000534    |
# |    reward               | -0.004833963 |
# |    std                  | 1.02         |
# |    value_loss           | 0.0126       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041421936 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.0532      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0205      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000916    |
# |    reward               | -0.003168207 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004390937 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.00093     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0303     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00277    |
# |    reward               | 0.037349686 |
# |    std                  | 1.02        |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -38967.49
# total_reward: -48967.49
# total_cost: 143.67
# total_trades: 2674
# Sharpe: -0.539
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 7           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006438258 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.021       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0355     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00372    |
# |    reward               | 0.012623025 |
# |    std                  | 1.02        |
# |    value_loss           | 0.00918     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 8             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.0038273807  |
# |    clip_fraction        | 0.0127        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -0.00534      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0243       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000907     |
# |    reward               | -0.0031443432 |
# |    std                  | 1.01          |
# |    value_loss           | 0.011         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 9             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.007863497   |
# |    clip_fraction        | 0.0443        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -0.00106      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0139       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00283      |
# |    reward               | -0.0059660464 |
# |    std                  | 1.01          |
# |    value_loss           | 0.000863      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 10           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0055586454 |
# |    clip_fraction        | 0.0815       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0264      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00528     |
# |    reward               | 0.014892078  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00036      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 11           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035821744 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.000446     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0269      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00146     |
# |    reward               | -0.004204915 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0026947134 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.000627     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.021       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00088      |
# |    reward               | 0.0027663012 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00451      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 13           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0046079746 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0248      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00176     |
# |    reward               | -0.001878569 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00463      |
# ------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -14068.45
# total_reward: -24068.45
# total_cost: 175.23
# total_trades: 2778
# Sharpe: 0.458
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 525           |
# |    iterations           | 14            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.0012515839  |
# |    clip_fraction        | 0.0136        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0293       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000975     |
# |    reward               | 0.00048594867 |
# |    std                  | 1.03          |
# |    value_loss           | 0.000677      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 15           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0054902094 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0378      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00288     |
# |    reward               | 0.0020514722 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00377      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 16           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.004209034  |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | -2.21e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0342      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000791    |
# |    reward               | 0.0044872807 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00356      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 17           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0045124553 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 8.17e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0179      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000683    |
# |    reward               | -0.0089351   |
# |    std                  | 1.03         |
# |    value_loss           | 0.00273      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 18           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.002465012  |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0266      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000573    |
# |    reward               | 0.0048884638 |
# |    std                  | 1.04         |
# |    value_loss           | 0.000323     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 531           |
# |    iterations           | 19            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.0025308034  |
# |    clip_fraction        | 0.0129        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0299       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00139      |
# |    reward               | 0.00010687367 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00106       |
# -------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -17565.03
# total_reward: -27565.03
# total_cost: 145.44
# total_trades: 2782
# Sharpe: 0.052
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 20           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0046604765 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | -2.46e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0283      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0036      |
# |    reward               | 0.013075918  |
# |    std                  | 1.05         |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 21           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.008452091  |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 1.7e-05      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00273     |
# |    reward               | -0.017577253 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00471      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 22           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.005086445  |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0346      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0017      |
# |    reward               | -0.009432194 |
# |    std                  | 1.04         |
# |    value_loss           | 0.000676     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 534           |
# |    iterations           | 23            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.0006141515  |
# |    clip_fraction        | 0.00586       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 4.32e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0304       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0.000187      |
# |    reward               | -0.0065673394 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00269       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 535           |
# |    iterations           | 24            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.0015940986  |
# |    clip_fraction        | 0.00791       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.92         |
# |    explained_variance   | 4.95e-06      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0375       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000984     |
# |    reward               | -0.0050911363 |
# |    std                  | 1.05          |
# |    value_loss           | 0.00429       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 536          |
# |    iterations           | 25           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0054492075 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 8.62e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0328      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00117     |
# |    reward               | 0.009254135  |
# |    std                  | 1.05         |
# |    value_loss           | 0.0108       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.24059002814303412
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.00000000e+04 1.27264275e+02 4.63944817e+01 0.00000000e+00
#   0.00000000e+00 1.56814897e+00 1.55860245e-01 1.27312553e+02
#   4.68248978e+01 1.18756523e+02 4.44620438e+01 6.09375763e+01
#   5.35973358e+01 1.67363785e+02 8.20076141e+01 3.47928848e+01
#   1.45549049e+01 1.21856277e+02 4.56945267e+01 1.18212578e+02
#   4.52962074e+01]]
# ============================================
# turbulence_threshold:  23.751505847600722
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 632          |
# |    iterations      | 1            |
# |    time_elapsed    | 3            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.011068212 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.001861788 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -2.71       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0314     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00102    |
# |    reward               | 0.017896507 |
# |    std                  | 1.01        |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 3             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0006220796  |
# |    clip_fraction        | 0.00444       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -0.0905       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0295       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | 0.000106      |
# |    reward               | 0.00028002492 |
# |    std                  | 1.02          |
# |    value_loss           | 0.00299       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.003036046  |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.0217      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0177      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00126     |
# |    reward               | -0.021520525 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0156       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0048592715 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.0161       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0319      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00294     |
# |    reward               | 0.02368775   |
# |    std                  | 1.03         |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 550           |
# |    iterations           | 6             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.005290683   |
# |    clip_fraction        | 0.0363        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0.00342       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0247       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00269      |
# |    reward               | -0.0042018415 |
# |    std                  | 1.03          |
# |    value_loss           | 0.000573      |
# -------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: -17211.89
# total_reward: -27211.89
# total_cost: 142.60
# total_trades: 2778
# Sharpe: 0.264
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.006400034  |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.00167      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0325      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00234     |
# |    reward               | 0.0032589296 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00267      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 8            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0029908395 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.0241       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0212      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -1.67e-05    |
# |    reward               | 0.1919779    |
# |    std                  | 1.03         |
# |    value_loss           | 0.00457      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 9            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0036560118 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -0.0114      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0376      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0024      |
# |    reward               | 0.015119615  |
# |    std                  | 1.04         |
# |    value_loss           | 0.0192       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 545           |
# |    iterations           | 10            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.0044321767  |
# |    clip_fraction        | 0.0303        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.0072        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0234       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00121      |
# |    reward               | -0.0067600664 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00967       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005297606 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.0555     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0277     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00345    |
# |    reward               | 0.014015016 |
# |    std                  | 1.04        |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 12           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0039535365 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | -0.0257      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0309      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00058     |
# |    reward               | -0.03288732  |
# |    std                  | 1.05         |
# |    value_loss           | 0.0225       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 13           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0067919074 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -0.000687    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0425      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00578     |
# |    reward               | 0.00784538   |
# |    std                  | 1.04         |
# |    value_loss           | 0.00185      |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -24654.01
# total_reward: -34654.01
# total_cost: 141.49
# total_trades: 2716
# Sharpe: -0.063
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 14           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.007889879  |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.000768     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0309      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00743     |
# |    reward               | -0.021131793 |
# |    std                  | 1.03         |
# |    value_loss           | 0.0072       |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 542            |
# |    iterations           | 15             |
# |    time_elapsed         | 56             |
# |    total_timesteps      | 30720          |
# | train/                  |                |
# |    approx_kl            | 0.005427351    |
# |    clip_fraction        | 0.0429         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.91          |
# |    explained_variance   | -0.000444      |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0415        |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -0.00299       |
# |    reward               | -0.00017480488 |
# |    std                  | 1.04           |
# |    value_loss           | 0.00714        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 16           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.00475746   |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -5.72e-06    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0187      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000348    |
# |    reward               | 0.0051806397 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00852      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 17           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0047115614 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 1.32e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0247      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00239     |
# |    reward               | 4.31324e-05  |
# |    std                  | 1.05         |
# |    value_loss           | 0.00275      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 18           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0035034793 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 8.25e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0356      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000993    |
# |    reward               | 0.012553062  |
# |    std                  | 1.05         |
# |    value_loss           | 0.013        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 19           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0047380524 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.000153     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0166      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00158     |
# |    reward               | -0.00525082  |
# |    std                  | 1.06         |
# |    value_loss           | 0.0135       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 542           |
# |    iterations           | 20            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.0062906025  |
# |    clip_fraction        | 0.0638        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.96         |
# |    explained_variance   | 0.000121      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.03         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00528      |
# |    reward               | -0.0021716957 |
# |    std                  | 1.06          |
# |    value_loss           | 0.0217        |
# -------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -48991.25
# total_reward: -58991.25
# total_cost: 173.72
# total_trades: 3040
# Sharpe: 0.050
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 21           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0041686855 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | -0.00013     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0405      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00344     |
# |    reward               | -0.019243864 |
# |    std                  | 1.06         |
# |    value_loss           | 0.00329      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 22           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049946588 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.000121     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.000904    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000958    |
# |    reward               | 0.0041321293 |
# |    std                  | 1.06         |
# |    value_loss           | 0.0249       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 23           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0035334001 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 7.78e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0246      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | 0.0710757    |
# |    std                  | 1.06         |
# |    value_loss           | 0.0314       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 24          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004334622 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0277     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00109    |
# |    reward               | 0.02703662  |
# |    std                  | 1.06        |
# |    value_loss           | 0.0408      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 25           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0030120143 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.00023      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 0.010670886  |
# |    std                  | 1.06         |
# |    value_loss           | 0.00423      |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.057378222169250495
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.34657295e+04  1.38436142e+02  5.30183411e+01 -2.80000000e+01
#    4.00000000e+00 -7.20215023e-01  4.26341534e-01  1.43149094e+02
#    5.35047035e+01  1.34908569e+02  5.09570732e+01  5.20145950e+01
#    5.90749817e+01 -6.45338440e+01  1.22190323e+02  1.45665255e+01
#    1.08885574e+01  1.40167862e+02  5.20393448e+01  1.39584137e+02
#    5.14109840e+01]]
# ============================================
# turbulence_threshold:  23.751505847600722
# ======Model training from:  2010-04-01 to  2021-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_1
# -------------------------------------
# | time/              |              |
# |    fps             | 628          |
# |    iterations      | 1            |
# |    time_elapsed    | 3            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.011068212 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.001861788  |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -2.71        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0314      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00102     |
# |    reward               | -0.010534004 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003501926 |
# |    clip_fraction        | 0.00952     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.0609     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0213     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000195   |
# |    reward               | 0.01177735  |
# |    std                  | 1.02        |
# |    value_loss           | 0.00278     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0028781206 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.0563      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0217      |
# ...
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0302      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00322     |
# |    reward               | -0.001264827 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00265      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 9            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046493523 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.275        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0251      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00322     |
# |    reward               | -0.023355419 |
# |    std                  | 1.03         |
# |    value_loss           | 0.000989     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 10            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.0031663075  |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0.108         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0202       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000869     |
# |    reward               | -0.0043226047 |
# |    std                  | 1.03          |
# |    value_loss           | 0.00464       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 11           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0032516965 |
# |    clip_fraction        | 0.00322      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.0509       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00242     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000376    |
# |    reward               | -0.03567171  |
# |    std                  | 1.03         |
# |    value_loss           | 0.0245       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 12           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0014517562 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -0.0136      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0302      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000165    |
# |    reward               | -0.022592945 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00122      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 13           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036611366 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | -0.015       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0253      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00181     |
# |    reward               | 0.0067943754 |
# |    std                  | 1.04         |
# |    value_loss           | 0.00972      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 14           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0036054421 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.0165       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0316      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | -0.07045535  |
# |    std                  | 1.05         |
# |    value_loss           | 0.0388       |
# ------------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: -82188.87
# total_reward: -92188.87
# total_cost: 166.60
# total_trades: 2934
# Sharpe: -0.314
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 506           |
# |    iterations           | 15            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00643567    |
# |    clip_fraction        | 0.066         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.93         |
# |    explained_variance   | -0.000324     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0266       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00397      |
# |    reward               | -0.0050816173 |
# |    std                  | 1.04          |
# |    value_loss           | 0.0264        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 16           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.004936083  |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0312      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00196     |
# |    reward               | -0.005198549 |
# |    std                  | 1.05         |
# |    value_loss           | 0.0139       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 17           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.00246605   |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.0485       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0255      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000905    |
# |    reward               | 0.0006521404 |
# |    std                  | 1.06         |
# |    value_loss           | 0.0125       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 18           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0019118375 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.0437       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00766     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000153     |
# |    reward               | -0.020625478 |
# |    std                  | 1.06         |
# |    value_loss           | 0.0422       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 19          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004730612 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0277     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000723   |
# |    reward               | 0.010423212 |
# |    std                  | 1.06        |
# |    value_loss           | 0.00498     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 20           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0046318895 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0212      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00278     |
# |    reward               | -0.012041288 |
# |    std                  | 1.07         |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 21           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.005826412  |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0205      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00201     |
# |    reward               | -0.030484041 |
# |    std                  | 1.08         |
# |    value_loss           | 0.0335       |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: -61985.15
# total_reward: -71985.15
# total_cost: 173.88
# total_trades: 3046
# Sharpe: -0.074
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 486           |
# |    iterations           | 22            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.003958053   |
# |    clip_fraction        | 0.0146        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.99         |
# |    explained_variance   | 0.218         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0262       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00095      |
# |    reward               | -0.0074548917 |
# |    std                  | 1.08          |
# |    value_loss           | 0.00566       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 485           |
# |    iterations           | 23            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.007547673   |
# |    clip_fraction        | 0.0485        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.97         |
# |    explained_variance   | 0.166         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0258       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00281      |
# |    reward               | -0.0065878946 |
# |    std                  | 1.06          |
# |    value_loss           | 0.0253        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 24          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003971344 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0382     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00197    |
# |    reward               | 0.03427437  |
# |    std                  | 1.06        |
# |    value_loss           | 0.0163      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 483          |
# |    iterations           | 25           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0044429298 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0164      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00143     |
# |    reward               | 0.012177015  |
# |    std                  | 1.06         |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  -0.28114294275254925
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.4667277e+04  1.6475818e+02  6.8323845e+01 -4.3000000e+01
#    1.9000000e+01  1.1170341e+00  1.2218081e+00  1.6967516e+02
#    7.0062653e+01  1.6157565e+02  6.4570763e+01  5.4364864e+01
#    5.9780571e+01  3.2257877e+01  1.1528533e+02  8.9902557e-02
#    1.7686350e+01  1.6446692e+02  6.6441353e+01  1.6219325e+02
#    6.4627541e+01]]
# Ensemble Strategy took:  6.653562688827515  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0   -0.24059           0
# 1  189  2021-04-06  2021-07-06        PPO          0  -0.057378           0
# 2  252  2021-07-06  2021-10-04        PPO          0  -0.255815           0
# 3  315  2021-10-04  2022-01-03        PPO          0  -0.281143           0

# %%
len(ensemble_agent.crk_model)
# Out:
# 4

# %%
ensemble_agent.crk_model[0].policy.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict([('log_std',
#                Parameter containing:
#                tensor([0.0456, 0.0610], requires_grad=True))]),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('features_extractor',
#                FlattenExtractor(
#                  (flatten): Flatten(start_dim=1, end_dim=-1)
#                )),
#               ('mlp_extractor',
#                MlpExtractor(
#                  (shared_net): Sequential()
#                  (policy_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                  (value_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                )),
#               ('action_net',
#                Linear(in_features=64, out_features=2, bias=True)),
#               ('value_net',
#                Linear(in_features=64, out_features=1, bias=True))]),
#  'observation_space': Box([-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#   inf inf inf], (21,), float32),
#  'action_space': Box([-1. -1.], [1. 1.], (2,), float32),
#  'normalize_images': True,
#  'optimizer_class': torch.optim.adam.Adam,
#  'optimizer_kwargs': {'eps': 1e-05},
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      eps: 1e-05
#      foreach: None
#      lr: 0.00025
#      maximize: False
#      weight_decay: 0
#  ),
#  'features_extractor_class': stable_baselines3.common.torch_layers.FlattenExtractor,
#  'features_extractor_kwargs': {},
#  '_squash_output': False,
#  'net_arch': [{'pi': [64, 64], 'vf': [64, 64]}],
#  'activation_fn': torch.nn.modules.activation.Tanh,
#  'ortho_init': True,
#  'features_dim': 21,
#  'log_std_init': 0.0,
#  'use_sde': False,
#  'dist_kwargs': None,
#  'action_dist': <stable_baselines3.common.distributions.DiagGaussianDistribution at 0x1e0982ff640>}

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.4189635864475165

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10000.000000  2021-04-07      0.000000  2021-04-07
# 2    9980.987143  2021-04-08     -0.001901  2021-04-08
# 3    9980.238100  2021-04-09     -0.000075  2021-04-09
# 4    9981.638033  2021-04-12      0.000140  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.154587
# Cumulative returns    -0.154587
# Annual volatility      0.114200
# Sharpe ratio          -1.418964
# Calmar ratio          -1.000000
# Stability              0.635324
# Max drawdown          -0.154587
# Omega ratio            0.788963
# Sortino ratio         -1.900492
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.915339
# Daily value at risk   -0.015031
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-15.459%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-15.459%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.42%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.42</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-15.459%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.90</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.503%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.10</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.51</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15.46</td>
#       <td>2021-04-07</td>
#       <td>2022-04-01</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.06%</td>
#       <td>-2.22%</td>
#       <td>2.29%</td>
#     </tr>
#   </tbody>
# </table>
