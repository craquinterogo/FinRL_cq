# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AIG','CTRA']
print(DOW_30_TICKER)
# Out:
# ['AIG', 'CTRA']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high        low      close    volume   tic  \
# 6121  2022-05-26  34.340000  35.779999  34.220001  33.063053  11206100  CTRA
# 6122  2022-05-27  57.849998  59.000000  57.630001  57.997391   3891100   AIG
# 6123  2022-05-27  34.250000  35.529999  34.200001  33.893208   8413700  CTRA
# 6124  2022-05-31  58.650002  59.759998  58.169998  57.682827   5639200   AIG
# 6125  2022-05-31  36.060001  36.450001  34.130001  32.757710  22122700  CTRA
#
#       day
# 6121    3
# 6122    4
# 6123    4
# 6124    1
# 6125    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume   tic  day
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921482   6250200   AIG    3
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570669   4922000  CTRA    3
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559864  16281300   AIG    0
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793334   4937200  CTRA    0
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131056  19971000   AIG    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
processed.head()
# Out:
#          date       open       high        low      close    volume   tic  \
# 0  2010-04-01  34.250000  34.490002  33.810001  22.921482   6250200   AIG
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570669   4922000  CTRA
# 2  2010-04-05  34.430000  35.450001  33.900002  23.559864  16281300   AIG
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793334   4937200  CTRA
# 4  2010-04-06  35.490002  36.380001  35.200001  24.131056  19971000   AIG
#
#    day      macd    boll_ub    boll_lb  rsi_30      cci_30  dx_30  \
# 0    3  0.000000  24.143481  22.337865   100.0   66.666667  100.0
# 1    3  0.000000  24.143481  22.337865   100.0   66.666667  100.0
# 2    0  0.014323  24.143481  22.337865   100.0   66.666667  100.0
# 3    0  0.004996   7.996899   7.367105   100.0   66.666667  100.0
# 4    1  0.035963  24.747663  22.327272   100.0  100.000000  100.0
#
#    close_30_sma  close_60_sma  turbulence
# 0     22.921482     22.921482         0.0
# 1      7.570669      7.570669         0.0
# 2     23.240673     23.240673         0.0
# 3      7.682002      7.682002         0.0
# 4     23.537467     23.537467         0.0

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 seed=106,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 50_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.344868671225086
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# -----------------------------------
# | time/              |            |
# |    fps             | 256        |
# |    iterations      | 1          |
# |    time_elapsed    | 7          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.0024374 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038341123 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -1.13        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00154     |
# |    reward               | 0.011670478  |
# |    std                  | 1            |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.006924408  |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.045       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0356      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00227     |
# |    reward               | -0.030717496 |
# |    std                  | 1            |
# |    value_loss           | 0.00277      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0033204053 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0618      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.03        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000841    |
# |    reward               | -0.009665623 |
# |    std                  | 0.999        |
# |    value_loss           | 0.00167      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 5             |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0027763783  |
# |    clip_fraction        | 0.00771       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -0.0119       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0258       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -7.56e-05     |
# |    reward               | 0.00048334428 |
# |    std                  | 1             |
# |    value_loss           | 0.00103       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 6            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0047740247 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00443      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0312      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00393     |
# |    reward               | 0.013149175  |
# |    std                  | 1            |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 5740.32
# total_reward: -4259.68
# total_cost: 139.14
# total_trades: 2754
# Sharpe: 0.114
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004348087 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.00658     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0251     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00185    |
# |    reward               | 0.037408385 |
# |    std                  | 0.999       |
# |    value_loss           | 0.00252     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 8           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005944744 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.00926     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0303     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0041     |
# |    reward               | 0.008062711 |
# |    std                  | 1           |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 9            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0043948647 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00717     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0331      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00148     |
# |    reward               | 0.011672689  |
# |    std                  | 0.995        |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 10           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0013336919 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00252      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0289      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -3.53e-05    |
# |    reward               | 0.028550435  |
# |    std                  | 0.996        |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 374           |
# |    iterations           | 11            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.0060717314  |
# |    clip_fraction        | 0.0497        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.00912       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0237       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00456      |
# |    reward               | -0.0008899991 |
# |    std                  | 0.995         |
# |    value_loss           | 0.00342       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 12           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0056976085 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.00462      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0214      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00262     |
# |    reward               | 0.0013660515 |
# |    std                  | 0.991        |
# |    value_loss           | 0.00248      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 374           |
# |    iterations           | 13            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.0046768016  |
# |    clip_fraction        | 0.0199        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | -0.000143     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0263       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00156      |
# |    reward               | -0.0042222743 |
# |    std                  | 0.994         |
# |    value_loss           | 0.00182       |
# -------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 6626.64
# total_reward: -3373.36
# total_cost: 141.24
# total_trades: 2742
# Sharpe: 0.082
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 14           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0032930514 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00421      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0365      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000634    |
# |    reward               | -0.004514665 |
# |    std                  | 1            |
# |    value_loss           | 0.000864     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 15           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0022864533 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.000874     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.036       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00131     |
# |    reward               | -0.016423037 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00129      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 16           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033611604 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.0177       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0317      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000915    |
# |    reward               | 0.006267469  |
# |    std                  | 1.02         |
# |    value_loss           | 0.00149      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 17           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0040308293 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.00259      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0263      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00262     |
# |    reward               | -0.010208045 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00143      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 18            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00087469886 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0.00184       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0219       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.000157      |
# |    reward               | 0.003569142   |
# |    std                  | 1.02          |
# |    value_loss           | 0.00101       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 19           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035000811 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.00429      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0386      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | 0.0066118054 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00182      |
# ------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 6852.46
# total_reward: -3147.54
# total_cost: 119.47
# total_trades: 2792
# Sharpe: 0.384
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 20           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027978308 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.00931      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0376      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00105     |
# |    reward               | 0.019008335  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00234      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 21           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0025102051 |
# |    clip_fraction        | 0.00371      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.002        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0343      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000352    |
# |    reward               | 0.012841308  |
# |    std                  | 1.04         |
# |    value_loss           | 0.00525      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 22            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.0023228782  |
# |    clip_fraction        | 0.00278       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | -0.0058       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0354       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000653     |
# |    reward               | -0.0031095485 |
# |    std                  | 1.04          |
# |    value_loss           | 0.00138       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 23           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020463893 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.00569      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0316      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000444    |
# |    reward               | 0.0007264526 |
# |    std                  | 1.05         |
# |    value_loss           | 0.00251      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 24            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.0004280458  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.93         |
# |    explained_variance   | 0.00319       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0262       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -3.36e-05     |
# |    reward               | -0.0077091525 |
# |    std                  | 1.05          |
# |    value_loss           | 0.00169       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 25           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024796552 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.00369      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0409      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000889    |
# |    reward               | 0.009676341  |
# |    std                  | 1.05         |
# |    value_loss           | 0.00167      |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.24802984886498752
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[ 1.0000000e+04  4.4805416e+01  1.6062765e+01  0.0000000e+00
#    0.0000000e+00  5.4846525e-01  5.2864801e-02  4.6732227e+01
#    1.6984123e+01  4.3252018e+01  1.5429830e+01  5.7691322e+01
#    5.0486050e+01  1.1617350e+01 -3.8270973e+01  7.4090924e+00
#    8.9696541e+00  4.4508801e+01  1.6239408e+01  4.1729580e+01
#    1.6083075e+01]]
# ============================================
# turbulence_threshold:  19.344868671225086
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -----------------------------------
# | time/              |            |
# |    fps             | 419        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.0024374 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038341123 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -1.13        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00154     |
# |    reward               | 0.027248798  |
# |    std                  | 1            |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037977034 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.0837      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0277      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00162     |
# |    reward               | 0.0033727894 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00265      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.003274241  |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.0341      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0336      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00138     |
# |    reward               | -0.004102405 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012262136 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.00671     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0348      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000188    |
# |    reward               | 0.0049835998 |
# |    std                  | 1.01         |
# |    value_loss           | 0.000764     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0045867553 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.00136     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.038       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00317     |
# |    reward               | 0.0029701777 |
# |    std                  | 1.01         |
# |    value_loss           | 0.000971     |
# ------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 5982.01
# total_reward: -4017.99
# total_cost: 142.10
# total_trades: 2810
# Sharpe: -0.038
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 7             |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.0038026539  |
# |    clip_fraction        | 0.0128        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | -0.00346      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0239       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000343     |
# |    reward               | -0.0041138893 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00123       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 8             |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.0041360077  |
# |    clip_fraction        | 0.0161        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0.00146       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0314       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00133      |
# |    reward               | -0.0012635742 |
# |    std                  | 1             |
# |    value_loss           | 0.00118       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 9            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.004022139  |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00814     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00907     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00163     |
# |    reward               | 0.0045764144 |
# |    std                  | 1            |
# |    value_loss           | 0.000964     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 10           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0040000407 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00938     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0365      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00195     |
# |    reward               | 0.0091642495 |
# |    std                  | 0.996        |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 11          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004731194 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.00421     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0341     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00311    |
# |    reward               | 0.017833699 |
# |    std                  | 1           |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 12           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.004330474  |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.00129      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0254      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000869    |
# |    reward               | 0.0033699735 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 13           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0045733573 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.00756     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0357      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0023      |
# |    reward               | -0.016722282 |
# |    std                  | 1.01         |
# |    value_loss           | 0.000957     |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 4415.50
# total_reward: -5584.50
# total_cost: 136.06
# total_trades: 2682
# Sharpe: -0.101
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 14           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0032797214 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.00308     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0327      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000946    |
# |    reward               | -0.022065394 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 15            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.0024037843  |
# |    clip_fraction        | 0.0131        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.00854       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.033        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 0.000456      |
# |    reward               | -0.0026392022 |
# |    std                  | 1.02          |
# |    value_loss           | 0.00155       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 16           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0027385382 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.000583     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0342      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000189    |
# |    reward               | -0.007375213 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 17           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0046922117 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.011        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0286      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00416     |
# |    reward               | 0.0021482147 |
# |    std                  | 1.01         |
# |    value_loss           | 0.000528     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 374           |
# |    iterations           | 18            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.0038398663  |
# |    clip_fraction        | 0.0187        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.00233       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0341       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000873     |
# |    reward               | -0.0042945077 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00123       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 19           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.004898381  |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.00364      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0304      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00207     |
# |    reward               | -0.009963175 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00209      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 20           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.005081401  |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.00339     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0323      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00276     |
# |    reward               | -0.010493455 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00156      |
# ------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 6048.90
# total_reward: -3951.10
# total_cost: 136.76
# total_trades: 2886
# Sharpe: 0.018
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 21           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.004266022  |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.003       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0389      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00242     |
# |    reward               | -0.014306323 |
# |    std                  | 1.01         |
# |    value_loss           | 0.000981     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 22           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.003918217  |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -4.79e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0235      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00211     |
# |    reward               | -0.018864585 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 23           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0030545166 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.0006      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0387      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | 0.045703784  |
# |    std                  | 1.02         |
# |    value_loss           | 0.00281      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 24           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.004540978  |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.00462     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0307      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000884    |
# |    reward               | -0.012579946 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00937      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 25           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0038970457 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.0012      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0298      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00256     |
# |    reward               | 0.006035713  |
# |    std                  | 1.02         |
# |    value_loss           | 0.00132      |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.04821063212526794
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# [[ 1.87817188e+04  4.50344238e+01  1.48622675e+01 -1.94000000e+02
#   -3.00000000e+00 -8.47349823e-01  7.72210434e-02  5.13974648e+01
#    1.58006058e+01  4.36544991e+01  1.34798079e+01  4.45638161e+01
#    4.97791557e+01 -1.11025421e+02  9.52524185e+01  3.32284203e+01
#    5.63854551e+00  4.85274696e+01  1.46157284e+01  4.77497673e+01
#    1.47524796e+01]]
# ============================================
# turbulence_threshold:  19.344868671225086
# ======Model training from:  2010-04-01 to  2021-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_1
# -----------------------------------
# | time/              |            |
# |    fps             | 434        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.0024374 |
# -----------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 405           |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0038341123  |
# |    clip_fraction        | 0.0228        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -1.13         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0281       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00154      |
# |    reward               | -0.0059916675 |
# |    std                  | 1             |
# |    value_loss           | 0.0026        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 394           |
# |    iterations           | 3             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0031908327  |
# |    clip_fraction        | 0.00713       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -0.264        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0299       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000428     |
# |    reward               | -0.0020516918 |
# |    std                  | 1             |
# |    value_loss           | 0.00152       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0050153434 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.000125     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0255      |
# |    n_updates            | 30           |
# ...
# |    loss                 | -0.0271      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0021      |
# |    reward               | 0.0010899765 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 375           |
# |    iterations           | 9             |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0032399197  |
# |    clip_fraction        | 0.0134        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0.007         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0316       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00122      |
# |    reward               | -0.0037420676 |
# |    std                  | 1.03          |
# |    value_loss           | 0.000811      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 10           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0060678367 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.000459     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.018       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00277     |
# |    reward               | 0.007467522  |
# |    std                  | 1.02         |
# |    value_loss           | 0.00232      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 11           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0032851417 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.00276      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0286      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00107     |
# |    reward               | -0.011204871 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 12            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.004912029   |
# |    clip_fraction        | 0.0278        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.00585       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0378       |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00211      |
# |    reward               | -0.0060767625 |
# |    std                  | 1.01          |
# |    value_loss           | 0.000894      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 13            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.0042837486  |
# |    clip_fraction        | 0.018         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.00431       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0338       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00208      |
# |    reward               | -0.0061834278 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00182       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 14           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0029923795 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.0194      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0192      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000418    |
# |    reward               | -0.04979392  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 620.89
# total_reward: -9379.11
# total_cost: 131.30
# total_trades: 2888
# Sharpe: 0.298
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 15           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.005812343  |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.000354     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0254      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00299     |
# |    reward               | -0.007558241 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0045       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 16           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0027830417 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0254       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0308      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00193     |
# |    reward               | -0.02070009  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 17            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.005477029   |
# |    clip_fraction        | 0.0512        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0.0211        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0304       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00413      |
# |    reward               | 0.00019389743 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00227       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 18           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0051876158 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.00113      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0195      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00321     |
# |    reward               | 0.039265506  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00679      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 19           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0034544608 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.000735    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0346      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000995    |
# |    reward               | 0.0020652493 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 20           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0021254905 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.00231      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0308      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000405    |
# |    reward               | -0.013883394 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00412      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 21           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0036859792 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.00758     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0283      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000861    |
# |    reward               | 0.0017678016 |
# |    std                  | 1.02         |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 3060.98
# total_reward: -6939.02
# total_cost: 137.38
# total_trades: 2940
# Sharpe: -0.195
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 22           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.003691446  |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.00844      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0234      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00258     |
# |    reward               | 0.0041371454 |
# |    std                  | 1.03         |
# |    value_loss           | 0.00062      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 23            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00079934194 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0292       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0.000152      |
# |    reward               | -0.010188958  |
# |    std                  | 1.03          |
# |    value_loss           | 0.00103       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 24            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.0036135693  |
# |    clip_fraction        | 0.0143        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0.00859       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0289       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00174      |
# |    reward               | -0.0051062177 |
# |    std                  | 1.03          |
# |    value_loss           | 0.00184       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 25           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0032014754 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.0283       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0321      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0013      |
# |    reward               | 0.005600099  |
# |    std                  | 1.03         |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.04379079667838234
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.8149064e+04  5.6106422e+01  1.7893316e+01 -1.7700000e+02
#   -2.0000000e+01  3.6457914e-01 -2.4918349e-01  5.6597851e+01
#    1.9178036e+01  5.1466885e+01  1.7312626e+01  5.4033588e+01
#    4.8056087e+01  1.1924820e+02 -1.1977662e+02  1.8484997e+01
#    2.1615852e+01  5.3881409e+01  1.8416004e+01  5.5446522e+01
#    1.8800699e+01]]
# Ensemble Strategy took:  9.110108478864033  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0   -0.24803           0
# 1  189  2021-04-06  2021-07-06        PPO          0  -0.048211           0
# 2  252  2021-07-06  2021-10-04        PPO          0  -0.413798           0
# 3  315  2021-10-04  2022-01-03        PPO          0   0.043791           0

# %%
len(ensemble_agent.crk_model)
# Out:
# 4

# %%
ensemble_agent.crk_model[0].policy.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict([('log_std',
#                Parameter containing:
#                tensor([0.0340, 0.0733], requires_grad=True))]),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('features_extractor',
#                FlattenExtractor(
#                  (flatten): Flatten(start_dim=1, end_dim=-1)
#                )),
#               ('mlp_extractor',
#                MlpExtractor(
#                  (shared_net): Sequential()
#                  (policy_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                  (value_net): Sequential(
#                    (0): Linear(in_features=21, out_features=64, bias=True)
#                    (1): Tanh()
#                    (2): Linear(in_features=64, out_features=64, bias=True)
#                    (3): Tanh()
#                  )
#                )),
#               ('action_net',
#                Linear(in_features=64, out_features=2, bias=True)),
#               ('value_net',
#                Linear(in_features=64, out_features=1, bias=True))]),
#  'observation_space': Box([-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#   inf inf inf], (21,), float32),
#  'action_space': Box([-1. -1.], [1. 1.], (2,), float32),
#  'normalize_images': True,
#  'optimizer_class': torch.optim.adam.Adam,
#  'optimizer_kwargs': {'eps': 1e-05},
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      eps: 1e-05
#      foreach: None
#      lr: 0.00025
#      maximize: False
#      weight_decay: 0
#  ),
#  'features_extractor_class': stable_baselines3.common.torch_layers.FlattenExtractor,
#  'features_extractor_kwargs': {},
#  '_squash_output': False,
#  'net_arch': [{'pi': [64, 64], 'vf': [64, 64]}],
#  'activation_fn': torch.nn.modules.activation.Tanh,
#  'ortho_init': True,
#  'features_dim': 21,
#  'log_std_init': 0.0,
#  'use_sde': False,
#  'dist_kwargs': None,
#  'action_dist': <stable_baselines3.common.distributions.DiagGaussianDistribution at 0x16b320bafd0>}

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.0258863854523945

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10000.335058  2021-04-07      0.000034  2021-04-07
# 2   10184.320875  2021-04-08      0.018398  2021-04-08
# 3   10082.170110  2021-04-09     -0.010030  2021-04-09
# 4    9976.234064  2021-04-12     -0.010507  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.347018
# Cumulative returns    -0.347018
# Annual volatility      0.355397
# Sharpe ratio          -1.025886
# Calmar ratio          -0.904859
# Stability              0.785378
# Max drawdown          -0.383505
# Omega ratio            0.846875
# Sortino ratio         -1.395165
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.947709
# Daily value at risk   -0.046223
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-34.702%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-34.702%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>35.54%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.03</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.90</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-38.35%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.40</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.622%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.20</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-1.25</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38.35</td>
#       <td>2021-07-08</td>
#       <td>2022-03-25</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14.68</td>
#       <td>2021-04-20</td>
#       <td>2021-06-01</td>
#       <td>2021-07-08</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.65</td>
#       <td>2021-04-08</td>
#       <td>2021-04-14</td>
#       <td>2021-04-20</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.14%</td>
#       <td>-7.22%</td>
#       <td>7.34%</td>
#     </tr>
#   </tbody>
# </table>
