# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentOne
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AMCR','JNPR']
print(DOW_30_TICKER)
# Out:
# ['AMCR', 'JNPR']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (5591, 8)

# %%
df['tic'].value_counts()
# Out:
# JNPR    3063
# AMCR    2528
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high    low      close    volume   tic  day
# 5586  2022-05-26  30.190001  30.940001  30.18  29.994238   3476800  JNPR    3
# 5587  2022-05-27  13.190000  13.310000  13.12  13.040057   8531400  AMCR    4
# 5588  2022-05-27  30.980000  31.230000  30.77  30.581974   2867000  JNPR    4
# 5589  2022-05-31  13.170000  13.260000  13.01  12.834316  35769100  AMCR    1
# 5590  2022-05-31  30.860001  30.950001  30.41  30.256529   5073000  JNPR    1

# %%
df.shape
# Out:
# (5591, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  30.809999  31.080000  30.209999  24.890247  3832100  JNPR    3
# 1  2010-04-05  30.780001  30.930000  30.430000  25.225386  7685900  JNPR    0
# 2  2010-04-06  30.610001  31.770000  30.430000  25.862970  8171100  JNPR    1
# 3  2010-04-07  31.520000  31.870001  31.320000  25.740353  6328300  JNPR    2
# 4  2010-04-08  31.420000  31.490000  30.670000  25.560528  6908900  JNPR    3

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# JNPR    3063
# AMCR    2528
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# JNPR    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentOne(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 seed=106,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 0, 
                 'ppo' : 60_000, 
                 'ddpg' : 0
                 }

# %%
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)
df_summary = ensemble_agent.run_ensemble_strategy(None,
                                                 PPO_model_kwargs,
                                                 None,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  12.043065126125105
# ======Model training from:  2010-04-01 to  2021-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_1
# -------------------------------------
# | time/              |              |
# |    fps             | 298          |
# |    iterations      | 1            |
# |    time_elapsed    | 6            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.008676064 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.002285468  |
# |    clip_fraction        | 0.00425      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.195       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.013       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000158     |
# |    reward               | 0.0015127509 |
# |    std                  | 1            |
# |    value_loss           | 0.00292      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057925927 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0128       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0174      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00166     |
# |    reward               | -0.003366073 |
# |    std                  | 0.988        |
# |    value_loss           | 0.0037       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 430           |
# |    iterations           | 4             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0051625133  |
# |    clip_fraction        | 0.0361        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.035        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00519      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0019       |
# |    reward               | -0.0056737983 |
# |    std                  | 0.988         |
# |    value_loss           | 0.00233       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 447           |
# |    iterations           | 5             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0046319943  |
# |    clip_fraction        | 0.0359        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.000228     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.03         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.0035       |
# |    reward               | 0.00045154043 |
# |    std                  | 0.981         |
# |    value_loss           | 0.00216       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 6           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003745541 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0203     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00205    |
# |    reward               | 0.010418455 |
# |    std                  | 0.978       |
# |    value_loss           | 0.00083     |
# -----------------------------------------
# day: 2707, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 10485.43
# total_reward: 485.43
# total_cost: 98.08
# total_trades: 2707
# Sharpe: 0.104
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 7            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0044271783 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00087     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0166      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | 0.0059020594 |
# |    std                  | 0.977        |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 8            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0027411385 |
# |    clip_fraction        | 0.00913      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00073     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00672     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00045     |
# |    reward               | 0.009029744  |
# |    std                  | 0.976        |
# |    value_loss           | 0.000916     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 9            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0047571384 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000366    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0227      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0037      |
# |    reward               | -0.008328299 |
# |    std                  | 0.971        |
# |    value_loss           | 0.000853     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 505           |
# |    iterations           | 10            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 9.0630085e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0134       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | 0.000145      |
# |    reward               | -0.0018374441 |
# |    std                  | 0.968         |
# |    value_loss           | 0.0011        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 11           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0013387079 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000728    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0102      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000218    |
# |    reward               | -0.006394584 |
# |    std                  | 0.98         |
# |    value_loss           | 0.000794     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 12           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.002275527  |
# |    clip_fraction        | 0.00552      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00124     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0243      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000579    |
# |    reward               | 0.0017332515 |
# |    std                  | 0.986        |
# |    value_loss           | 0.000549     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 524           |
# |    iterations           | 13            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.0025964081  |
# |    clip_fraction        | 0.00869       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.000624     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0196       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000875     |
# |    reward               | -0.0056344937 |
# |    std                  | 0.979         |
# |    value_loss           | 0.000479      |
# -------------------------------------------
# day: 2707, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 10147.68
# total_reward: 147.68
# total_cost: 94.55
# total_trades: 2707
# Sharpe: 0.090
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 528           |
# |    iterations           | 14            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.0014191235  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0161       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -6.67e-05     |
# |    reward               | -0.0011246304 |
# |    std                  | 0.977         |
# |    value_loss           | 0.000907      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 15           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0037020133 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000106    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0257      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00202     |
# |    reward               | 0.015893525  |
# |    std                  | 0.972        |
# |    value_loss           | 0.000885     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 535          |
# |    iterations           | 16           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0029202178 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000209     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0248      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0016      |
# |    reward               | 0.0022168611 |
# |    std                  | 0.967        |
# |    value_loss           | 0.000685     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 538           |
# |    iterations           | 17            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.0028679487  |
# |    clip_fraction        | 0.00146       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000655      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0143       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000418     |
# |    reward               | -0.0017356818 |
# |    std                  | 0.959         |
# |    value_loss           | 0.000542      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 18           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0040299958 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0137      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | 0.011154356  |
# |    std                  | 0.963        |
# |    value_loss           | 0.000759     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 19           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0026968776 |
# |    clip_fraction        | 0.00405      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000277     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00533     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000319    |
# |    reward               | 0.003207227  |
# |    std                  | 0.967        |
# |    value_loss           | 0.000772     |
# ------------------------------------------
# day: 2707, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 11897.84
# total_reward: 1897.84
# total_cost: 95.95
# total_trades: 2707
# Sharpe: 0.182
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 542           |
# |    iterations           | 20            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.004852591   |
# |    clip_fraction        | 0.0254        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.00109       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0182       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00197      |
# |    reward               | -0.0010938812 |
# |    std                  | 0.97          |
# |    value_loss           | 0.00161       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 21           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0018302388 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000365     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0192      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000127    |
# |    reward               | 0.0007534039 |
# |    std                  | 0.973        |
# |    value_loss           | 0.00107      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 544           |
# |    iterations           | 22            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.0034701345  |
# |    clip_fraction        | 0.00376       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.013        |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000436     |
# |    reward               | -0.0064969463 |
# |    std                  | 0.965         |
# |    value_loss           | 0.000685      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 545           |
# |    iterations           | 23            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.003194966   |
# |    clip_fraction        | 0.00356       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000669      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00401      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000488     |
# |    reward               | -0.0016232855 |
# |    std                  | 0.957         |
# |    value_loss           | 0.00116       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 24           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0006166386 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000825     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0142      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000196    |
# |    reward               | -0.008802287 |
# |    std                  | 0.969        |
# |    value_loss           | 0.000893     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 25           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0038603442 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00153      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0135      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00157     |
# |    reward               | 0.0046592923 |
# |    std                  | 0.968        |
# |    value_loss           | 0.000508     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 548           |
# |    iterations           | 26            |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00073554297 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0148       |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000334     |
# |    reward               | 0.00079173694 |
# |    std                  | 0.985         |
# |    value_loss           | 0.000388      |
# -------------------------------------------
# day: 2707, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: 9575.30
# total_reward: -424.70
# total_cost: 104.45
# total_trades: 2707
# Sharpe: 0.036
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 549           |
# |    iterations           | 27            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00016877081 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.00192       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0114       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 7.72e-05      |
# |    reward               | 0.0058414843  |
# |    std                  | 0.985         |
# |    value_loss           | 0.000748      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 550          |
# |    iterations           | 28           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0022947271 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000908     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00264     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -5.49e-05    |
# |    reward               | 0.009488407  |
# |    std                  | 0.988        |
# |    value_loss           | 0.000563     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 29           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0028964353 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0011       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0161      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000331    |
# |    reward               | -0.003667441 |
# |    std                  | 0.984        |
# |    value_loss           | 0.000708     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 552           |
# |    iterations           | 30            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.0019971484  |
# |    clip_fraction        | 0.00449       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.011        |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000388     |
# |    reward               | -0.0013391082 |
# |    std                  | 0.99          |
# |    value_loss           | 0.000467      |
# -------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  -0.15047053380108913
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# [[1.0000000e+04 2.4394415e+01 0.0000000e+00 3.0838451e-01 2.4958952e+01
#   2.3238611e+01 5.6291115e+01 7.8714073e+01 1.9371996e+01 2.3590780e+01
#   2.3505814e+01]]
# ============================================
# turbulence_threshold:  12.043065126125105
# ======Model training from:  2010-04-01 to  2021-04-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 747          |
# |    iterations      | 1            |
# |    time_elapsed    | 2            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.008676064 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.002285468  |
# |    clip_fraction        | 0.00425      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.195       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.013       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000158     |
# |    reward               | 0.0060481564 |
# |    std                  | 1            |
# |    value_loss           | 0.00292      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0024401313 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0516      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00948     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000135    |
# |    reward               | 0.003206134  |
# |    std                  | 0.991        |
# |    value_loss           | 0.00382      |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 603            |
# |    iterations           | 4              |
# |    time_elapsed         | 13             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.00026080201  |
# |    clip_fraction        | 4.88e-05       |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.4           |
# |    explained_variance   | -0.00482       |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0151        |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.000239      |
# |    reward               | -0.00069566764 |
# |    std                  | 0.976          |
# |    value_loss           | 0.0024         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019195941 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0135      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0018      |
# |    reward               | -0.010219608 |
# |    std                  | 0.965        |
# |    value_loss           | 0.00147      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 6            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0008254375 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00172     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0123      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 6.5e-05      |
# |    reward               | 0.0009918654 |
# |    std                  | 0.97         |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# day: 2770, episode: 5
# begin_total_asset: 10000.00
# end_total_asset: 9075.94
# total_reward: -924.06
# total_cost: 101.56
# total_trades: 2770
# Sharpe: 0.040
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0029884768 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00608     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00575     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000561    |
# |    reward               | -0.006340407 |
# |    std                  | 0.968        |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 8.617208e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00125     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0126      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.000149     |
# |    reward               | -0.029108416 |
# |    std                  | 0.968        |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 9            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0019308754 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0152      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000893    |
# |    reward               | -0.003937588 |
# |    std                  | 0.967        |
# |    value_loss           | 0.00292      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 10           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0020831195 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0162      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000163     |
# |    reward               | -0.010256477 |
# |    std                  | 0.972        |
# |    value_loss           | 0.00148      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 11           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 6.166799e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -6.68e-06    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0129      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 4.68e-05     |
# |    reward               | 0.015365742  |
# |    std                  | 0.98         |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0029548958 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -3.7e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0124      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000643    |
# |    reward               | 0.012719394  |
# |    std                  | 0.979        |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 13           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0029193403 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0222      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000946    |
# |    reward               | -0.030592874 |
# |    std                  | 0.976        |
# |    value_loss           | 0.00095      |
# ------------------------------------------
# day: 2770, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 10163.35
# total_reward: 163.35
# total_cost: 97.35
# total_trades: 2770
# Sharpe: 0.118
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 14           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0017545377 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -2.44e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0183      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00113     |
# |    reward               | 0.008074597  |
# |    std                  | 0.998        |
# |    value_loss           | 0.00204      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 583           |
# |    iterations           | 15            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.0025750217  |
# |    clip_fraction        | 0.00654       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0101       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000358     |
# |    reward               | -0.0048203906 |
# |    std                  | 0.996         |
# |    value_loss           | 0.0014        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 16           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0029719283 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0175      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000969    |
# |    reward               | 0.015146024  |
# |    std                  | 0.994        |
# |    value_loss           | 0.00135      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 17           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0028208788 |
# |    clip_fraction        | 0.00591      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0143      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00067     |
# |    reward               | -0.009158861 |
# |    std                  | 0.988        |
# |    value_loss           | 0.00362      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 582           |
# |    iterations           | 18            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.001676508   |
# |    clip_fraction        | 0.00483       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0156       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000496     |
# |    reward               | -0.0061699697 |
# |    std                  | 1             |
# |    value_loss           | 0.00317       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 19           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.004574792  |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0122      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00231     |
# |    reward               | -0.005534577 |
# |    std                  | 0.999        |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 20           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0024456335 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00978     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000236    |
# |    reward               | -0.009240485 |
# |    std                  | 1            |
# |    value_loss           | 0.00139      |
# ------------------------------------------
# day: 2770, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 8909.89
# total_reward: -1090.11
# total_cost: 100.34
# total_trades: 2770
# Sharpe: 0.037
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 21           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.002591309  |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0255      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000543    |
# |    reward               | -0.003670152 |
# |    std                  | 1            |
# |    value_loss           | 0.00101      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 22           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0044390364 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0239      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00169     |
# |    reward               | 0.0029737167 |
# |    std                  | 0.997        |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 23           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.003991454  |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0153      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00121     |
# |    reward               | 0.0034931696 |
# |    std                  | 0.995        |
# |    value_loss           | 0.000666     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 615           |
# |    iterations           | 24            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 3.157067e-05  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0146       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 5.25e-05      |
# |    reward               | -0.0006902943 |
# |    std                  | 0.991         |
# |    value_loss           | 0.000663      |
# ...
# |    n_updates            | 120          |
# |    policy_gradient_loss | -8.29e-05    |
# |    reward               | 0.020824801  |
# |    std                  | 0.987        |
# |    value_loss           | 0.00145      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 14           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0033124418 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -5.41e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00893     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000729    |
# |    reward               | -0.013026986 |
# |    std                  | 0.994        |
# |    value_loss           | 0.00118      |
# ------------------------------------------
# day: 2896, episode: 10
# begin_total_asset: 10000.00
# end_total_asset: 10064.56
# total_reward: 64.56
# total_cost: 104.99
# total_trades: 2896
# Sharpe: 0.083
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 15           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0042024846 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0151      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000929    |
# |    reward               | -0.004281476 |
# |    std                  | 0.984        |
# |    value_loss           | 0.000376     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 704           |
# |    iterations           | 16            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.001923052   |
# |    clip_fraction        | 0.00283       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -9.54e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0129       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000389     |
# |    reward               | -0.0036063336 |
# |    std                  | 0.996         |
# |    value_loss           | 0.000988      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 17           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0024708242 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -3.58e-06    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0245      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000444    |
# |    reward               | 0.0061353324 |
# |    std                  | 0.996        |
# |    value_loss           | 0.000848     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 709           |
# |    iterations           | 18            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00027144284 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.018        |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 2.7e-05       |
# |    reward               | -0.0020317559 |
# |    std                  | 1             |
# |    value_loss           | 0.000448      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 713           |
# |    iterations           | 19            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.0041702073  |
# |    clip_fraction        | 0.0104        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0235       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000723     |
# |    reward               | -0.0037183382 |
# |    std                  | 0.999         |
# |    value_loss           | 0.000718      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 717           |
# |    iterations           | 20            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.0010501692  |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -2.5e-06      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00576      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 1.05e-05      |
# |    reward               | -0.0057613146 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00155       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 21           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0031458992 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0162      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000814    |
# |    reward               | 0.0032350952 |
# |    std                  | 1            |
# |    value_loss           | 0.000629     |
# ------------------------------------------
# day: 2896, episode: 15
# begin_total_asset: 10000.00
# end_total_asset: 8533.76
# total_reward: -1466.24
# total_cost: 103.96
# total_trades: 2896
# Sharpe: -0.023
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 22           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0050404165 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0115      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00201     |
# |    reward               | 0.0021959743 |
# |    std                  | 1            |
# |    value_loss           | 0.000485     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 23           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0041453354 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0137      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00114     |
# |    reward               | 0.003641905  |
# |    std                  | 1            |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 24           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.002461512  |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0178      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000569    |
# |    reward               | 0.0040515903 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00168      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 25           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0021808716 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.015       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000263    |
# |    reward               | 0.017941294  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00271      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 26           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0047650337 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0263      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00331     |
# |    reward               | -0.009203939 |
# |    std                  | 1            |
# |    value_loss           | 0.00183      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 27           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0039752633 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0212      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000813    |
# |    reward               | 0.013331854  |
# |    std                  | 1            |
# |    value_loss           | 0.003        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 28           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0036155665 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0186      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000269    |
# |    reward               | 0.049075104  |
# |    std                  | 0.996        |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# day: 2896, episode: 20
# begin_total_asset: 10000.00
# end_total_asset: 5397.60
# total_reward: -4602.40
# total_cost: 110.36
# total_trades: 2896
# Sharpe: 0.070
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 726           |
# |    iterations           | 29            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00038698994 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00796      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.000141      |
# |    reward               | 0.04042832    |
# |    std                  | 1             |
# |    value_loss           | 0.00241       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 30           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0034336038 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0165      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0012      |
# |    reward               | 0.0034521164 |
# |    std                  | 0.999        |
# |    value_loss           | 0.00489      |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  -0.5065971201017504
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# [[ 1.45262666e+04  3.44254303e+01 -1.82000000e+02  1.00107348e+00
#    3.53951797e+01  3.07549877e+01  6.53525391e+01  1.21201065e+02
#    4.64443741e+01  3.22997971e+01  3.06517162e+01]]
# Ensemble Strategy took:  6.437055071194966  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO          0  -0.150471           0
# 1  189  2021-04-06  2021-07-06        PPO          0   -0.14577           0
# 2  252  2021-07-06  2021-10-04        PPO          0  -0.039107           0
# 3  315  2021-10-04  2022-01-03        PPO          0  -0.506597           0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.5391093821311346

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1   10004.255683  2021-04-07      0.000426  2021-04-07
# 2    9988.191933  2021-04-08     -0.001606  2021-04-08
# 3   10002.844104  2021-04-09      0.001467  2021-04-09
# 4    9989.222927  2021-04-12     -0.001362  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.209049
# Cumulative returns    -0.209049
# Annual volatility      0.145968
# Sharpe ratio          -1.539109
# Calmar ratio          -0.906942
# Stability              0.864182
# Max drawdown          -0.230499
# Omega ratio            0.762007
# Sortino ratio         -1.888126
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.734967
# Daily value at risk   -0.019282
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-20.905%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-20.905%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.597%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.54</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.91</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-23.05%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.76</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.89</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.928%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.14</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.64</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23.05</td>
#       <td>2021-04-22</td>
#       <td>2022-03-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.90</td>
#       <td>2021-04-07</td>
#       <td>2021-04-16</td>
#       <td>2021-04-20</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.35</td>
#       <td>2021-04-20</td>
#       <td>2021-04-21</td>
#       <td>2021-04-22</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.09%</td>
#       <td>-4.49%</td>
#       <td>2.54%</td>
#     </tr>
#   </tbody>
# </table>
