# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['CMCSA','DIS']
print(DOW_30_TICKER)
# Out:
# ['CMCSA', 'DIS']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close    volume  \
# 6121  2022-05-26  104.220001  106.129997  103.959999  105.610001  11297800
# 6122  2022-05-27   44.130001   44.639999   43.980000   43.477409  18073500
# 6123  2022-05-27  106.889999  109.370003  106.529999  109.320000  13671300
# 6124  2022-05-31   43.910000   44.660000   43.480000   43.595554  25249600
# 6125  2022-05-31  110.000000  111.239998  107.910004  110.440002  20274600
#
#         tic  day
# 6121    DIS    3
# 6122  CMCSA    4
# 6123    DIS    4
# 6124  CMCSA    1
# 6125    DIS    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume    tic  \
# 0  2010-04-01   9.410000   9.520000   9.310000   7.365884  38877200  CMCSA
# 1  2010-04-01  35.070000  35.590000  35.009998  30.965103  14603000    DIS
# 2  2010-04-05   9.405000   9.490000   9.340000   7.387471  26500200  CMCSA
# 3  2010-04-05  35.279999  35.540001  35.070000  30.677664  10607900    DIS
# 4  2010-04-06   9.340000   9.460000   9.290000   7.363917  22708600  CMCSA
#
#    day
# 0    3
# 1    3
# 2    0
# 3    0
# 4    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.88446380099779
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_58
# ---------------------------------------
# | time/                 |             |
# |    fps                | 43          |
# |    iterations         | 100         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.82       |
# |    explained_variance | -17.5       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.466      |
# |    reward             | 0.018539248 |
# |    std                | 0.991       |
# |    value_loss         | 0.0227      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 78           |
# |    iterations         | 200          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.83        |
# |    explained_variance | -25.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.374       |
# |    reward             | -0.018701492 |
# |    std                | 0.994        |
# |    value_loss         | 0.0259       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 108        |
# |    iterations         | 300        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | -46.5      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.49      |
# |    reward             | 0.01255927 |
# |    std                | 0.993      |
# |    value_loss         | 0.0266     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 133          |
# |    iterations         | 400          |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.84        |
# |    explained_variance | -7.23        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.344        |
# |    reward             | -0.010228138 |
# |    std                | 1            |
# |    value_loss         | 0.0213       |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 500      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | -1.84    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0744  |
# |    reward             | 0.0      |
# |    std                | 1.01     |
# |    value_loss         | 0.0186   |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 173         |
# |    iterations         | 600         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | -417        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.333      |
# |    reward             | 0.013802552 |
# |    std                | 1.01        |
# |    value_loss         | 0.0329      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 190          |
# |    iterations         | 700          |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -2.88        |
# |    explained_variance | -1.32        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.209        |
# |    reward             | 0.0060420963 |
# |    std                | 1.02         |
# |    value_loss         | 0.00688      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 205           |
# |    iterations         | 800           |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.9          |
# |    explained_variance | -14.3         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.151        |
# |    reward             | -0.0068105524 |
# |    std                | 1.03          |
# |    value_loss         | 0.00659       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 218          |
# |    iterations         | 900          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | -44.5        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.383       |
# |    reward             | -0.010725858 |
# |    std                | 1.03         |
# |    value_loss         | 0.0353       |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 230          |
# |    iterations         | 1000         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | 0.139        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.0315       |
# |    reward             | 0.0072823036 |
# |    std                | 1.03         |
# |    value_loss         | 0.000857     |
# ----------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.21883374482694695
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_49
# -------------------------------------
# | time/              |              |
# |    fps             | 207          |
# |    iterations      | 1            |
# |    time_elapsed    | 9            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.007978188 |
# -------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 2             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0075387023  |
# |    clip_fraction        | 0.0901        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -3.6          |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.023        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0127       |
# |    reward               | -0.0036357678 |
# |    std                  | 0.99          |
# |    value_loss           | 0.0351        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.00709215   |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -5           |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0354      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0127      |
# |    reward               | 0.0002454747 |
# |    std                  | 0.986        |
# |    value_loss           | 0.0148       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.2680047673833489
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_49
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  19.88446380099779
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_47
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -29        |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -0.147     |
# |    reward             | 0.01736837 |
# |    std                | 1.02       |
# |    value_loss         | 0.00348    |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 77           |
# |    iterations         | 200          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | 0.0167       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.0569      |
# |    reward             | -0.004301078 |
# |    std                | 1.03         |
# |    value_loss         | 0.000766     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 300         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.93       |
# |    explained_variance | -14.8       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.167      |
# |    reward             | 0.027333893 |
# |    std                | 1.05        |
# |    value_loss         | 0.014       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 129          |
# |    iterations         | 400          |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -23.3        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -0.279       |
# |    reward             | -0.021039344 |
# |    std                | 1.05         |
# |    value_loss         | 0.0164       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 150         |
# |    iterations         | 500         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -2.97       |
# |    explained_variance | -11.5       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.0837     |
# |    reward             | -0.15800636 |
# |    std                | 1.07        |
# |    value_loss         | 0.0596      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 600        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.97      |
# |    explained_variance | -1.13e+03  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 0.235      |
# |    reward             | 0.00186651 |
# |    std                | 1.07       |
# |    value_loss         | 0.0294     |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 186           |
# |    iterations         | 700           |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -3            |
# |    explained_variance | -89.5         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.155        |
# |    reward             | -0.0013637374 |
# |    std                | 1.08          |
# |    value_loss         | 0.0161        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 201           |
# |    iterations         | 800           |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -3.02         |
# |    explained_variance | -113          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.38         |
# |    reward             | -0.0005142681 |
# |    std                | 1.1           |
# |    value_loss         | 0.0114        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 215          |
# |    iterations         | 900          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.04        |
# |    explained_variance | -11.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.14        |
# |    reward             | 0.0043963213 |
# |    std                | 1.11         |
# |    value_loss         | 0.00288      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 228          |
# |    iterations         | 1000         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.05        |
# |    explained_variance | -75.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.129       |
# |    reward             | 0.0063406187 |
# |    std                | 1.11         |
# |    value_loss         | 0.00483      |
# ----------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.18539247594312433
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_47
# -------------------------------------
# | time/              |              |
# |    fps             | 175          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.008630388 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.007038047  |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -10.9        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0225      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0111      |
# |    reward               | -0.015809055 |
# |    std                  | 0.995        |
# |    value_loss           | 0.104        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 3             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0067709377  |
# |    clip_fraction        | 0.0634        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -8.49         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0381       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.0102       |
# |    reward               | -0.0003863225 |
# |    std                  | 0.999         |
# |    value_loss           | 0.0172        |
# -------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.1556070194343884
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_47
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  19.88446380099779
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_47
# --------------------------------------
# | time/                 |            |
# |    fps                | 95         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -101       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -0.122     |
# |    reward             | 0.02386008 |
# |    std                | 1.01       |
# |    value_loss         | 0.0281     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 76           |
# |    iterations         | 200          |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.86        |
# |    explained_variance | -6.35        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.17         |
# |    reward             | 0.0137220565 |
# |    std                | 1.01         |
# |    value_loss         | 0.00538      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 105         |
# |    iterations         | 300         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | -2.86       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 0.0199      |
# |    reward             | 0.036909975 |
# |    std                | 1.02        |
# |    value_loss         | 0.00397     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 129          |
# |    iterations         | 400          |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | -37.1        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -0.0946      |
# |    reward             | -0.046927594 |
# |    std                | 1.03         |
# |    value_loss         | 0.0117       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 150         |
# |    iterations         | 500         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | -0.721      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 0.47        |
# |    reward             | -0.22994722 |
# |    std                | 1.04        |
# |    value_loss         | 0.0464      |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 168           |
# |    iterations         | 600           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.93         |
# |    explained_variance | -721          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.109         |
# |    reward             | -0.0015568965 |
# |    std                | 1.05          |
# |    value_loss         | 0.0101        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 185           |
# |    iterations         | 700           |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.94         |
# |    explained_variance | -3.69e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.0226       |
# |    reward             | -0.0007815501 |
# |    std                | 1.05          |
# |    value_loss         | 0.0372        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 199          |
# |    iterations         | 800          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -488         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | -0.245       |
# |    reward             | 0.0005243555 |
# |    std                | 1.05         |
# |    value_loss         | 0.0194       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 900        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.96      |
# |    explained_variance | -635       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 0.366      |
# |    reward             | 0.01677046 |
# |    std                | 1.06       |
# |    value_loss         | 0.0152     |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 221           |
# |    iterations         | 1000          |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -2.98         |
# |    explained_variance | -308          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | 0.173         |
# |    reward             | -0.0045703426 |
# |    std                | 1.07          |
# |    value_loss         | 0.0215        |
# -----------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  -0.06891586805255731
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_47
# --------------------------------------
# | time/              |               |
# |    fps             | 170           |
# |    iterations      | 1             |
# |    time_elapsed    | 12            |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0022013485 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0070691914 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -7.34        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0345      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0107      |
# |    reward               | 0.0042739143 |
# |    std                  | 0.992        |
# |    value_loss           | 0.0664       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 3             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.005261896   |
# |    clip_fraction        | 0.0441        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -7.7          |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0394       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.0106       |
# |    reward               | -0.0034036327 |
# |    std                  | 1             |
# |    value_loss           | 0.0271        |
# -------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  -0.08568666038196406
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_46
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  19.88446380099779
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_44
# ---------------------------------------
# | time/                 |             |
# |    fps                | 83          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | -86.9       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.0621     |
# |    reward             | 0.018249711 |
# |    std                | 1.02        |
# |    value_loss         | 0.0187      |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 66             |
# |    iterations         | 200            |
# |    time_elapsed       | 15             |
# |    total_timesteps    | 1000           |
# | train/                |                |
# |    entropy_loss       | -2.88          |
# |    explained_variance | -36.7          |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 199            |
# |    policy_loss        | -0.366         |
# |    reward             | -4.0048788e-05 |
# |    std                | 1.02           |
# |    value_loss         | 0.0176         |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 89           |
# |    iterations         | 300          |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | -29          |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 0.0575       |
# |    reward             | 0.0025575403 |
# |    std                | 1.03         |
# |    value_loss         | 0.00644      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 111        |
# |    iterations         | 400        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -38.6      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 0.494      |
# |    reward             | -0.0213539 |
# |    std                | 1.03       |
# |    value_loss         | 0.0456     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 129         |
# |    iterations         | 500         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | -1.51       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.646      |
# |    reward             | -0.12843066 |
# |    std                | 1.04        |
# |    value_loss         | 0.0824      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 144          |
# |    iterations         | 600          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -2.31e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.0262      |
# |    reward             | 0.0045603276 |
# |    std                | 1.05         |
# |    value_loss         | 0.0126       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 158           |
# |    iterations         | 700           |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.94         |
# |    explained_variance | -155          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.253         |
# |    reward             | -0.0036261368 |
# |    std                | 1.05          |
# |    value_loss         | 0.0102        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 170           |
# |    iterations         | 800           |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.95         |
# |    explained_variance | -429          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.152        |
# |    reward             | 0.00027958685 |
# |    std                | 1.06          |
# |    value_loss         | 0.00868       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 181           |
# |    iterations         | 900           |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -2.97         |
# |    explained_variance | -326          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | -0.197        |
# |    reward             | -0.0035350951 |
# |    std                | 1.07          |
# |    value_loss         | 0.00605       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 190          |
# |    iterations         | 1000         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.97        |
# |    explained_variance | -10          |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.00262      |
# |    reward             | -0.010180738 |
# |    std                | 1.07         |
# |    value_loss         | 8.18e-05     |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.21755206092546378
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_44
# --------------------------------------
# | time/              |               |
# |    fps             | 173           |
# |    iterations      | 1             |
# |    time_elapsed    | 11            |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0023457725 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 247           |
# |    iterations           | 2             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.005514469   |
# |    clip_fraction        | 0.0335        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -20.7         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0421       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00737      |
# |    reward               | -0.0019757862 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0434        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0048758416 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -15.5        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.051       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00963     |
# |    reward               | -0.006966198 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0146       |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  -0.2716768579152618
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_44
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  14.56573315858841  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO   0.218834   0.268005    0.112831
# 1  189  2021-04-06  2021-07-06        PPO  -0.185392  -0.155607   -0.222154
# 2  252  2021-07-06  2021-10-04       DDPG  -0.068916  -0.085687    0.013671
# 3  315  2021-10-04  2022-01-03       DDPG  -0.217552  -0.271677         0.0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.072632262737632

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1    9985.841631  2021-04-07     -0.001416  2021-04-07
# 2    9984.716271  2021-04-08     -0.000113  2021-04-08
# 3   10004.997890  2021-04-09      0.002031  2021-04-09
# 4    9978.328731  2021-04-12     -0.002666  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.165870
# Cumulative returns    -0.165870
# Annual volatility      0.158010
# Sharpe ratio          -1.072632
# Calmar ratio          -0.680438
# Stability              0.803046
# Max drawdown          -0.243770
# Omega ratio            0.779149
# Sortino ratio         -1.356021
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.695760
# Daily value at risk   -0.020580
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-16.587%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-16.587%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.801%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.07</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.68</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.377%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.36</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.058%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.19</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.31</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.38</td>
#       <td>2021-04-14</td>
#       <td>2021-12-01</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.27</td>
#       <td>2021-04-09</td>
#       <td>2021-04-12</td>
#       <td>2021-04-13</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.15</td>
#       <td>2021-04-06</td>
#       <td>2021-04-08</td>
#       <td>2021-04-09</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.07%</td>
#       <td>-6.49%</td>
#       <td>3.71%</td>
#     </tr>
#   </tbody>
# </table>
