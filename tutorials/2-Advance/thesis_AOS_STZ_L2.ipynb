# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AOS','STZ']
print(DOW_30_TICKER)
# Out:
# ['AOS', 'STZ']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AOS    3063
# STZ    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26  244.100006  247.479996  242.750000  242.723373   887800
# 6122  2022-05-27   59.830002   61.220001   59.759998   60.584621   638000
# 6123  2022-05-27  246.529999  247.240005  244.910004  244.650299   959400
# 6124  2022-05-31   60.630001   61.000000   59.470001   59.496037  2994700
# 6125  2022-05-31  245.210007  246.059998  242.360001  243.815964  1958900
#
#       tic  day
# 6121  STZ    3
# 6122  AOS    4
# 6123  STZ    4
# 6124  AOS    1
# 6125  STZ    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume  tic  day
# 0  2010-04-01   8.788333   8.838333   8.696667   7.267148  1438200  AOS    3
# 1  2010-04-01  16.510000  16.600000  16.330000  14.931827  1212600  STZ    3
# 2  2010-04-05   8.815000   8.956667   8.773333   7.435959  1413600  AOS    0
# 3  2010-04-05  16.510000  16.719999  16.430000  15.085669   823200  STZ    0
# 4  2010-04-06   8.888333   9.040000   8.858333   7.462248  1264800  AOS    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AOS    3063
# STZ    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 10000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  24.526671293542265
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_61
# ---------------------------------------
# | time/                 |             |
# |    fps                | 31          |
# |    iterations         | 100         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.82       |
# |    explained_variance | -0.0398     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 0.00623     |
# |    reward             | 0.026234452 |
# |    std                | 0.991       |
# |    value_loss         | 0.00019     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 57          |
# |    iterations         | 200         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.84       |
# |    explained_variance | 0.0731      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.189      |
# |    reward             | 0.005548707 |
# |    std                | 1           |
# |    value_loss         | 0.00633     |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 300        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0.143      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 0.932      |
# |    reward             | 0.07197767 |
# |    std                | 1.01       |
# |    value_loss         | 0.128      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 99           |
# |    iterations         | 400          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.87        |
# |    explained_variance | -1.93        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -0.273       |
# |    reward             | -0.050895877 |
# |    std                | 1.02         |
# |    value_loss         | 0.047        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 117         |
# |    iterations         | 500         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | -0.302      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.57       |
# |    reward             | -0.34510306 |
# |    std                | 1.02        |
# |    value_loss         | 0.173       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 133           |
# |    iterations         | 600           |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.86         |
# |    explained_variance | -796          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.421         |
# |    reward             | 0.00025514583 |
# |    std                | 1.01          |
# |    value_loss         | 0.0623        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 148          |
# |    iterations         | 700          |
# |    time_elapsed       | 23           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | -2.77e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.104        |
# |    reward             | 0.0047603343 |
# |    std                | 1.03         |
# |    value_loss         | 0.0107       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 161           |
# |    iterations         | 800           |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.91         |
# |    explained_variance | -71.6         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.228        |
# |    reward             | -0.0005883549 |
# |    std                | 1.04          |
# |    value_loss         | 0.0137        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 174         |
# |    iterations         | 900         |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | -69.7       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 0.752       |
# |    reward             | 0.003165985 |
# |    std                | 1.04        |
# |    value_loss         | 0.0468      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 184          |
# |    iterations         | 1000         |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.91        |
# |    explained_variance | -536         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.196        |
# |    reward             | 0.0012974613 |
# |    std                | 1.04         |
# |    value_loss         | 0.00617      |
# ----------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.14043506232576403
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_52
# -------------------------------------
# | time/              |              |
# |    fps             | 154          |
# |    iterations      | 1            |
# |    time_elapsed    | 13           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0015289483 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054082125 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -6.27        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0221      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0077      |
# |    reward               | -0.01320015  |
# |    std                  | 1            |
# |    value_loss           | 0.0659       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 3            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0063975896 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.371       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0487      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0105      |
# |    reward               | 0.011517285  |
# |    std                  | 1            |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.11679283870832075
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_52
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  24.526671293542265
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_50
# ---------------------------------------
# | time/                 |             |
# |    fps                | 69          |
# |    iterations         | 100         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.00568    |
# |    reward             | 0.005671531 |
# |    std                | 1.02        |
# |    value_loss         | 4.64e-06    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 70           |
# |    iterations         | 200          |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.92        |
# |    explained_variance | -4.69        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 1.43         |
# |    reward             | -0.023287488 |
# |    std                | 1.04         |
# |    value_loss         | 0.224        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 90          |
# |    iterations         | 300         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.94       |
# |    explained_variance | -146        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 1.56        |
# |    reward             | 0.023290252 |
# |    std                | 1.05        |
# |    value_loss         | 0.133       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 113           |
# |    iterations         | 400           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -2.95         |
# |    explained_variance | -46.1         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | 1.16          |
# |    reward             | -0.0055647753 |
# |    std                | 1.06          |
# |    value_loss         | 0.153         |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 133          |
# |    iterations         | 500          |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -2.98        |
# |    explained_variance | -16.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | 0.504        |
# |    reward             | -0.023499724 |
# |    std                | 1.07         |
# |    value_loss         | 0.0656       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 151           |
# |    iterations         | 600           |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.98         |
# |    explained_variance | -22.8         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.693        |
# |    reward             | -0.0013245099 |
# |    std                | 1.07          |
# |    value_loss         | 0.0562        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 166         |
# |    iterations         | 700         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.98       |
# |    explained_variance | -110        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.0422     |
# |    reward             | -0.02881525 |
# |    std                | 1.08        |
# |    value_loss         | 0.00774     |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 179           |
# |    iterations         | 800           |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -3            |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | -0.218        |
# |    reward             | -0.0005769183 |
# |    std                | 1.08          |
# |    value_loss         | 0.0046        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 190         |
# |    iterations         | 900         |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -3.01       |
# |    explained_variance | -4.78       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 0.164       |
# |    reward             | 0.004639558 |
# |    std                | 1.09        |
# |    value_loss         | 0.00532     |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 199           |
# |    iterations         | 1000          |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -3.02         |
# |    explained_variance | -73.6         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | -0.0411       |
# |    reward             | -0.0019859872 |
# |    std                | 1.1           |
# |    value_loss         | 0.0048        |
# -----------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.11839918580674223
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_50
# -------------------------------------
# | time/              |              |
# |    fps             | 154          |
# |    iterations      | 1            |
# |    time_elapsed    | 13           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0024429224 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004733418 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -7.63       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0285     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00657    |
# |    reward               | -0.0770839  |
# |    std                  | 0.999       |
# |    value_loss           | 0.0547      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 3             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0064184344  |
# |    clip_fraction        | 0.0521        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -3.23         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0323       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.0128       |
# |    reward               | -7.646904e-05 |
# |    std                  | 1             |
# |    value_loss           | 0.0157        |
# -------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.039835573879231624
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_50
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  24.526671293542265
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_50
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.84       |
# |    explained_variance | -70.7       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.389      |
# |    reward             | 0.026319247 |
# |    std                | 1           |
# |    value_loss         | 0.0479      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 200         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | 0.43        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.015       |
# |    reward             | 0.005944269 |
# |    std                | 1.01        |
# |    value_loss         | 0.00262     |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 113        |
# |    iterations         | 300        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -0.688     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 0.0811     |
# |    reward             | 0.10238858 |
# |    std                | 1.01       |
# |    value_loss         | 0.00302    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 140         |
# |    iterations         | 400         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | 0.0595      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -0.144      |
# |    reward             | -0.04592943 |
# |    std                | 1.01        |
# |    value_loss         | 0.0278      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 163         |
# |    iterations         | 500         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 0.072       |
# |    reward             | -0.06509797 |
# |    std                | 1.02        |
# |    value_loss         | 0.00106     |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 183            |
# |    iterations         | 600            |
# |    time_elapsed       | 16             |
# |    total_timesteps    | 3000           |
# | train/                |                |
# |    entropy_loss       | -2.87          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 599            |
# |    policy_loss        | -0.00103       |
# |    reward             | -0.00022552801 |
# |    std                | 1.02           |
# |    value_loss         | 5.07e-07       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 200           |
# |    iterations         | 700           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.91         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.02         |
# |    reward             | -0.0036373397 |
# |    std                | 1.03          |
# |    value_loss         | 2.91e-05      |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 216         |
# |    iterations         | 800         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.95       |
# |    explained_variance | -97.7       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 0.212       |
# |    reward             | 0.008824544 |
# |    std                | 1.06        |
# |    value_loss         | 0.0121      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 230        |
# |    iterations         | 900        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | -144       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -0.659     |
# |    reward             | 0.02297809 |
# |    std                | 1.05       |
# |    value_loss         | 0.0761     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 242          |
# |    iterations         | 1000         |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -7.37        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.059       |
# |    reward             | 0.0035509814 |
# |    std                | 1.05         |
# |    value_loss         | 0.0038       |
# ----------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  -0.41770741888144036
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_50
# -------------------------------------
# | time/              |              |
# |    fps             | 182          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0048623937 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.003925151  |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -16.5        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0232      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00411     |
# |    reward               | 0.0012436104 |
# |    std                  | 1            |
# |    value_loss           | 0.0784       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.008173291  |
# |    clip_fraction        | 0.0724       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -15.8        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0442      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0138      |
# |    reward               | -0.016723521 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0187       |
# ------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  -0.7117794834335984
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_49
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  24.526671293542265
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_47
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 100        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -4.98      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -0.0206    |
# |    reward             | 0.03268419 |
# |    std                | 1.02       |
# |    value_loss         | 0.00171    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 65          |
# |    iterations         | 200         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | -66.3       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.31       |
# |    reward             | -0.05011303 |
# |    std                | 1.03        |
# |    value_loss         | 0.0332      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 300        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | -3.21      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.319     |
# |    reward             | 0.03803907 |
# |    std                | 1.04       |
# |    value_loss         | 0.0258     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 104          |
# |    iterations         | 400          |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -25.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.104        |
# |    reward             | -0.043001458 |
# |    std                | 1.05         |
# |    value_loss         | 0.0154       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 500        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.95      |
# |    explained_variance | -0.0184    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -0.442     |
# |    reward             | -0.2756899 |
# |    std                | 1.06       |
# |    value_loss         | 0.106      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 133          |
# |    iterations         | 600          |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -2.93        |
# |    explained_variance | -59.5        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 0.076        |
# |    reward             | 0.0007529114 |
# |    std                | 1.05         |
# |    value_loss         | 0.00928      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 145           |
# |    iterations         | 700           |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.94         |
# |    explained_variance | -2.7e+03      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.508        |
# |    reward             | 0.00020767591 |
# |    std                | 1.05          |
# |    value_loss         | 0.0452        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 154          |
# |    iterations         | 800          |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -310         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 0.182        |
# |    reward             | 0.0022352478 |
# |    std                | 1.05         |
# |    value_loss         | 0.00627      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 163         |
# |    iterations         | 900         |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -2.95       |
# |    explained_variance | -155        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -0.0585     |
# |    reward             | -0.00103272 |
# |    std                | 1.06        |
# |    value_loss         | 0.00221     |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 171            |
# |    iterations         | 1000           |
# |    time_elapsed       | 29             |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -2.98          |
# |    explained_variance | -131           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | -0.112         |
# |    reward             | -0.00066923426 |
# |    std                | 1.08           |
# |    value_loss         | 0.00296        |
# ------------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.4201187275149802
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_47
# --------------------------------------
# | time/              |               |
# |    fps             | 145           |
# |    iterations      | 1             |
# |    time_elapsed    | 14            |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0002473994 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 219           |
# |    iterations           | 2             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0065295175  |
# |    clip_fraction        | 0.0442        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -5.31         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0176       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00955      |
# |    reward               | 0.00058660464 |
# |    std                  | 0.999         |
# |    value_loss           | 0.0557        |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 268            |
# |    iterations           | 3              |
# |    time_elapsed         | 22             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | 0.0051918346   |
# |    clip_fraction        | 0.0358         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.83          |
# |    explained_variance   | -3.09          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0357        |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.011         |
# |    reward               | -0.00021306073 |
# |    std                  | 0.995          |
# |    value_loss           | 0.0209         |
# --------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.5375019003674855
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_47
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  15.581461222966512  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C   0.140435   0.116793    0.138929
# 1  189  2021-04-06  2021-07-06       DDPG  -0.118399   0.039836    0.099977
# 2  252  2021-07-06  2021-10-04       DDPG  -0.417707  -0.711779   -0.228861
# 3  315  2021-10-04  2022-01-03       DDPG   0.420119   0.537502    0.590749

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.17246807815158638

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   10000.000000  2021-04-06           NaN  2021-04-06
# 1    9932.942395  2021-04-07     -0.006706  2021-04-07
# 2    9482.192349  2021-04-08     -0.045379  2021-04-08
# 3    9479.670850  2021-04-09     -0.000266  2021-04-09
# 4    9559.788524  2021-04-12      0.008452  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.048629
# Cumulative returns    -0.048629
# Annual volatility      0.187674
# Sharpe ratio          -0.172468
# Calmar ratio          -0.283878
# Stability              0.231501
# Max drawdown          -0.171302
# Omega ratio            0.971438
# Sortino ratio         -0.223198
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.837717
# Daily value at risk   -0.023773
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-4.863%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-4.863%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.767%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.17</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.28</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-17.13%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.22</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.377%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.09</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.56</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.13</td>
#       <td>2021-09-02</td>
#       <td>2021-09-30</td>
#       <td>2022-01-04</td>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16.86</td>
#       <td>2022-01-04</td>
#       <td>2022-03-11</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.80</td>
#       <td>2021-05-28</td>
#       <td>2021-07-22</td>
#       <td>2021-08-16</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.20</td>
#       <td>2021-04-06</td>
#       <td>2021-04-09</td>
#       <td>2021-04-16</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.87</td>
#       <td>2021-05-06</td>
#       <td>2021-05-12</td>
#       <td>2021-05-25</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.01%</td>
#       <td>-6.05%</td>
#       <td>3.43%</td>
#     </tr>
#   </tbody>
# </table>
