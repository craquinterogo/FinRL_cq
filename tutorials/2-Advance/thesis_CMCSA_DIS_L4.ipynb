# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['CMCSA','DIS']
print(DOW_30_TICKER)
# Out:
# ['CMCSA', 'DIS']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close    volume  \
# 6121  2022-05-26  104.220001  106.129997  103.959999  105.610001  11297800
# 6122  2022-05-27   44.130001   44.639999   43.980000   43.477409  18073500
# 6123  2022-05-27  106.889999  109.370003  106.529999  109.320000  13671300
# 6124  2022-05-31   43.910000   44.660000   43.480000   43.595551  25249600
# 6125  2022-05-31  110.000000  111.239998  107.910004  110.440002  20274600
#
#         tic  day
# 6121    DIS    3
# 6122  CMCSA    4
# 6123    DIS    4
# 6124  CMCSA    1
# 6125    DIS    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume    tic  \
# 0  2010-04-01   9.410000   9.520000   9.310000   7.365880  38877200  CMCSA
# 1  2010-04-01  35.070000  35.590000  35.009998  30.965103  14603000    DIS
# 2  2010-04-05   9.405000   9.490000   9.340000   7.387473  26500200  CMCSA
# 3  2010-04-05  35.279999  35.540001  35.070000  30.677664  10607900    DIS
# 4  2010-04-06   9.340000   9.460000   9.290000   7.363916  22708600  CMCSA
#
#    day
# 0    3
# 1    3
# 2    0
# 3    0
# 4    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 30#63 # rebalance_window is the number of days to retrain the model
validation_window = 30 #63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_60_3
# -------------------------------------
# | time/                 |           |
# |    fps                | 35        |
# |    iterations         | 100       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.85     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.656     |
# |    reward             | 1.5544572 |
# |    std                | 1.01      |
# |    value_loss         | 1.35      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 64         |
# |    iterations         | 200        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | -0.0419    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 2.62       |
# |    reward             | -2.2791286 |
# |    std                | 0.999      |
# |    value_loss         | 6.06       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 300       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0.00885   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -9.55     |
# |    reward             | 3.1383116 |
# |    std                | 1         |
# |    value_loss         | 17.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 109       |
# |    iterations         | 400       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.84     |
# |    explained_variance | 0.00669   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 10.6      |
# |    reward             | -4.025277 |
# |    std                | 0.999     |
# |    value_loss         | 21.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 127        |
# |    iterations         | 500        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 0.000866   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -67.9      |
# |    reward             | -31.355385 |
# |    std                | 0.991      |
# |    value_loss         | 426        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 600       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.15      |
# |    reward             | 1.0579076 |
# |    std                | 0.987     |
# |    value_loss         | 0.387     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 700       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0.0151    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -4.39     |
# |    reward             | 0.7161007 |
# |    std                | 0.992     |
# |    value_loss         | 4.75      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 167        |
# |    iterations         | 800        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.83      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -1.27      |
# |    reward             | -1.0103867 |
# |    std                | 0.996      |
# |    value_loss         | 2.75       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 178        |
# |    iterations         | 900        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.83      |
# |    explained_variance | 0.00429    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -12.5      |
# |    reward             | -1.6220925 |
# |    std                | 0.996      |
# |    value_loss         | 35.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -26.9    |
# |    reward             | 1.343659 |
# |    std                | 0.994    |
# |    value_loss         | 120      |
# ------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-02-17
# A2C Sharpe Ratio:  0.2745576523351684
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_60_2
# -------------------------------------
# | time/              |              |
# |    fps             | 173          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.111414164 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004447794 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0367      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00277    |
# |    reward               | -0.10947338 |
# |    std                  | 0.991       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.004555267  |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0869       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | 6.189812e-05 |
# |    std                  | 0.992        |
# |    value_loss           | 0.535        |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-02-17
# PPO Sharpe Ratio:  0.12962320740969152
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_60_2
# ======DDPG Validation from:  2021-01-04 to  2021-02-17
# ======Best Model Retraining from:  2010-04-01 to  2021-02-17
# ======Trading from:  2021-02-17 to  2021-03-31
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-02-17
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_90_2
# ---------------------------------------
# | time/                 |             |
# |    fps                | 59          |
# |    iterations         | 100         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.0085     |
# |    reward             | 0.068177395 |
# |    std                | 1.01        |
# |    value_loss         | 0.00186     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 65           |
# |    iterations         | 200          |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | 1.79e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.00688     |
# |    reward             | 0.0030331397 |
# |    std                | 1.02         |
# |    value_loss         | 1.84e-05     |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 300        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.00204   |
# |    reward             | 0.00841269 |
# |    std                | 1.05       |
# |    value_loss         | 6.33e-07   |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 100           |
# |    iterations         | 400           |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -2.99         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | 0.0241        |
# |    reward             | -0.0074091847 |
# |    std                | 1.08          |
# |    value_loss         | 4.34e-05      |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 114       |
# |    iterations         | 500       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.0489    |
# |    reward             | 0.0       |
# |    std                | 1.12      |
# |    value_loss         | 0.000388  |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 126           |
# |    iterations         | 600           |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -3.14         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.00217      |
# |    reward             | -4.746506e-05 |
# |    std                | 1.17          |
# |    value_loss         | 7.59e-07      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 136          |
# |    iterations         | 700          |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -3.24        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -0.0067      |
# |    reward             | 0.0010753412 |
# |    std                | 1.22         |
# |    value_loss         | 2.52e-06     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 144         |
# |    iterations         | 800         |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -3.35       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -0.00377    |
# |    reward             | 0.005589772 |
# |    std                | 1.29        |
# |    value_loss         | 4.62e-06    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 152           |
# |    iterations         | 900           |
# |    time_elapsed       | 29            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -3.46         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 0.00355       |
# |    reward             | 0.00037689303 |
# |    std                | 1.36          |
# |    value_loss         | 8.87e-07      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 158            |
# |    iterations         | 1000           |
# |    time_elapsed       | 31             |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -3.55          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | -0.00838       |
# |    reward             | -0.00037082305 |
# |    std                | 1.43           |
# |    value_loss         | 8.98e-06       |
# ------------------------------------------
# ======A2C Validation from:  2021-02-17 to  2021-03-31
# A2C Sharpe Ratio:  0.2473803002134207
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_90_2
# -------------------------------------
# | time/              |              |
# |    fps             | 131          |
# |    iterations      | 1            |
# |    time_elapsed    | 15           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.011259963 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054973294 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.121        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00387     |
# |    reward               | -2.8222935   |
# |    std                  | 1            |
# |    value_loss           | 0.407        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 3            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0054939557 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.25         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0015      |
# |    reward               | -0.18650888  |
# |    std                  | 1            |
# |    value_loss           | 6.31         |
# ------------------------------------------
# ======PPO Validation from:  2021-02-17 to  2021-03-31
# PPO Sharpe Ratio:  -0.32383882613697984
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_90_2
# ======DDPG Validation from:  2021-02-17 to  2021-03-31
# ======Best Model Retraining from:  2010-04-01 to  2021-03-31
# ======Trading from:  2021-03-31 to  2021-05-13
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-03-31
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_120_2
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.394     |
# |    reward             | 0.775566  |
# |    std                | 1.02      |
# |    value_loss         | 0.342     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 74         |
# |    iterations         | 200        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.524      |
# |    reward             | -0.8475429 |
# |    std                | 1.01       |
# |    value_loss         | 0.798      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 300       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -7.35     |
# |    reward             | 1.5197936 |
# |    std                | 1.02      |
# |    value_loss         | 4.61      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 116       |
# |    iterations         | 400       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 5.53      |
# |    reward             | -1.652749 |
# |    std                | 1.02      |
# |    value_loss         | 3.58      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 500       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.9      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -11.5     |
# |    reward             | -9.281263 |
# |    std                | 1.03      |
# |    value_loss         | 40        |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 154         |
# |    iterations         | 600         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.00716    |
# |    reward             | 0.013973684 |
# |    std                | 1.04        |
# |    value_loss         | 8.08e-06    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 170          |
# |    iterations         | 700          |
# |    time_elapsed       | 20           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -0.000191    |
# |    reward             | 0.0005646696 |
# |    std                | 1.05         |
# |    value_loss         | 5.69e-08     |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 800       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -2.98     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.0257   |
# |    reward             | 0.0       |
# |    std                | 1.07      |
# |    value_loss         | 7.94e-05  |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 196          |
# |    iterations         | 900          |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -3.02        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | -0.00106     |
# |    reward             | 0.0015950679 |
# |    std                | 1.1          |
# |    value_loss         | 1.52e-07     |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 206       |
# |    iterations         | 1000      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.041     |
# |    reward             | 0.0       |
# |    std                | 1.12      |
# |    value_loss         | 0.000163  |
# -------------------------------------
# ======A2C Validation from:  2021-03-31 to  2021-05-13
# A2C Sharpe Ratio:  -0.4415150047983642
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_120_2
# ------------------------------------
# | time/              |             |
# |    fps             | 150         |
# |    iterations      | 1           |
# |    time_elapsed    | 13          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.06467816 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041179806 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0405      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0375       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00169     |
# |    reward               | 1.2078172    |
# |    std                  | 1            |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 248           |
# |    iterations           | 3             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0045341398  |
# |    clip_fraction        | 0.0316        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0.00123       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.206         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00367      |
# |    reward               | -0.0076635703 |
# |    std                  | 1             |
# |    value_loss           | 1.24          |
# -------------------------------------------
# ======PPO Validation from:  2021-03-31 to  2021-05-13
# PPO Sharpe Ratio:  -0.17962493327659204
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_120_2
# ======DDPG Validation from:  2021-03-31 to  2021-05-13
# ======Best Model Retraining from:  2010-04-01 to  2021-05-13
# ======Trading from:  2021-05-13 to  2021-06-25
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-05-13
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_150_2
# -----------------------------------------
# | time/                 |               |
# |    fps                | 73            |
# |    iterations         | 100           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -2.93         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | 0.0012        |
# |    reward             | 0.00028392297 |
# |    std                | 1.05          |
# |    value_loss         | 4.35e-07      |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 200       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.000873 |
# |    reward             | 0.0       |
# |    std                | 1.1       |
# |    value_loss         | 1.93e-07  |
# -------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 92             |
# |    iterations         | 300            |
# |    time_elapsed       | 16             |
# |    total_timesteps    | 1500           |
# | train/                |                |
# |    entropy_loss       | -3.12          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 299            |
# |    policy_loss        | -0.00429       |
# |    reward             | -0.00018553392 |
# |    std                | 1.15           |
# |    value_loss         | 6.32e-06       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 112           |
# |    iterations         | 400           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -3.23         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | 0.00369       |
# |    reward             | -0.0030098697 |
# |    std                | 1.22          |
# |    value_loss         | 2.59e-06      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 127          |
# |    iterations         | 500          |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -3.3         |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | -0.0105      |
# |    reward             | -0.041767973 |
# |    std                | 1.26         |
# |    value_loss         | 2.42e-05     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 142          |
# |    iterations         | 600          |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -3.36        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.00295     |
# |    reward             | 0.0011084548 |
# |    std                | 1.3          |
# |    value_loss         | 7.59e-07     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 154          |
# |    iterations         | 700          |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -3.45        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.00219      |
# |    reward             | 5.686298e-06 |
# |    std                | 1.36         |
# |    value_loss         | 5.49e-07     |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 800      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.55    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0164  |
# |    reward             | 0.0      |
# |    std                | 1.43     |
# |    value_loss         | 1.7e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 900      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.66    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.000533 |
# |    reward             | 0.0      |
# |    std                | 1.51     |
# |    value_loss         | 1.56e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 175       |
# |    iterations         | 1000      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.78     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.00865   |
# |    reward             | 0.0       |
# |    std                | 1.6       |
# |    value_loss         | 6.82e-06  |
# -------------------------------------
# ======A2C Validation from:  2021-05-13 to  2021-06-25
# A2C Sharpe Ratio:  0.15420794700748694
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_150_2
# ------------------------------------
# | time/              |             |
# |    fps             | 141         |
# |    iterations      | 1           |
# |    time_elapsed    | 14          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.13787563 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 2            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0049957493 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.15         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000946    |
# |    reward               | -0.0667379   |
# |    std                  | 1.01         |
# |    value_loss           | 0.299        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006066015 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.105       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00188    |
# |    reward               | 0.001641087 |
# |    std                  | 1.02        |
# |    value_loss           | 0.226       |
# -----------------------------------------
# ======PPO Validation from:  2021-05-13 to  2021-06-25
# PPO Sharpe Ratio:  0.22947757464052468
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_150_2
# ======DDPG Validation from:  2021-05-13 to  2021-06-25
# ======Best Model Retraining from:  2010-04-01 to  2021-06-25
# ======Trading from:  2021-06-25 to  2021-08-09
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-06-25
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_180_2
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.15     |
# |    reward             | 0.460029 |
# |    std                | 1.01     |
# |    value_loss         | 0.116    |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 200         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.173      |
# |    reward             | -0.09639479 |
# |    std                | 1.01        |
# |    value_loss         | 0.0217      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 106        |
# |    iterations         | 300        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.0104    |
# |    reward             | 0.01110949 |
# |    std                | 1.03       |
# |    value_loss         | 3.43e-05   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 130         |
# |    iterations         | 400         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.93       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 0.0699      |
# |    reward             | -0.00523982 |
# |    std                | 1.05        |
# |    value_loss         | 0.000472    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 150          |
# |    iterations         | 500          |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -2.97        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | 0.0248       |
# |    reward             | -0.022070536 |
# |    std                | 1.07         |
# |    value_loss         | 0.000216     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 166           |
# |    iterations         | 600           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -3            |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.167        |
# |    reward             | -0.0041731214 |
# |    std                | 1.09          |
# |    value_loss         | 0.0066        |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 181            |
# |    iterations         | 700            |
# |    time_elapsed       | 19             |
# |    total_timesteps    | 3500           |
# | train/                |                |
# |    entropy_loss       | -3.05          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 699            |
# |    policy_loss        | 0.114          |
# |    reward             | -0.00046738106 |
# |    std                | 1.11           |
# |    value_loss         | 0.00181        |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 800       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.05     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.156    |
# |    reward             | 0.2046894 |
# |    std                | 1.11      |
# |    value_loss         | 0.00491   |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 204         |
# |    iterations         | 900         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -3.07       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 6.01        |
# |    reward             | -0.34817082 |
# |    std                | 1.12        |
# |    value_loss         | 1.47        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 214        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -3.09      |
# |    explained_variance | 0.0633     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 2.56       |
# |    reward             | 0.17901875 |
# |    std                | 1.13       |
# |    value_loss         | 0.646      |
# --------------------------------------
# ======A2C Validation from:  2021-06-25 to  2021-08-09
# A2C Sharpe Ratio:  -0.24539512988294682
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_180_2
# -------------------------------------
# | time/              |              |
# |    fps             | 177          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.036994092 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005395026 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.024       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00201    |
# |    reward               | 0.10177968  |
# |    std                  | 0.991       |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0049597425 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.254        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00222     |
# |    reward               | 0.041691266  |
# |    std                  | 0.989        |
# |    value_loss           | 1.6          |
# ------------------------------------------
# ======PPO Validation from:  2021-06-25 to  2021-08-09
# PPO Sharpe Ratio:  0.03221518767495401
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_180_2
# ======DDPG Validation from:  2021-06-25 to  2021-08-09
# ======Best Model Retraining from:  2010-04-01 to  2021-08-09
# ======Trading from:  2021-08-09 to  2021-09-21
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2021-08-09
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_210_2
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.9      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.214     |
# |    reward             | 0.7207775 |
# |    std                | 1.03      |
# |    value_loss         | 0.258     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 200        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -0.0258    |
# ...
# |    reward             | -0.003906939 |
# |    std                | 1.28         |
# |    value_loss         | 2.66e-07     |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 125      |
# |    iterations         | 500      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.41    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.00382 |
# |    reward             | 0.0      |
# |    std                | 1.33     |
# |    value_loss         | 2.2e-06  |
# ------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 141            |
# |    iterations         | 600            |
# |    time_elapsed       | 21             |
# |    total_timesteps    | 3000           |
# | train/                |                |
# |    entropy_loss       | -3.47          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 599            |
# |    policy_loss        | -0.00662       |
# |    reward             | -0.00060231495 |
# |    std                | 1.37           |
# |    value_loss         | 3.74e-06       |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 155         |
# |    iterations         | 700         |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -3.54       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.02       |
# |    reward             | 0.021602077 |
# |    std                | 1.42        |
# |    value_loss         | 3.02e-05    |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 167      |
# |    iterations         | 800      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.61    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.00453 |
# |    reward             | 0.0      |
# |    std                | 1.47     |
# |    value_loss         | 2.11e-06 |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 178           |
# |    iterations         | 900           |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -3.67         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 0.01          |
# |    reward             | -0.0003931554 |
# |    std                | 1.52          |
# |    value_loss         | 2.3e-05       |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 1000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.73    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00286  |
# |    reward             | 0.0      |
# |    std                | 1.56     |
# |    value_loss         | 1.1e-06  |
# ------------------------------------
# ======A2C Validation from:  2021-12-15 to  2022-01-28
# A2C Sharpe Ratio:  -0.43772519086605005
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_300_2
# -----------------------------------
# | time/              |            |
# |    fps             | 163        |
# |    iterations      | 1          |
# |    time_elapsed    | 12         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.02359477 |
# -----------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 237           |
# |    iterations           | 2             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00038426978 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.193         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | 0.000196      |
# |    reward               | -0.042929273  |
# |    std                  | 0.996         |
# |    value_loss           | 0.299         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005168689 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.739       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00265    |
# |    reward               | 0.024612771 |
# |    std                  | 0.995       |
# |    value_loss           | 6.21        |
# -----------------------------------------
# ======PPO Validation from:  2021-12-15 to  2022-01-28
# PPO Sharpe Ratio:  -0.6044043147713426
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_300_2
# ======DDPG Validation from:  2021-12-15 to  2022-01-28
# ======Best Model Retraining from:  2010-04-01 to  2022-01-28
# ======Trading from:  2022-01-28 to  2022-03-14
# ============================================
# turbulence_threshold:  19.88457090719197
# ======Model training from:  2010-04-01 to  2022-01-28
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_330_2
# ---------------------------------------
# | time/                 |             |
# |    fps                | 84          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.95       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.00338    |
# |    reward             | 0.015214832 |
# |    std                | 1.06        |
# |    value_loss         | 1.57e-06    |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 69       |
# |    iterations         | 200      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0058   |
# |    reward             | 0.0      |
# |    std                | 1.1      |
# |    value_loss         | 5.91e-06 |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 90           |
# |    iterations         | 300          |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 0.000632     |
# |    reward             | 0.0006991436 |
# |    std                | 1.15         |
# |    value_loss         | 5.6e-07      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 111          |
# |    iterations         | 400          |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -3.19        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -0.00577     |
# |    reward             | -0.009276412 |
# |    std                | 1.19         |
# |    value_loss         | 7.54e-06     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 129         |
# |    iterations         | 500         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -3.25       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 0.106       |
# |    reward             | -0.19579655 |
# |    std                | 1.23        |
# |    value_loss         | 0.0294      |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 144      |
# |    iterations         | 600      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -3.3     |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 8.81e-05 |
# |    reward             | 0.0      |
# |    std                | 1.26     |
# |    value_loss         | 3.13e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 158      |
# |    iterations         | 700      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.000291 |
# |    reward             | 0.0      |
# |    std                | 1.29     |
# |    value_loss         | 1.31e-08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 800       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.4      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.00914  |
# |    reward             | 0.0       |
# |    std                | 1.33      |
# |    value_loss         | 1.5e-05   |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 181           |
# |    iterations         | 900           |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -3.48         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 0.000338      |
# |    reward             | -0.0011499588 |
# |    std                | 1.38          |
# |    value_loss         | 4.87e-08      |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 191      |
# |    iterations         | 1000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.59    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00936 |
# |    reward             | 0.0      |
# |    std                | 1.46     |
# |    value_loss         | 1e-05    |
# ------------------------------------
# ======A2C Validation from:  2022-01-28 to  2022-03-14
# A2C Sharpe Ratio:  -0.6093881254872231
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_330_2
# ------------------------------------
# | time/              |             |
# |    fps             | 163         |
# |    iterations      | 1           |
# |    time_elapsed    | 12          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.17326805 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.00414495   |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.267        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000458    |
# |    reward               | -0.005582377 |
# |    std                  | 1            |
# |    value_loss           | 0.558        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 3             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0058725243  |
# |    clip_fraction        | 0.0465        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.11          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00266      |
# |    reward               | 0.00035588976 |
# |    std                  | 1             |
# |    value_loss           | 0.304         |
# -------------------------------------------
# ======PPO Validation from:  2022-01-28 to  2022-03-14
# PPO Sharpe Ratio:  -0.47160422348128184
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_330_2
# ======DDPG Validation from:  2022-01-28 to  2022-03-14
# ======Best Model Retraining from:  2010-04-01 to  2022-03-14
# ======Trading from:  2022-03-14 to  2022-04-26
# Ensemble Strategy took:  38.34123293558756  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0   60  2021-01-04  2021-02-17        A2C   0.274558   0.129623         0.0
# 1   90  2021-02-17  2021-03-31        A2C    0.24738  -0.323839   -0.238144
# 2  120  2021-03-31  2021-05-13        PPO  -0.441515  -0.179625   -0.276948
# 3  150  2021-05-13  2021-06-25        PPO   0.154208   0.229478         0.0
# 4  180  2021-06-25  2021-08-09        PPO  -0.245395   0.032215         0.0
# 5  210  2021-08-09  2021-09-21        A2C   0.117322  -0.039101   -0.105297
# 6  240  2021-09-21  2021-11-02        PPO  -0.331132   -0.22208   -0.253457
# 7  270  2021-11-02  2021-12-15       DDPG  -0.522564  -0.367047         0.0
# 8  300  2021-12-15  2022-01-28       DDPG  -0.437725  -0.604404   -0.112781
# 9  330  2022-01-28  2022-03-14       DDPG  -0.609388  -0.471604         0.0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.9236365618772793

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-02-17           NaN  2021-02-17
# 1   9.995979e+05  2021-02-18     -0.000402  2021-02-18
# 2   9.997053e+05  2021-02-19      0.000107  2021-02-19
# 3   1.002120e+06  2021-02-22      0.002415  2021-02-22
# 4   1.004233e+06  2021-02-23      0.002108  2021-02-23

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.042464
# Cumulative returns    -0.050346
# Annual volatility      0.045990
# Sharpe ratio          -0.923637
# Calmar ratio          -0.558502
# Stability              0.762542
# Max drawdown          -0.076032
# Omega ratio            0.832905
# Sortino ratio         -1.224408
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.911568
# Daily value at risk   -0.005963
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (299, 8)
# Annual return          0.072506
# Cumulative returns     0.086599
# Annual volatility      0.153945
# Sharpe ratio           0.533075
# Calmar ratio           0.555680
# Stability              0.530201
# Max drawdown          -0.130481
# Omega ratio            1.091667
# Sortino ratio          0.754643
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.921990
# Daily value at risk   -0.019070
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (299, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-02-17</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-25</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-4.246%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-5.035%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.599%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.92</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.56</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.76</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.603%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.22</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.596%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.05</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.60</td>
#       <td>2021-03-08</td>
#       <td>2021-12-01</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.63</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-08</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.04</td>
#       <td>2021-02-17</td>
#       <td>2021-02-18</td>
#       <td>2021-02-22</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.02%</td>
#       <td>-1.83%</td>
#       <td>1.26%</td>
#     </tr>
#   </tbody>
# </table>
