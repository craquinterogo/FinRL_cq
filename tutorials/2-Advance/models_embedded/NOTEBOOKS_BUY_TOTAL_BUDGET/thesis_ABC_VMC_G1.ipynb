# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['ABC','VMC']
print(DOW_30_TICKER)
# Out:
# ['ABC', 'VMC']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# ABC    3063
# VMC    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26  162.279999  165.449997  161.710007  163.544281   334900
# 6122  2022-05-27  155.529999  157.039993  154.550003  155.893753  1650200
# 6123  2022-05-27  165.770004  169.740005  165.770004  168.949982   461800
# 6124  2022-05-31  156.000000  156.380005  153.729996  153.836502  4329600
# 6125  2022-05-31  167.330002  167.330002  163.509995  164.131638   968200
#
#       tic  day
# 6121  VMC    3
# 6122  ABC    4
# 6123  VMC    4
# 6124  ABC    1
# 6125  VMC    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume  tic  day
# 0  2010-04-01  28.990000  29.129999  28.420000  23.580265  3680900  ABC    3
# 1  2010-04-01  47.459999  49.270000  47.459999  43.927681  1512100  VMC    3
# 2  2010-04-05  28.629999  29.020000  28.530001  23.852430  2339700  ABC    0
# 3  2010-04-05  49.119999  49.950001  48.910000  44.222992   843600  VMC    0
# 4  2010-04-06  28.920000  29.139999  28.799999  23.943159  1739100  ABC    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# ABC    3063
# VMC    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  20.23699031118985
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_62
# ----------------------------------------
# | time/                 |              |
# |    fps                | 32           |
# |    iterations         | 100          |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.0039      |
# |    reward             | 0.0034284352 |
# |    std                | 1.03         |
# |    value_loss         | 0.000154     |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 60        |
# |    iterations         | 200       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.277    |
# |    reward             | -0.699775 |
# |    std                | 1.04      |
# |    value_loss         | 0.35      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 300       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.9      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 3.3       |
# |    reward             | 1.1141747 |
# |    std                | 1.03      |
# |    value_loss         | 0.729     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 105      |
# |    iterations         | 400      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 4.93     |
# |    reward             | 0.877636 |
# |    std                | 1.04     |
# |    value_loss         | 4.39     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 500        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 8.03       |
# |    reward             | -6.9089847 |
# |    std                | 1.05       |
# |    value_loss         | 16.6       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 140      |
# |    iterations         | 600      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.95    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00177  |
# |    reward             | 0.0      |
# |    std                | 1.06     |
# |    value_loss         | 4.39e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 700      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00646  |
# |    reward             | 0.0      |
# |    std                | 1.07     |
# |    value_loss         | 8.8e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 800       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.0102   |
# |    reward             | 0.0       |
# |    std                | 1.09      |
# |    value_loss         | 2.32e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 900       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.05     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.000396 |
# |    reward             | 0.0       |
# |    std                | 1.11      |
# |    value_loss         | 1.15e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 192       |
# |    iterations         | 1000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.11     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.00169  |
# |    reward             | 0.0       |
# |    std                | 1.15      |
# |    value_loss         | 3.35e-07  |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.08915624165201386
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_53
# ------------------------------------
# | time/              |             |
# |    fps             | 161         |
# |    iterations      | 1           |
# |    time_elapsed    | 12          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.09380158 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0013333495 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.45         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000189     |
# |    reward               | -0.7657273   |
# |    std                  | 1            |
# |    value_loss           | 3.81         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005853416 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.00164     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.53        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00322    |
# |    reward               | 0.048256475 |
# |    std                  | 1.01        |
# |    value_loss           | 4.64        |
# -----------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.32681731263678454
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_53
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  20.23699031118985
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_51
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 100        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.548      |
# |    reward             | 0.23664142 |
# |    std                | 1.01       |
# |    value_loss         | 0.0413     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 200         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.85       |
# |    explained_variance | -0.272      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -1.42       |
# |    reward             | -0.87829345 |
# |    std                | 1.01        |
# |    value_loss         | 1.39        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 97         |
# |    iterations         | 300        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -0.114     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -9.33      |
# |    reward             | -2.2685397 |
# |    std                | 1.01       |
# |    value_loss         | 12.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 400        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.163      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -1.8       |
# |    reward             | 0.62536603 |
# |    std                | 1          |
# |    value_loss         | 7.02       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 138        |
# |    iterations         | 500        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | 0.00407    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -7.27      |
# |    reward             | -7.8520026 |
# |    std                | 1          |
# |    value_loss         | 56.8       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 600      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 2.56     |
# |    reward             | 0.594373 |
# |    std                | 1.01     |
# |    value_loss         | 1.41     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 171        |
# |    iterations         | 700        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | 0.00374    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -2.05      |
# |    reward             | -3.1666098 |
# |    std                | 1          |
# |    value_loss         | 0.621      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 184        |
# |    iterations         | 800        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 15.3       |
# |    reward             | 0.85549563 |
# |    std                | 0.99       |
# |    value_loss         | 52.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 900        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.81      |
# |    explained_variance | 0.041      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 16.6       |
# |    reward             | -1.8764486 |
# |    std                | 0.988      |
# |    value_loss         | 57         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1000      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 0.006     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 27.2      |
# |    reward             | -4.701008 |
# |    std                | 0.987     |
# |    value_loss         | 140       |
# -------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.024306547858267583
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_51
# ------------------------------------
# | time/              |             |
# |    fps             | 164         |
# |    iterations      | 1           |
# |    time_elapsed    | 12          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.042867612 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0022439752 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00332     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.23         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000948    |
# |    reward               | -0.5217097   |
# |    std                  | 1            |
# |    value_loss           | 2.98         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0062850593 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.000257    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.92         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00134     |
# |    reward               | 0.022983812  |
# |    std                  | 1.01         |
# |    value_loss           | 6.62         |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.32497662135588273
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_51
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  20.23699031118985
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_51
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -0.0879   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.46      |
# |    reward             | 0.8514179 |
# |    std                | 1.02      |
# |    value_loss         | 0.625     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 75         |
# |    iterations         | 200        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0.214      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.0172     |
# |    reward             | -1.6496773 |
# |    std                | 1.02       |
# |    value_loss         | 2.1        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | -0.776     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -10.8      |
# |    reward             | -2.3742638 |
# |    std                | 1.02       |
# |    value_loss         | 15.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 108       |
# |    iterations         | 400       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | -0.0314   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -1.8      |
# |    reward             | 0.8465256 |
# |    std                | 1.02      |
# |    value_loss         | 17.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 127       |
# |    iterations         | 500       |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | 0.00158   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -34.8     |
# |    reward             | -7.203112 |
# |    std                | 1.02      |
# |    value_loss         | 232       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 600        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -1.05      |
# |    reward             | -1.1108114 |
# |    std                | 1.02       |
# |    value_loss         | 1.47       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 157        |
# |    iterations         | 700        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -2.02      |
# |    reward             | 0.13599499 |
# |    std                | 1.02       |
# |    value_loss         | 1.23       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 800      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | -0.0662  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.24     |
# |    reward             | 0.503355 |
# |    std                | 1.03     |
# |    value_loss         | 3.07     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 900       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -7.8      |
# |    reward             | 11.395877 |
# |    std                | 1.03      |
# |    value_loss         | 142       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 192         |
# |    iterations         | 1000        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -2.89       |
# |    explained_variance | 0.0015      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 5.62        |
# |    reward             | -13.4182005 |
# |    std                | 1.02        |
# |    value_loss         | 53.4        |
# ---------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  -0.11232908155153692
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_51
# ------------------------------------
# | time/              |             |
# |    fps             | 168         |
# |    iterations      | 1           |
# |    time_elapsed    | 12          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.08555418 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004145163 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.0101     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.987       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00134    |
# |    reward               | 0.04420949  |
# |    std                  | 0.997       |
# |    value_loss           | 3.52        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008366296 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.22        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00545    |
# |    reward               | -0.20015056 |
# |    std                  | 0.991       |
# |    value_loss           | 6.16        |
# -----------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  -0.15119394628945734
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_50
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  20.23699031118985
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_48
# ------------------------------------
# | time/                 |          |
# |    fps                | 88       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.00803  |
# |    reward             | 0.0      |
# |    std                | 1.04     |
# |    value_loss         | 1.74e-05 |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 73          |
# |    iterations         | 200         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.93       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.129      |
# |    reward             | -0.13029365 |
# |    std                | 1.05        |
# |    value_loss         | 0.0352      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.91      |
# |    reward             | -0.1410861 |
# |    std                | 1.05       |
# |    value_loss         | 0.0731     |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 113           |
# |    iterations         | 400           |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -2.95         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | 0.0299        |
# |    reward             | 0.00069457706 |
# |    std                | 1.06          |
# |    value_loss         | 0.000355      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 131          |
# |    iterations         | 500          |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -2.97        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | 0.115        |
# |    reward             | -0.007495751 |
# |    std                | 1.07         |
# |    value_loss         | 0.0018       |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 147       |
# |    iterations         | 600       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.12     |
# |    reward             | 0.0228816 |
# |    std                | 1.09      |
# |    value_loss         | 0.00525   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 161       |
# |    iterations         | 700       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -1.92     |
# |    reward             | -0.172361 |
# |    std                | 1.09      |
# |    value_loss         | 0.46      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 173       |
# |    iterations         | 800       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.897    |
# |    reward             | 0.5196787 |
# |    std                | 1.09      |
# |    value_loss         | 1.31      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 184        |
# |    iterations         | 900        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -3         |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 5.59       |
# |    reward             | -0.5795455 |
# |    std                | 1.09       |
# |    value_loss         | 9.67       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 1000       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -3.01      |
# |    explained_variance | 0.0118     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -19.7      |
# |    reward             | -2.6575208 |
# |    std                | 1.09       |
# |    value_loss         | 43.2       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.2774737893433796
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_48
# -------------------------------------
# | time/              |              |
# |    fps             | 179          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0047975983 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006300345 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00282    |
# |    reward               | -0.02603566 |
# |    std                  | 0.997       |
# |    value_loss           | 0.596       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046449346 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.624        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00396     |
# |    reward               | -0.07926019  |
# |    std                  | 0.994        |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.28451021290800904
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_48
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  14.252683266003926  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO   0.089156   0.326817         0.0
# 1  189  2021-04-06  2021-07-06        A2C  -0.024307  -0.324977   -0.160144
# 2  252  2021-07-06  2021-10-04       DDPG  -0.112329  -0.151194   -0.010173
# 3  315  2021-10-04  2022-01-03        PPO   0.277474    0.28451    0.250707

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  1.8303670002192172

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.999944e+05  2021-04-07     -0.000006  2021-04-07
# 2   9.998819e+05  2021-04-08     -0.000112  2021-04-08
# 3   1.000067e+06  2021-04-09      0.000185  2021-04-09
# 4   1.000216e+06  2021-04-12      0.000149  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.272929
# Cumulative returns     0.272929
# Annual volatility      0.137578
# Sharpe ratio           1.830367
# Calmar ratio           2.562458
# Stability              0.597132
# Max drawdown          -0.106511
# Omega ratio            1.425646
# Sortino ratio          2.868457
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.478435
# Daily value at risk   -0.016334
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>27.293%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>27.293%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.758%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.83</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.56</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.651%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.43</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.87</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.48</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.633%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.35</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10.65</td>
#       <td>2021-11-03</td>
#       <td>2021-12-01</td>
#       <td>2021-12-22</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.51</td>
#       <td>2022-01-11</td>
#       <td>2022-01-26</td>
#       <td>2022-02-01</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.47</td>
#       <td>2021-09-15</td>
#       <td>2021-10-06</td>
#       <td>2021-11-02</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.31</td>
#       <td>2022-02-16</td>
#       <td>2022-02-24</td>
#       <td>2022-03-02</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.45</td>
#       <td>2021-12-30</td>
#       <td>2022-01-06</td>
#       <td>2022-01-10</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-3.73%</td>
#       <td>3.53%</td>
#     </tr>
#   </tbody>
# </table>
