# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AMGN','PCAR']
print(DOW_30_TICKER)
# Out:
# ['AMGN', 'PCAR']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AMGN    3063
# PCAR    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 6121  2022-05-26   84.000000   85.050003   83.790001   83.534164  2069800
# 6122  2022-05-27  253.500000  256.230011  250.919998  251.571075  2678900
# 6123  2022-05-27   85.070000   85.870003   84.919998   85.053146  2347300
# 6124  2022-05-31  255.000000  257.260010  251.009995  253.029663  6737500
# 6125  2022-05-31   85.470001   87.599998   84.360001   86.214722  3783300
#
#        tic  day
# 6121  PCAR    3
# 6122  AMGN    4
# 6123  PCAR    4
# 6124  AMGN    1
# 6125  PCAR    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close   volume   tic  day
# 0  2010-04-01  59.950001  60.939999  59.950001  45.575970  5916500  AMGN    3
# 1  2010-04-01  43.509998  44.250000  43.349998  29.000076  2009200  PCAR    3
# 2  2010-04-05  60.740002  60.889999  60.270000  45.291111  3679800  AMGN    0
# 3  2010-04-05  44.020000  44.980000  43.830002  29.615402  3137700  PCAR    0
# 4  2010-04-06  60.250000  60.490002  59.840000  45.193668  3947200  AMGN    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# AMGN    3063
# PCAR    3063
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AMGN    3063
# PCAR    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 50000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  18.791680926470168
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_49
# ------------------------------------------
# | time/                 |                |
# |    fps                | 106            |
# |    iterations         | 100            |
# |    time_elapsed       | 4              |
# |    total_timesteps    | 500            |
# | train/                |                |
# |    entropy_loss       | -2.94          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 99             |
# |    policy_loss        | -0.00526       |
# |    reward             | -0.00032485853 |
# |    std                | 1.05           |
# |    value_loss         | 3.77e-06       |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 161          |
# |    iterations         | 200          |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -3.02        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.128       |
# |    reward             | -0.065436855 |
# |    std                | 1.1          |
# |    value_loss         | 0.00296      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 197         |
# |    iterations         | 300         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -3.06       |
# |    explained_variance | -1.62       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.649      |
# |    reward             | 0.068404086 |
# |    std                | 1.12        |
# |    value_loss         | 0.0661      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 223          |
# |    iterations         | 400          |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -3.04        |
# |    explained_variance | -1.28        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.0689       |
# |    reward             | -0.011540642 |
# |    std                | 1.11         |
# |    value_loss         | 0.0207       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 242         |
# |    iterations         | 500         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -3.06       |
# |    explained_variance | -3.26       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.082      |
# |    reward             | -0.11920574 |
# |    std                | 1.12        |
# |    value_loss         | 0.124       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 252          |
# |    iterations         | 600          |
# |    time_elapsed       | 11           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -3.07        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.0173      |
# |    reward             | -0.017679922 |
# |    std                | 1.12         |
# |    value_loss         | 6.33e-05     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 260         |
# |    iterations         | 700         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -3.08       |
# |    explained_variance | -2.23       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.167      |
# |    reward             | 0.005677937 |
# |    std                | 1.13        |
# |    value_loss         | 0.00708     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 267         |
# |    iterations         | 800         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -3.09       |
# |    explained_variance | -4.13       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -0.175      |
# |    reward             | 0.012688694 |
# |    std                | 1.13        |
# |    value_loss         | 0.0141      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 275         |
# |    iterations         | 900         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -3.1        |
# |    explained_variance | -18.6       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -0.0735     |
# |    reward             | 0.018310552 |
# |    std                | 1.14        |
# |    value_loss         | 0.00635     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 282          |
# |    iterations         | 1000         |
# |    time_elapsed       | 17           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -3.12        |
# |    explained_variance | 0.221        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.306       |
# |    reward             | -0.028113648 |
# |    std                | 1.15         |
# |    value_loss         | 0.011        |
# ----------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.16303093326579654
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_40
# ------------------------------------
# | time/              |             |
# |    fps             | 488         |
# |    iterations      | 1           |
# |    time_elapsed    | 4           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.002163892 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 446          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0056914724 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -3.76        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0157      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0072      |
# |    reward               | -0.11163981  |
# |    std                  | 0.996        |
# |    value_loss           | 0.0673       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0056360895 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.877       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.023       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00594     |
# |    reward               | 0.07896657   |
# |    std                  | 0.994        |
# |    value_loss           | 0.0578       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.040986206548388006
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_40
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  18.791680926470168
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_38
# --------------------------------------
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 100        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.202      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.011      |
# |    reward             | 0.10460302 |
# |    std                | 1.01       |
# |    value_loss         | 0.00264    |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 386          |
# |    iterations         | 200          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.85        |
# |    explained_variance | -1.85        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.128        |
# |    reward             | -0.085517265 |
# |    std                | 1.01         |
# |    value_loss         | 0.0127       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 391        |
# |    iterations         | 300        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -2.84      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 0.347      |
# |    reward             | 0.07435497 |
# |    std                | 1.02       |
# |    value_loss         | 0.0447     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 392          |
# |    iterations         | 400          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.87        |
# |    explained_variance | 0.156        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.275        |
# |    reward             | -0.047268365 |
# |    std                | 1.02         |
# |    value_loss         | 0.0477       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 392        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0.752      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -0.166     |
# |    reward             | -0.5439742 |
# |    std                | 1.02       |
# |    value_loss         | 0.025      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 391          |
# |    iterations         | 600          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -2.89        |
# |    explained_variance | -8.99        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 0.0718       |
# |    reward             | -0.004069848 |
# |    std                | 1.02         |
# |    value_loss         | 0.00231      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 394          |
# |    iterations         | 700          |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | -144         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -0.299       |
# |    reward             | -0.008625911 |
# |    std                | 1.03         |
# |    value_loss         | 0.0215       |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 394            |
# |    iterations         | 800            |
# |    time_elapsed       | 10             |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -2.92          |
# |    explained_variance | -4.24          |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | -0.129         |
# |    reward             | -0.00057732826 |
# |    std                | 1.04           |
# |    value_loss         | 0.00217        |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 392         |
# |    iterations         | 900         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -2.95       |
# |    explained_variance | -1.04       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -0.045      |
# |    reward             | 0.059465725 |
# |    std                | 1.06        |
# |    value_loss         | 0.00189     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 390          |
# |    iterations         | 1000         |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.98        |
# |    explained_variance | -0.114       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.263        |
# |    reward             | 0.0035342902 |
# |    std                | 1.07         |
# |    value_loss         | 0.0208       |
# ----------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.07918887865247921
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_38
# ------------------------------------
# | time/              |             |
# |    fps             | 527         |
# |    iterations      | 1           |
# |    time_elapsed    | 3           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.036382385 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007771584 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -1.19       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0207     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00946    |
# |    reward               | -0.21487884 |
# |    std                  | 1.01        |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0069346293 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0694       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00453     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00903     |
# |    reward               | -0.04649582  |
# |    std                  | 1.01         |
# |    value_loss           | 0.0776       |
# ------------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.00846936107536217
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_38
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  18.791680926470168
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_38
# --------------------------------------
# | time/                 |            |
# |    fps                | 381        |
# |    iterations         | 100        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | -14        |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -0.456     |
# |    reward             | 0.08255989 |
# |    std                | 1.03       |
# |    value_loss         | 0.054      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 397         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | -0.338      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.0108     |
# |    reward             | -0.12664846 |
# |    std                | 1.03        |
# |    value_loss         | 0.0152      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 398         |
# |    iterations         | 300         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.89       |
# |    explained_variance | 0.205       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.569      |
# |    reward             | 0.018087374 |
# |    std                | 1.03        |
# |    value_loss         | 0.0891      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 403         |
# |    iterations         | 400         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | -0.676      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 1.29        |
# |    reward             | 0.037873935 |
# |    std                | 1.02        |
# |    value_loss         | 0.258       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 405        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 1.02       |
# |    reward             | -1.0809104 |
# |    std                | 1.02       |
# |    value_loss         | 0.386      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 406          |
# |    iterations         | 600          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -2.9         |
# |    explained_variance | -1.24        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 0.193        |
# |    reward             | -0.021479055 |
# |    std                | 1.03         |
# |    value_loss         | 0.00718      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 409         |
# |    iterations         | 700         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.193      |
# |    reward             | 0.002784943 |
# |    std                | 1.03        |
# |    value_loss         | 0.0034      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 410         |
# |    iterations         | 800         |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.9        |
# |    explained_variance | -18.9       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 0.00175     |
# |    reward             | 0.043889474 |
# |    std                | 1.03        |
# |    value_loss         | 0.0121      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 900        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0.0324     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -0.881     |
# |    reward             | 0.21169642 |
# |    std                | 1.04       |
# |    value_loss         | 0.24       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 1000       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.92      |
# |    explained_variance | 0.59       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 0.117      |
# |    reward             | 0.03614622 |
# |    std                | 1.05       |
# |    value_loss         | 0.0126     |
# --------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  -0.4705366543162416
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_38
# -----------------------------------
# | time/              |            |
# |    fps             | 560        |
# |    iterations      | 1          |
# |    time_elapsed    | 3          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.11353022 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.003746424 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | -0.849      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0341     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00576    |
# |    reward               | 0.07148689  |
# |    std                  | 0.986       |
# |    value_loss           | 0.033       |
# -----------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 504            |
# |    iterations           | 3              |
# |    time_elapsed         | 12             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | 0.0049692765   |
# |    clip_fraction        | 0.0479         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.8           |
# |    explained_variance   | -0.729         |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0186        |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.00653       |
# |    reward               | -0.00016900344 |
# |    std                  | 0.982          |
# |    value_loss           | 0.0305         |
# --------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  -0.27577508371173254
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_37
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  18.791680926470168
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_35
# --------------------------------------
# | time/                 |            |
# |    fps                | 315        |
# |    iterations         | 100        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | -0.873     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.465      |
# |    reward             | 0.11421646 |
# |    std                | 1.01       |
# |    value_loss         | 0.0318     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 346          |
# |    iterations         | 200          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.85        |
# |    explained_variance | -1.63        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.0838       |
# |    reward             | -0.075925365 |
# |    std                | 1.01         |
# |    value_loss         | 0.0128       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 357         |
# |    iterations         | 300         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | -0.717      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -0.152      |
# |    reward             | 0.112800576 |
# |    std                | 1.01        |
# |    value_loss         | 0.0138      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 364         |
# |    iterations         | 400         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | 0.236       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 0.159       |
# |    reward             | -0.04271535 |
# |    std                | 1.02        |
# |    value_loss         | 0.0311      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 365        |
# |    iterations         | 500        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -1.59      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -1.02      |
# |    reward             | -0.3208318 |
# |    std                | 1.03       |
# |    value_loss         | 0.251      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 367        |
# |    iterations         | 600        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -7.85      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -0.235     |
# |    reward             | 0.09194808 |
# |    std                | 1.03       |
# |    value_loss         | 0.0133     |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 369           |
# |    iterations         | 700           |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.91         |
# |    explained_variance | -8.17         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.204         |
# |    reward             | -0.0076051126 |
# |    std                | 1.04          |
# |    value_loss         | 0.00849       |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 372            |
# |    iterations         | 800            |
# |    time_elapsed       | 10             |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -2.92          |
# |    explained_variance | -4.48          |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | -0.233         |
# |    reward             | -0.00053993607 |
# |    std                | 1.04           |
# |    value_loss         | 0.0137         |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 372          |
# |    iterations         | 900          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -2.92        |
# |    explained_variance | -3.62        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 0.286        |
# |    reward             | -0.011968155 |
# |    std                | 1.04         |
# |    value_loss         | 0.0225       |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 373          |
# |    iterations         | 1000         |
# |    time_elapsed       | 13           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -0.869       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.329       |
# |    reward             | -0.063802555 |
# |    std                | 1.05         |
# |    value_loss         | 0.0257       |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.33392975331499913
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_35
# -----------------------------------
# | time/              |            |
# |    fps             | 524        |
# |    iterations      | 1          |
# |    time_elapsed    | 3          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.01602144 |
# -----------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 496            |
# |    iterations           | 2              |
# |    time_elapsed         | 8              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.006973629    |
# |    clip_fraction        | 0.0788         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | -1.5           |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0169        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00898       |
# |    reward               | -0.00023458019 |
# |    std                  | 1              |
# |    value_loss           | 0.0403         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.002962892  |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.492       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0185      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00406     |
# |    reward               | 0.0042426446 |
# |    std                  | 1            |
# |    value_loss           | 0.0273       |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.22888149657068643
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_35
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  11.951932934919993  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06       DDPG   0.163031   0.040986    0.248685
# 1  189  2021-04-06  2021-07-06        PPO  -0.079189  -0.008469   -0.031517
# 2  252  2021-07-06  2021-10-04       DDPG  -0.470537  -0.275775   -0.241334
# 3  315  2021-10-04  2022-01-03        A2C    0.33393   0.228881         0.0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.12572824525261855

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   50000.000000  2021-04-06           NaN  2021-04-06
# 1   49883.568694  2021-04-07     -0.002329  2021-04-07
# 2   49625.140378  2021-04-08     -0.005181  2021-04-08
# 3   50038.043039  2021-04-09      0.008320  2021-04-09
# 4   50036.030954  2021-04-12     -0.000040  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.005313
# Cumulative returns     0.005313
# Annual volatility      0.197824
# Sharpe ratio           0.125728
# Calmar ratio           0.031643
# Stability              0.043065
# Max drawdown          -0.167911
# Omega ratio            1.022367
# Sortino ratio          0.177847
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.149818
# Daily value at risk   -0.024825
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.531%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.531%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.782%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-16.791%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.482%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.55</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.79</td>
#       <td>2021-04-20</td>
#       <td>2021-10-04</td>
#       <td>2022-01-13</td>
#       <td>193</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.93</td>
#       <td>2022-01-14</td>
#       <td>2022-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.75</td>
#       <td>2021-04-06</td>
#       <td>2021-04-08</td>
#       <td>2021-04-09</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.13</td>
#       <td>2021-04-13</td>
#       <td>2021-04-14</td>
#       <td>2021-04-15</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.00</td>
#       <td>2021-04-09</td>
#       <td>2021-04-12</td>
#       <td>2021-04-13</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-7.21%</td>
#       <td>4.81%</td>
#     </tr>
#   </tbody>
# </table>
