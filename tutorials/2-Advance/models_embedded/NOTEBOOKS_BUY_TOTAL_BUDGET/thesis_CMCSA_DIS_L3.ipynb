# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['CMCSA','DIS']
print(DOW_30_TICKER)
# Out:
# ['CMCSA', 'DIS']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date        open        high         low       close    volume  \
# 6121  2022-05-26  104.220001  106.129997  103.959999  105.610001  11297800
# 6122  2022-05-27   44.130001   44.639999   43.980000   43.477409  18073500
# 6123  2022-05-27  106.889999  109.370003  106.529999  109.320000  13671300
# 6124  2022-05-31   43.910000   44.660000   43.480000   43.595551  25249600
# 6125  2022-05-31  110.000000  111.239998  107.910004  110.440002  20274600
#
#         tic  day
# 6121    DIS    3
# 6122  CMCSA    4
# 6123    DIS    4
# 6124  CMCSA    1
# 6125    DIS    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume    tic  \
# 0  2010-04-01   9.410000   9.520000   9.310000   7.365883  38877200  CMCSA
# 1  2010-04-01  35.070000  35.590000  35.009998  30.965101  14603000    DIS
# 2  2010-04-05   9.405000   9.490000   9.340000   7.387471  26500200  CMCSA
# 3  2010-04-05  35.279999  35.540001  35.070000  30.677666  10607900    DIS
# 4  2010-04-06   9.340000   9.460000   9.290000   7.363921  22708600  CMCSA
#
#    day
# 0    3
# 1    3
# 2    0
# 3    0
# 4    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# CMCSA    3063
# DIS      3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 30#63 # rebalance_window is the number of days to retrain the model
validation_window = 30 #63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_60_1
# ---------------------------------------
# | time/                 |             |
# |    fps                | 32          |
# |    iterations         | 100         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.88       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.0121     |
# |    reward             | 0.038706217 |
# |    std                | 1.02        |
# |    value_loss         | 0.00073     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 58          |
# |    iterations         | 200         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.89       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.219      |
# |    reward             | 0.068416364 |
# |    std                | 1.03        |
# |    value_loss         | 0.013       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 300        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -0.454     |
# |    reward             | 0.16976482 |
# |    std                | 1.03       |
# |    value_loss         | 0.0484     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 400         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -2.91       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 0.723       |
# |    reward             | -0.57488436 |
# |    std                | 1.04        |
# |    value_loss         | 0.153       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 116        |
# |    iterations         | 500        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 0.053      |
# |    reward             | -6.1352434 |
# |    std                | 1.03       |
# |    value_loss         | 14.2       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 131          |
# |    iterations         | 600          |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -2.91        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.0359      |
# |    reward             | -0.009079765 |
# |    std                | 1.04         |
# |    value_loss         | 0.00269      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 700        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.91      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -2.21      |
# |    reward             | 0.12545846 |
# |    std                | 1.03       |
# |    value_loss         | 0.422      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 154        |
# |    iterations         | 800        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -0.28      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -7.33      |
# |    reward             | 0.52579665 |
# |    std                | 1.03       |
# |    value_loss         | 8.34       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 164          |
# |    iterations         | 900          |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -2.91        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 2.91         |
# |    reward             | -0.107921176 |
# |    std                | 1.03         |
# |    value_loss         | 5.94         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 172       |
# |    iterations         | 1000      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.9      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.699     |
# |    reward             | 1.2147716 |
# |    std                | 1.03      |
# |    value_loss         | 3.14      |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-02-17
# A2C Sharpe Ratio:  0.313964697985851
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_60_1
# -------------------------------------
# | time/              |              |
# |    fps             | 163          |
# |    iterations      | 1            |
# |    time_elapsed    | 12           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.049047694 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006166596 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.000613   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.885       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00138    |
# |    reward               | -0.26946118 |
# |    std                  | 1.01        |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 274           |
# |    iterations           | 3             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0046373205  |
# |    clip_fraction        | 0.0126        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 7.84e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.61          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00036      |
# |    reward               | -0.0009731487 |
# |    std                  | 1.01          |
# |    value_loss           | 6.13          |
# -------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-02-17
# PPO Sharpe Ratio:  0.20065907396139976
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_60_1
# ======DDPG Validation from:  2021-01-04 to  2021-02-17
# ======Best Model Retraining from:  2010-04-01 to  2021-02-17
# ======Trading from:  2021-02-17 to  2021-03-31
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-02-17
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_90_1
# ---------------------------------------
# | time/                 |             |
# |    fps                | 116         |
# |    iterations         | 100         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.98       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.0198     |
# |    reward             | 0.016318442 |
# |    std                | 1.07        |
# |    value_loss         | 0.000153    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 200         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -3.02       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 0.0606      |
# |    reward             | -0.09412415 |
# |    std                | 1.09        |
# |    value_loss         | 0.0296      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 110       |
# |    iterations         | 300       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -1.21     |
# |    reward             | 0.2959845 |
# |    std                | 1.1       |
# |    value_loss         | 0.159     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 130        |
# |    iterations         | 400        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -3.05      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 1.04       |
# |    reward             | -0.3788992 |
# |    std                | 1.11       |
# |    value_loss         | 0.174      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 152        |
# |    iterations         | 500        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -3.07      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -3.63      |
# |    reward             | -3.2709227 |
# |    std                | 1.12       |
# |    value_loss         | 4.55       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 171         |
# |    iterations         | 600         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -3.07       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.865      |
# |    reward             | -0.22874199 |
# |    std                | 1.12        |
# |    value_loss         | 0.0971      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 187         |
# |    iterations         | 700         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -3.07       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 0.482       |
# |    reward             | 0.057847694 |
# |    std                | 1.12        |
# |    value_loss         | 0.125       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 800       |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | 0.0143    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -3.98     |
# |    reward             | 1.4951222 |
# |    std                | 1.12      |
# |    value_loss         | 3.68      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 900        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -3.05      |
# |    explained_variance | -0.414     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 0.0898     |
# |    reward             | 0.34414503 |
# |    std                | 1.11       |
# |    value_loss         | 0.488      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 218       |
# |    iterations         | 1000      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -18.8     |
# |    reward             | 0.7424644 |
# |    std                | 1.12      |
# |    value_loss         | 58.9      |
# -------------------------------------
# ======A2C Validation from:  2021-02-17 to  2021-03-31
# A2C Sharpe Ratio:  -0.19060428652741845
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_90_1
# -------------------------------------
# | time/              |              |
# |    fps             | 166          |
# |    iterations      | 1            |
# |    time_elapsed    | 12           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.058775615 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0056059496 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.221        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00533     |
# |    reward               | -3.3839924   |
# |    std                  | 1.01         |
# |    value_loss           | 0.504        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0034293267 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3            |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000478    |
# |    reward               | -0.1311579   |
# |    std                  | 1.01         |
# |    value_loss           | 8.25         |
# ------------------------------------------
# ======PPO Validation from:  2021-02-17 to  2021-03-31
# PPO Sharpe Ratio:  -0.3468049268870404
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_90_1
# ======DDPG Validation from:  2021-02-17 to  2021-03-31
# ======Best Model Retraining from:  2010-04-01 to  2021-03-31
# ======Trading from:  2021-03-31 to  2021-05-13
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-03-31
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_120_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 107       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.457     |
# |    reward             | 0.5072426 |
# |    std                | 1.02      |
# |    value_loss         | 0.0804    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.785    |
# |    reward             | 0.7972547 |
# |    std                | 1.01      |
# |    value_loss         | 1.46      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 97        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0.0829    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -12.1     |
# |    reward             | 2.4908323 |
# |    std                | 1.01      |
# |    value_loss         | 8.21      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 115        |
# |    iterations         | 400        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 4.7        |
# |    reward             | -3.1553192 |
# |    std                | 1.01       |
# |    value_loss         | 4.93       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 500        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.84      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 0.813      |
# |    reward             | -12.792961 |
# |    std                | 0.999      |
# |    value_loss         | 60.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 154        |
# |    iterations         | 600        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -0.265     |
# |    reward             | 0.17230359 |
# |    std                | 1.01       |
# |    value_loss         | 0.0155     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 170         |
# |    iterations         | 700         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -1.66       |
# |    reward             | -0.29347128 |
# |    std                | 1.02        |
# |    value_loss         | 0.546       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 800       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -2.86     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 3.28      |
# |    reward             | 1.0445176 |
# |    std                | 1.01      |
# |    value_loss         | 2.67      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 197        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -0.0285    |
# |    reward             | -0.7120256 |
# |    std                | 1.01       |
# |    value_loss         | 0.247      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 208        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 4.72       |
# |    reward             | -0.6307993 |
# |    std                | 1.01       |
# |    value_loss         | 6.1        |
# --------------------------------------
# ======A2C Validation from:  2021-03-31 to  2021-05-13
# A2C Sharpe Ratio:  -0.19836906511470673
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_120_1
# -------------------------------------
# | time/              |              |
# |    fps             | 183          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.019929877 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005199302 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0633      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00238    |
# |    reward               | 0.09272544  |
# |    std                  | 1           |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 3             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.004523388   |
# |    clip_fraction        | 0.036         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00971      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00215      |
# |    reward               | -0.0018166376 |
# |    std                  | 1             |
# |    value_loss           | 0.0878        |
# -------------------------------------------
# ======PPO Validation from:  2021-03-31 to  2021-05-13
# PPO Sharpe Ratio:  -0.2921474844887361
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_120_1
# ======DDPG Validation from:  2021-03-31 to  2021-05-13
# ======Best Model Retraining from:  2010-04-01 to  2021-05-13
# ======Trading from:  2021-05-13 to  2021-06-25
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-05-13
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_150_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -2.83      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.112      |
# |    reward             | 0.33834788 |
# |    std                | 0.997      |
# |    value_loss         | 0.0599     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 200        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.81      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.596      |
# |    reward             | -0.7336219 |
# |    std                | 0.986      |
# |    value_loss         | 0.592      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -5.43     |
# |    reward             | 1.2951632 |
# |    std                | 0.981     |
# |    value_loss         | 3.68      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 121          |
# |    iterations         | 400          |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.79        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.0587       |
# |    reward             | -0.012472279 |
# |    std                | 0.978        |
# |    value_loss         | 0.000546     |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 140      |
# |    iterations         | 500      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0495   |
# |    reward             | 0.0      |
# |    std                | 0.991    |
# |    value_loss         | 0.00033  |
# ------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 156            |
# |    iterations         | 600            |
# |    time_elapsed       | 19             |
# |    total_timesteps    | 3000           |
# | train/                |                |
# |    entropy_loss       | -2.86          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 599            |
# |    policy_loss        | 0.000501       |
# |    reward             | -2.0878208e-05 |
# |    std                | 1.01           |
# |    value_loss         | 1.09e-06       |
# ------------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 171      |
# |    iterations         | 700      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00367  |
# |    reward             | 0.0      |
# |    std                | 1.04     |
# |    value_loss         | 3.11e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 800      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0379  |
# |    reward             | 0.0      |
# |    std                | 1.07     |
# |    value_loss         | 0.000228 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -3.03      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -0.0314    |
# |    reward             | 0.01999632 |
# |    std                | 1.1        |
# |    value_loss         | 7.54e-05   |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0919  |
# |    reward             | 0.0      |
# |    std                | 1.13     |
# |    value_loss         | 0.000738 |
# ------------------------------------
# ======A2C Validation from:  2021-05-13 to  2021-06-25
# A2C Sharpe Ratio:  -0.5907037438460608
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_150_1
# --------------------------------------
# | time/              |               |
# |    fps             | 176           |
# |    iterations      | 1             |
# |    time_elapsed    | 11            |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0067583635 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 262          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050409194 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0192       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00151     |
# |    reward               | -0.033133347 |
# |    std                  | 1            |
# |    value_loss           | 0.0979       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0032989832 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00589     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.451        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00141     |
# |    reward               | 0.01813219   |
# |    std                  | 0.998        |
# |    value_loss           | 1.65         |
# ------------------------------------------
# ======PPO Validation from:  2021-05-13 to  2021-06-25
# PPO Sharpe Ratio:  0.0743286904692202
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_150_1
# ======DDPG Validation from:  2021-05-13 to  2021-06-25
# ======Best Model Retraining from:  2010-04-01 to  2021-06-25
# ======Trading from:  2021-06-25 to  2021-08-09
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-06-25
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_180_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 122       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.433     |
# |    reward             | 0.3823049 |
# |    std                | 1.02      |
# |    value_loss         | 0.0493    |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 200         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | -0.238      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -0.103      |
# |    reward             | -0.19687352 |
# |    std                | 1.02        |
# |    value_loss         | 2.41        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 300      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -2.88    |
# |    explained_variance | 0.152    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -6.8     |
# |    reward             | 2.631652 |
# |    std                | 1.02     |
# |    value_loss         | 8.97     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 118       |
# |    iterations         | 400       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | -0.000745 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 6.73      |
# |    reward             | -3.431981 |
# |    std                | 1.03      |
# |    value_loss         | 6.24      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 138        |
# |    iterations         | 500        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | 0.0206     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -5.04      |
# |    reward             | -17.385973 |
# |    std                | 1.02       |
# |    value_loss         | 110        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 156         |
# |    iterations         | 600         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.826      |
# |    reward             | -0.08510174 |
# |    std                | 1.01        |
# |    value_loss         | 0.125       |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 172      |
# |    iterations         | 700      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 10.1     |
# |    reward             | 0.936917 |
# |    std                | 1.02     |
# |    value_loss         | 11.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 800       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | -0.0743   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 4.19      |
# |    reward             | 5.6260705 |
# |    std                | 1.02      |
# |    value_loss         | 6.57      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 38.8       |
# |    reward             | -0.5494842 |
# |    std                | 1.02       |
# |    value_loss         | 213        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | -0.0454   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 6.91      |
# |    reward             | 4.3224454 |
# |    std                | 1.03      |
# |    value_loss         | 9.99      |
# -------------------------------------
# ======A2C Validation from:  2021-06-25 to  2021-08-09
# A2C Sharpe Ratio:  0.17151575209063866
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_180_1
# ------------------------------------
# | time/              |             |
# |    fps             | 179         |
# |    iterations      | 1           |
# |    time_elapsed    | 11          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.01067664 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0024877158 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0257       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000498    |
# |    reward               | 0.36195365   |
# |    std                  | 1.01         |
# |    value_loss           | 0.131        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0039239647 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -7.98e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.635        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 5.42e-05     |
# |    reward               | 0.13239701   |
# |    std                  | 1.01         |
# |    value_loss           | 2.57         |
# ------------------------------------------
# ======PPO Validation from:  2021-06-25 to  2021-08-09
# PPO Sharpe Ratio:  -0.003941998852385981
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_180_1
# ======DDPG Validation from:  2021-06-25 to  2021-08-09
# ======Best Model Retraining from:  2010-04-01 to  2021-08-09
# ======Trading from:  2021-08-09 to  2021-09-21
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2021-08-09
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_210_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 105       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.382     |
# |    reward             | 0.4156604 |
# |    std                | 1.02      |
# |    value_loss         | 0.0574    |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 80           |
# |    iterations         | 200          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.88        |
# |    explained_variance | 0.0781       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.398       |
# |    reward             | -0.021398969 |
# |    std                | 1.02         |
# |    value_loss         | 1.8          |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 95        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# ...
# |    reward             | -4.173882 |
# |    std                | 1.01      |
# |    value_loss         | 23.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 500       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | 0.0271    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -37.4     |
# |    reward             | -32.52357 |
# |    std                | 1.02      |
# |    value_loss         | 456       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 153         |
# |    iterations         | 600         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.87       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.995      |
# |    reward             | -0.12615024 |
# |    std                | 1.02        |
# |    value_loss         | 0.253       |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 168      |
# |    iterations         | 700      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | -0.0516  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -5.89    |
# |    reward             | 1.540849 |
# |    std                | 1.01     |
# |    value_loss         | 5.02     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 182         |
# |    iterations         | 800         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -2.86       |
# |    explained_variance | -0.0638     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 3.97        |
# |    reward             | -0.23615952 |
# |    std                | 1.01        |
# |    value_loss         | 4.49        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 195        |
# |    iterations         | 900        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.0267     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 3.19       |
# |    reward             | -1.3698686 |
# |    std                | 1.01       |
# |    value_loss         | 4.65       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 205        |
# |    iterations         | 1000       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -0.00263   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 7.91       |
# |    reward             | 0.34243277 |
# |    std                | 1.02       |
# |    value_loss         | 13.7       |
# --------------------------------------
# ======A2C Validation from:  2021-12-15 to  2022-01-28
# A2C Sharpe Ratio:  -0.5367586263744041
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_300_1
# -----------------------------------
# | time/              |            |
# |    fps             | 184        |
# |    iterations      | 1          |
# |    time_elapsed    | 11         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.1079994 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.005873704  |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0319       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0024      |
# |    reward               | -0.012211749 |
# |    std                  | 1            |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0038923735 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.899        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00131     |
# |    reward               | 0.02048715   |
# |    std                  | 1            |
# |    value_loss           | 2.16         |
# ------------------------------------------
# ======PPO Validation from:  2021-12-15 to  2022-01-28
# PPO Sharpe Ratio:  -0.149086398798561
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_300_1
# ======DDPG Validation from:  2021-12-15 to  2022-01-28
# ======Best Model Retraining from:  2010-04-01 to  2022-01-28
# ======Trading from:  2022-01-28 to  2022-03-14
# ============================================
# turbulence_threshold:  19.884458539350415
# ======Model training from:  2010-04-01 to  2022-01-28
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_330_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 105       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0025    |
# |    reward             | 0.0       |
# |    std                | 1.09      |
# |    value_loss         | 2.44e-05  |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 81           |
# |    iterations         | 200          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -3.06        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -0.00612     |
# |    reward             | -0.015248767 |
# |    std                | 1.12         |
# |    value_loss         | 0.00247      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 300        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -3.07      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -1.91      |
# |    reward             | 0.50270295 |
# |    std                | 1.12       |
# |    value_loss         | 0.446      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 116        |
# |    iterations         | 400        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -3.07      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 3.96       |
# |    reward             | -1.3795823 |
# |    std                | 1.12       |
# |    value_loss         | 2.56       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 500       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -9.32     |
# |    reward             | -7.999102 |
# |    std                | 1.12      |
# |    value_loss         | 30.9      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 155          |
# |    iterations         | 600          |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -3.06        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.0829      |
# |    reward             | -0.009151816 |
# |    std                | 1.12         |
# |    value_loss         | 0.000865     |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 171       |
# |    iterations         | 700       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.171    |
# |    reward             | 0.4183289 |
# |    std                | 1.13      |
# |    value_loss         | 0.0641    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 800       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 3.28      |
# |    reward             | 0.0753146 |
# |    std                | 1.14      |
# |    value_loss         | 2.56      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 900       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 1.08      |
# |    reward             | 0.7100685 |
# |    std                | 1.13      |
# |    value_loss         | 0.237     |
# -------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 209            |
# |    iterations         | 1000           |
# |    time_elapsed       | 23             |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -3.1           |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | 0.0286         |
# |    reward             | -3.0046482e-05 |
# |    std                | 1.14           |
# |    value_loss         | 0.000156       |
# ------------------------------------------
# ======A2C Validation from:  2022-01-28 to  2022-03-14
# A2C Sharpe Ratio:  -0.57271867065564
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_330_1
# -------------------------------------
# | time/              |              |
# |    fps             | 189          |
# |    iterations      | 1            |
# |    time_elapsed    | 10           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.011409727 |
# -------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 275            |
# |    iterations           | 2              |
# |    time_elapsed         | 14             |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.006192381    |
# |    clip_fraction        | 0.0288         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.83          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | 0.223          |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.0013        |
# |    reward               | -0.00048666238 |
# |    std                  | 0.996          |
# |    value_loss           | 0.723          |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0033173726 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.9          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000708    |
# |    reward               | 0.011065348  |
# |    std                  | 0.993        |
# |    value_loss           | 7.89         |
# ------------------------------------------
# ======PPO Validation from:  2022-01-28 to  2022-03-14
# PPO Sharpe Ratio:  -0.2231299270925814
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_330_1
# ======DDPG Validation from:  2022-01-28 to  2022-03-14
# ======Best Model Retraining from:  2010-04-01 to  2022-03-14
# ======Trading from:  2022-03-14 to  2022-04-26
# Ensemble Strategy took:  33.89707729816437  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0   60  2021-01-04  2021-02-17        A2C   0.313965   0.200659         0.0
# 1   90  2021-02-17  2021-03-31       DDPG  -0.190604  -0.346805         0.0
# 2  120  2021-03-31  2021-05-13       DDPG  -0.198369  -0.292147    0.235087
# 3  150  2021-05-13  2021-06-25        PPO  -0.590704   0.074329         0.0
# 4  180  2021-06-25  2021-08-09        A2C   0.171516  -0.003942   -0.005559
# 5  210  2021-08-09  2021-09-21       DDPG   -0.08939  -0.047368    0.112201
# 6  240  2021-09-21  2021-11-02       DDPG  -0.175196  -0.083265         0.0
# 7  270  2021-11-02  2021-12-15        PPO  -0.421278  -0.387374   -0.422421
# 8  300  2021-12-15  2022-01-28       DDPG  -0.536759  -0.149086         0.0
# 9  330  2022-01-28  2022-03-14        PPO  -0.572719   -0.22313   -0.563242

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.1763288667441714

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-02-17           NaN  2021-02-17
# 1   9.999459e+05  2021-02-18     -0.000054  2021-02-18
# 2   9.998994e+05  2021-02-19     -0.000046  2021-02-19
# 3   1.001182e+06  2021-02-22      0.001283  2021-02-22
# 4   1.002034e+06  2021-02-23      0.000851  2021-02-23

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.052998
# Cumulative returns    -0.062769
# Annual volatility      0.045554
# Sharpe ratio          -1.176329
# Calmar ratio          -0.612074
# Stability              0.752733
# Max drawdown          -0.086587
# Omega ratio            0.704662
# Sortino ratio         -1.327832
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.787635
# Daily value at risk   -0.005952
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (299, 8)
# Annual return          0.072506
# Cumulative returns     0.086599
# Annual volatility      0.153945
# Sharpe ratio           0.533075
# Calmar ratio           0.555680
# Stability              0.530201
# Max drawdown          -0.130481
# Omega ratio            1.091667
# Sortino ratio          0.754643
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.921990
# Daily value at risk   -0.019070
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (299, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-02-17</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-25</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-5.3%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-6.277%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.555%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.18</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.61</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.659%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.33</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.595%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.06</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.66</td>
#       <td>2021-09-02</td>
#       <td>2021-12-01</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.13</td>
#       <td>2021-03-16</td>
#       <td>2021-06-23</td>
#       <td>2021-07-12</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.78</td>
#       <td>2021-07-12</td>
#       <td>2021-07-19</td>
#       <td>2021-07-26</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.39</td>
#       <td>2021-07-26</td>
#       <td>2021-08-04</td>
#       <td>2021-08-11</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.36</td>
#       <td>2021-08-23</td>
#       <td>2021-08-26</td>
#       <td>2021-08-31</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.02%</td>
#       <td>-2.75%</td>
#       <td>1.42%</td>
#     </tr>
#   </tbody>
# </table>
