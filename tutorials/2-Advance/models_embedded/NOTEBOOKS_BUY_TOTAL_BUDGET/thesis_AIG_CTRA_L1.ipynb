# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_pair_trading_Prices import StockPairTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
DOW_30_TICKER = ['AIG','CTRA']
print(DOW_30_TICKER)
# Out:
# ['AIG', 'CTRA']

# %%
TRAIN_START_DATE = '2010-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (6126, 8)

# %%
df['tic'].value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %%
df.tail()
# Out:
#             date       open       high        low      close    volume   tic  \
# 6121  2022-05-26  34.340000  35.779999  34.220001  33.063053  11206100  CTRA
# 6122  2022-05-27  57.849998  59.000000  57.630001  58.290867   3891100   AIG
# 6123  2022-05-27  34.250000  35.529999  34.200001  33.893208   8413700  CTRA
# 6124  2022-05-31  58.650002  59.759998  58.169998  57.974712   5639200   AIG
# 6125  2022-05-31  36.060001  36.450001  34.130001  32.757710  22122700  CTRA
#
#       day
# 6121    3
# 6122    4
# 6123    4
# 6124    1
# 6125    1

# %%
df.shape
# Out:
# (6126, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close    volume   tic  day
# 0  2010-04-01  34.250000  34.490002  33.810001  23.037468   6250200   AIG    3
# 1  2010-04-01   9.325000   9.500000   9.325000   7.570669   4922000  CTRA    3
# 2  2010-04-05  34.430000  35.450001  33.900002  23.679079  16281300   AIG    0
# 3  2010-04-05   9.507500   9.745000   9.442500   7.793335   4937200  CTRA    0
# 4  2010-04-06  35.490002  36.380001  35.200001  24.253155  19971000   AIG    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
temp = df.tic.value_counts()
if temp[DOW_30_TICKER[0]] != temp[DOW_30_TICKER[1]]:
    raise Exception('Not same Lenght')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.tic.value_counts()
# Out:
# AIG     3063
# CTRA    3063
# Name: tic, dtype: int64

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 2, State Space: 21

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 5_000, 
                 'ppo' : 5_000, 
                 'ddpg' : 5_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.344820403481563
# ======Model training from:  2010-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_65
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -2.92       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 0.569       |
# |    reward             | 0.059429064 |
# |    std                | 1.04        |
# |    value_loss         | 0.0668      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 141         |
# |    iterations         | 200         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -2.94       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -6.65       |
# |    reward             | -0.47182518 |
# |    std                | 1.05        |
# |    value_loss         | 5.42        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 179         |
# |    iterations         | 300         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -2.94       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 0.493       |
# |    reward             | -0.25566545 |
# |    std                | 1.05        |
# |    value_loss         | 0.478       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 208        |
# |    iterations         | 400        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.93      |
# |    explained_variance | 0.0157     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 4.01       |
# |    reward             | 0.11190978 |
# |    std                | 1.05       |
# |    value_loss         | 3.38       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 500       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -2.94     |
# |    explained_variance | -0.00654  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.01      |
# |    reward             | 1.4112101 |
# |    std                | 1.05      |
# |    value_loss         | 6.31      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 248         |
# |    iterations         | 600         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -2.93       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 1.63        |
# |    reward             | 0.015639426 |
# |    std                | 1.05        |
# |    value_loss         | 0.213       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 700        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 11.9       |
# |    reward             | -2.2035823 |
# |    std                | 1.05       |
# |    value_loss         | 19.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 272        |
# |    iterations         | 800        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.94      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 2.56       |
# |    reward             | 0.14698131 |
# |    std                | 1.05       |
# |    value_loss         | 2.84       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 281       |
# |    iterations         | 900       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.94     |
# |    explained_variance | -0.13     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -3.7      |
# |    reward             | 0.9524796 |
# |    std                | 1.05      |
# |    value_loss         | 1.68      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 288      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | -0.163   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -5.08    |
# |    reward             | 0.906116 |
# |    std                | 1.04     |
# |    value_loss         | 4.74     |
# ------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.23033945490723864
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_55
# ------------------------------------
# | time/              |             |
# |    fps             | 426         |
# |    iterations      | 1           |
# |    time_elapsed    | 4           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.105122164 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 446          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.004418662  |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.108        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000984    |
# |    reward               | 0.0016645524 |
# |    std                  | 1.01         |
# |    value_loss           | 0.261        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 448          |
# |    iterations           | 3            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0015035666 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0183       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -9.35e-06    |
# |    reward               | 0.12551014   |
# |    std                  | 1.01         |
# |    value_loss           | 0.0911       |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.3190856831410645
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_55
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2010-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  19.344820403481563
# ======Model training from:  2010-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_53
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | 0.144     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -3.42     |
# |    reward             | 2.4021964 |
# |    std                | 1.02      |
# |    value_loss         | 1.36      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 203        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | 0.0281     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -10.9      |
# |    reward             | -0.9801951 |
# |    std                | 1.01       |
# |    value_loss         | 15.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 207        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.86      |
# |    explained_variance | -0.283     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -3.21      |
# |    reward             | 0.85043263 |
# |    std                | 1.01       |
# |    value_loss         | 2.95       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 214        |
# |    iterations         | 400        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.85      |
# |    explained_variance | 0.0723     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 7.86       |
# |    reward             | -2.2160237 |
# |    std                | 1.01       |
# |    value_loss         | 11.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 221        |
# |    iterations         | 500        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.87      |
# |    explained_variance | -0.0209    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -13.7      |
# |    reward             | -16.237316 |
# |    std                | 1.02       |
# |    value_loss         | 43.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 600       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.218     |
# |    reward             | -2.077735 |
# |    std                | 1.02      |
# |    value_loss         | 0.243     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 235        |
# |    iterations         | 700        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -2.89      |
# |    explained_variance | 0.0705     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -6.57      |
# |    reward             | -4.3331547 |
# |    std                | 1.03       |
# |    value_loss         | 4.77       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 238        |
# |    iterations         | 800        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.9       |
# |    explained_variance | -0.0129    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 2.23       |
# |    reward             | 0.86340386 |
# |    std                | 1.03       |
# |    value_loss         | 1.67       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 235       |
# |    iterations         | 900       |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | -0.0977   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 2.99      |
# |    reward             | 1.7523655 |
# |    std                | 1.03      |
# |    value_loss         | 2.77      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 234        |
# |    iterations         | 1000       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -2.88      |
# |    explained_variance | -0.145     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 7.96       |
# |    reward             | -1.3082464 |
# |    std                | 1.02       |
# |    value_loss         | 10.5       |
# --------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  -0.08804041815552957
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_53
# ------------------------------------
# | time/              |             |
# |    fps             | 272         |
# |    iterations      | 1           |
# |    time_elapsed    | 7           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.042789288 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068396563 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.049        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00487     |
# |    reward               | -0.38761702  |
# |    std                  | 0.995        |
# |    value_loss           | 0.16         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004043591 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.384       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000674   |
# |    reward               | -0.1355424  |
# |    std                  | 0.994       |
# |    value_loss           | 1.13        |
# -----------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  -0.018644091572209042
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_53
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2010-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  19.344820403481563
# ======Model training from:  2010-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_53
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -2.3      |
# |    reward             | 1.8050175 |
# |    std                | 0.989     |
# |    value_loss         | 0.753     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 317        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -5.67      |
# |    reward             | -1.0173125 |
# |    std                | 0.991      |
# |    value_loss         | 17.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 300        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -2.82      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -2.15      |
# |    reward             | 0.90995884 |
# |    std                | 0.994      |
# |    value_loss         | 2.46       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 331        |
# |    iterations         | 400        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -2.81      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 6.3        |
# |    reward             | -2.3422332 |
# |    std                | 0.985      |
# |    value_loss         | 12.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 340        |
# |    iterations         | 500        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -2.81      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -16.8      |
# |    reward             | -18.514252 |
# |    std                | 0.988      |
# |    value_loss         | 52.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 345       |
# |    iterations         | 600       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.21      |
# |    reward             | -0.553954 |
# |    std                | 0.984     |
# |    value_loss         | 0.424     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.8     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -9.49    |
# |    reward             | 0.802451 |
# |    std                | 0.98     |
# |    value_loss         | 13.1     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 356        |
# |    iterations         | 800        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -2.79      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 3.54       |
# |    reward             | 0.37454197 |
# |    std                | 0.976      |
# |    value_loss         | 2.98       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 900      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -2.8     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -24.8    |
# |    reward             | 7.353514 |
# |    std                | 0.983    |
# |    value_loss         | 93.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 1000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -2.8     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -6.02    |
# |    reward             | 2.593629 |
# |    std                | 0.984    |
# |    value_loss         | 35.6     |
# ------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  0.28567562999163315
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_252_53
# -----------------------------------
# | time/              |            |
# |    fps             | 470        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.12683041 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041429466 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.161        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000646    |
# |    reward               | 0.030233316  |
# |    std                  | 1            |
# |    value_loss           | 0.46         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 468           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.004799031   |
# |    clip_fraction        | 0.0338        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.485         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00179      |
# |    reward               | -0.0028774096 |
# |    std                  | 1             |
# |    value_loss           | 1.19          |
# -------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  0.17520543583578654
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_252_52
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2010-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  19.344820403481563
# ======Model training from:  2010-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_315_50
# -----------------------------------------
# | time/                 |               |
# |    fps                | 262           |
# |    iterations         | 100           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -2.93         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | -0.00674      |
# |    reward             | 0.00053628144 |
# |    std                | 1.05          |
# |    value_loss         | 8.97e-06      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 249           |
# |    iterations         | 200           |
# |    time_elapsed       | 4             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -3.02         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | -0.0376       |
# |    reward             | -0.0043813046 |
# |    std                | 1.09          |
# |    value_loss         | 0.000224      |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.00959   |
# |    reward             | 0.0       |
# |    std                | 1.12      |
# |    value_loss         | 3.1e-05   |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 279         |
# |    iterations         | 400         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -3.14       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -0.0049     |
# |    reward             | 0.001317318 |
# |    std                | 1.17        |
# |    value_loss         | 4.14e-06    |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 297            |
# |    iterations         | 500            |
# |    time_elapsed       | 8              |
# |    total_timesteps    | 2500           |
# | train/                |                |
# |    entropy_loss       | -3.23          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 499            |
# |    policy_loss        | 0.0245         |
# |    reward             | -1.6697777e-05 |
# |    std                | 1.22           |
# |    value_loss         | 8.84e-05       |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 311         |
# |    iterations         | 600         |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -3.32       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 7.16e-05    |
# |    reward             | 0.020629926 |
# |    std                | 1.27        |
# |    value_loss         | 1.54e-07    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 323         |
# |    iterations         | 700         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -3.34       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.863      |
# |    reward             | -0.36576715 |
# |    std                | 1.29        |
# |    value_loss         | 0.403       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 331         |
# |    iterations         | 800         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -3.34       |
# |    explained_variance | 0.0012      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -4.22       |
# |    reward             | -0.86792284 |
# |    std                | 1.29        |
# |    value_loss         | 2.92        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 337       |
# |    iterations         | 900       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.35     |
# |    explained_variance | 0.00956   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 4.5       |
# |    reward             | 2.0179856 |
# |    std                | 1.29      |
# |    value_loss         | 4.74      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 343        |
# |    iterations         | 1000       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -3.34      |
# |    explained_variance | 0.0273     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -7.4       |
# |    reward             | -1.3538642 |
# |    std                | 1.28       |
# |    value_loss         | 18         |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.24516524055064476
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_50
# -----------------------------------
# | time/              |            |
# |    fps             | 432        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.03982942 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0064696814 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0179       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00225     |
# |    reward               | -0.22913338  |
# |    std                  | 0.997        |
# |    value_loss           | 0.105        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.00426458  |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.159       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00152    |
# |    reward               | -0.19955492 |
# |    std                  | 1           |
# |    value_loss           | 0.309       |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.10431448409600959
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_50
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  13.858819897969564  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO   0.230339   0.319086    0.018467
# 1  189  2021-04-06  2021-07-06        PPO   -0.08804  -0.018644   -0.078014
# 2  252  2021-07-06  2021-10-04        A2C   0.285676   0.175205         0.0
# 3  315  2021-10-04  2022-01-03        PPO  -0.245165   0.104314   -0.229159

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.22563925834823526

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   1.000032e+06  2021-04-07      0.000032  2021-04-07
# 2   9.998099e+05  2021-04-08     -0.000222  2021-04-08
# 3   9.998450e+05  2021-04-09      0.000035  2021-04-09
# 4   9.999748e+05  2021-04-12      0.000130  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.010988
# Cumulative returns     0.010988
# Annual volatility      0.055403
# Sharpe ratio           0.225639
# Calmar ratio           0.312555
# Stability              0.246666
# Max drawdown          -0.035155
# Omega ratio            1.060033
# Sortino ratio          0.321375
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.152113
# Daily value at risk   -0.006930
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^GSPC", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.112517
# Cumulative returns     0.112046
# Annual volatility      0.149492
# Sharpe ratio           0.790765
# Calmar ratio           0.862325
# Stability              0.388079
# Max drawdown          -0.130481
# Omega ratio            1.139645
# Sortino ratio          1.131726
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.856084
# Daily value at risk   -0.018365
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^GSPC', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>1.099%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1.099%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.54%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.31</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-3.515%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.693%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3.52</td>
#       <td>2021-11-03</td>
#       <td>2021-12-01</td>
#       <td>2022-01-04</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.36</td>
#       <td>2022-01-14</td>
#       <td>2022-01-27</td>
#       <td>2022-02-08</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.95</td>
#       <td>2022-02-25</td>
#       <td>2022-03-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.11</td>
#       <td>2022-02-08</td>
#       <td>2022-02-14</td>
#       <td>2022-02-25</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.51</td>
#       <td>2022-01-04</td>
#       <td>2022-01-05</td>
#       <td>2022-01-06</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.00%</td>
#       <td>-1.86%</td>
#       <td>1.57%</td>
#     </tr>
#   </tbody>
# </table>
